# %%
import os
import keypoint_moseq as kpms

# Set your project directory
project_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\test2"

# List everything in the project directory
print("Contents of project directory:")
for item in os.listdir(project_dir):
    item_path = os.path.join(project_dir, item)
    if os.path.isdir(item_path):
        print(f"  [FOLDER] {item}")
    else:
        print(f"  [FILE] {item}")

print("\n" + "="*50)

# Try to find any files that might contain model information
model_files = []
for item in os.listdir(project_dir):
    if 'model' in item.lower() or item.endswith('.pkl') or item.endswith('.h5'):
        model_files.append(item)

if model_files:
    print("Found potential model files:")
    for f in model_files:
        print(f"  {f}")
else:
    print("No obvious model files found.")

# Check if the model training actually completed
# Look for any keypoint-moseq related files
kpms_files = []
for item in os.listdir(project_dir):
    if any(keyword in item.lower() for keyword in ['config', 'pca', 'checkpoint', 'results']):
        kpms_files.append(item)

if kpms_files:
    print("\nFound keypoint-moseq related files:")
    for f in kpms_files:
        print(f"  {f}")
# Out:
# Contents of project directory:
#   [FOLDER] 2025_07_17-14_55_28
#   [FOLDER] 2025_07_18-10_06_31
#   [FOLDER] 2025_07_18-13_17_52
#   [FOLDER] 2025_07_18-13_19_39
#   [FOLDER] 2025_07_18-15_53_33
#   [FOLDER] 2025_07_18-16_01_19
#   [FOLDER] 2025_07_18-16_05_03
#   [FOLDER] 2025_07_18-16_09_16
#   [FOLDER] 2025_07_18-16_14_45
#   [FOLDER] 2025_07_18-16_19_31
#   [FOLDER] 2025_07_18-16_27_34
#   [FOLDER] 2025_07_18-16_28_09
#   [FOLDER] 2025_07_18-16_30_55
#   [FOLDER] 2025_07_18-16_41_01
#   [FOLDER] 2025_07_21-09_52_31
#   [FOLDER] 2025_07_21-14_11_49
#   [FOLDER] 2025_07_21-14_38_18
#   [FOLDER] 2025_07_21-14_43_04
#   [FOLDER] 2025_07_21-14_51_36
#   [FOLDER] 2025_07_21-14_56_50
#   [FOLDER] 2025_07_21-15_04_32
#   [FOLDER] 2025_07_21-15_08_50
#   [FOLDER] 2025_07_21-15_15_25
#   [FOLDER] 2025_07_21-15_19_08
#   [FOLDER] 2025_07_21-15_49_45
#   [FOLDER] 2025_07_21-15_56_06
#   [FOLDER] 2025_07_21-16_01_17
#   [FOLDER] 2025_07_21-16_03_59
#   [FOLDER] 2025_07_21-16_10_04
#   [FOLDER] 2025_07_22-09_41_57
#   [FOLDER] 2025_07_22-10_01_28
#   [FOLDER] 2025_07_22-11_31_18
#   [FOLDER] 2025_07_22-11_36_56
#   [FOLDER] 2025_07_22-12_46_07
#   [FOLDER] 2025_07_22-12_51_51
#   [FOLDER] 2025_07_22-13_00_08
#   [FOLDER] 2025_07_22-13_05_51
#   [FOLDER] 2025_07_22-13_13_20
#   [FOLDER] 2025_07_22-13_18_54
#   [FOLDER] 2025_07_22-14_12_17
#   [FOLDER] 2025_07_22-14_17_52
#   [FOLDER] 2025_07_31-23_03_57
#   [FILE] config.yml
#   [FILE] pca.p
#   [FILE] pca_scree.pdf
#   [FILE] pcs-xy.pdf
#   [FOLDER] RI1 All
#   [FOLDER] RI1 Resp
#   [FOLDER] RI1 Upd
#   [FOLDER] RI2 All
#   [FOLDER] RI2 Resp
#   [FOLDER] RI2 Upd
#
# ==================================================
# No obvious model files found.
#
# Found keypoint-moseq related files:
#   config.yml
#   pca.p
#   pca_scree.pdf

# %%
import pandas as pd
import numpy as np
import keypoint_moseq as kpms
import os
import glob

# Set your project directory (updated to the correct path)
project_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2"
config = lambda: kpms.load_config(project_dir)

# Use the specific model you mentioned
model_name = "2025_08_04-15_38_34"
print(f"Using model: {model_name}")

# Load the checkpoint
model, data, metadata, current_iter = kpms.load_checkpoint(project_dir, model_name)
print(f"Loaded checkpoint at iteration: {current_iter}")

# Try to load existing results first, if that fails, extract new ones with overwrite
try:
    results_path = os.path.join(project_dir, model_name, "results.h5")
    if os.path.exists(results_path):
        print("Loading existing results...")
        results = kpms.load_results(project_dir, model_name)
    else:
        print("No existing results found, extracting new results...")
        results = kpms.extract_results(model, metadata, project_dir, model_name)
except:
    print("Loading failed, extracting results with overwrite...")
    # Extract results with overwrite (modify the source or use a workaround)
    results_path = os.path.join(project_dir, model_name, "results.h5")
    if os.path.exists(results_path):
        os.remove(results_path)  # Delete existing file
    results = kpms.extract_results(model, metadata, project_dir, model_name)

print(f"Successfully loaded results for {len(results)} recordings")

# Define the function to create Excel files and calculate average syllable durations
def create_excel_files_and_calculate_avg_durations(results, project_dir, model_name):
    """
    Create individual Excel files for each video/track with ALL frames and calculate average syllable duration for each individual track
    """
    duration_summary = []
    
    for video_key, result_data in results.items():
        # Extract video name and track info
        if 'track' in video_key.lower():
            # Extract track number from the key
            if 'track1' in video_key.lower():
                track_num = 1
            elif 'track2' in video_key.lower():
                track_num = 2
            else:
                track_num = 1  # default
        else:
            track_num = 1  # default if no track info
            
        # Extract clean video name (remove path and extension)
        video_name = video_key.split('\\')[-1].split('.')[0] if '\\' in video_key else video_key.split('.')[0]
        # Remove track info from video name if present
        video_name_clean = video_name.replace('_track1', '').replace('_track2', '').replace('track1', '').replace('track2', '')
        
        # Get ALL syllables (including NaN values)
        syllables = result_data['syllable']
        total_frames = len(syllables)
        
        # Create frame numbers for ALL frames
        all_frames = np.arange(total_frames)
        
        # Create DataFrame for this video/track with ALL frames
        df_data = {
            'frame_number': all_frames,
            'syllable': syllables,  # Keep NaN values
            'video_name': video_name_clean,
            'track_name': video_key,
            'track_number': track_num
        }
        
        df = pd.DataFrame(df_data)
        
        # Save individual Excel file with track number in filename
        excel_filename = f"{video_name_clean}_track{track_num}_syllables.xlsx"
        excel_path = os.path.join(project_dir, excel_filename)
        df.to_excel(excel_path, index=False)
        print(f"Saved: {excel_filename} ({total_frames} total frames)")
        
        # Calculate average syllable duration for THIS SPECIFIC video/track (excluding NaN frames)
        valid_mask = ~np.isnan(syllables)
        if np.any(valid_mask):
            clean_syllables = syllables[valid_mask].astype(int)
            
            all_durations = []
            current_syllable = clean_syllables[0]
            duration_start = 0
            
            for i in range(1, len(clean_syllables)):
                if clean_syllables[i] != current_syllable:
                    # End of current syllable bout
                    duration = i - duration_start
                    all_durations.append(duration)
                    
                    # Start new syllable bout
                    current_syllable = clean_syllables[i]
                    duration_start = i
            
            # Don't forget the last syllable bout
            final_duration = len(clean_syllables) - duration_start
            all_durations.append(final_duration)
            
            # Calculate average duration for THIS SPECIFIC video/track
            avg_duration = np.mean(all_durations)
            std_duration = np.std(all_durations)
            bout_count = len(all_durations)
            valid_frame_count = np.sum(valid_mask)
            nan_frame_count = np.sum(~valid_mask)
            
            duration_summary.append({
                'video_name': video_name_clean,
                'track_number': track_num,
                'track_name': video_key,
                'total_frames': total_frames,
                'valid_frames': valid_frame_count,
                'nan_frames': nan_frame_count,
                'average_syllable_duration_frames': avg_duration,
                'std_syllable_duration_frames': std_duration,
                'total_syllable_bouts': bout_count
            })
    
    return duration_summary

# Execute the function
print("Creating individual Excel files and calculating average syllable durations...")
duration_summary = create_excel_files_and_calculate_avg_durations(results, project_dir, model_name)

# Create and save summary DataFrame
summary_df = pd.DataFrame(duration_summary)
summary_path = os.path.join(project_dir, f"{model_name}_individual_track_syllable_durations.xlsx")
summary_df.to_excel(summary_path, index=False)
print(f"\nSaved duration summary: {model_name}_individual_track_syllable_durations.xlsx")

# Display summary
print("\n" + "="*80)
print("INDIVIDUAL TRACK SYLLABLE DURATION SUMMARY (FRAMES)")
print("="*80)

for _, row in summary_df.iterrows():
    print(f"{row['video_name']} - Track {row['track_number']}:")
    print(f"  Total frames: {row['total_frames']}")
    print(f"  Valid frames: {row['valid_frames']}")
    print(f"  NaN frames: {row['nan_frames']}")
    print(f"  Average syllable duration: {row['average_syllable_duration_frames']:.1f} ± {row['std_syllable_duration_frames']:.1f} frames")
    print(f"  Total syllable bouts: {row['total_syllable_bouts']}")
    print()

print(f"Files saved to: {project_dir}")
# Out:
# Using model: 2025_08_04-15_38_34
# Loaded checkpoint at iteration: 550
# Loading existing results...
# Successfully loaded results for 34 recordings
# Creating individual Excel files and calculating average syllable durations...
# Saved: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx (9300 total frames)
# Saved: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx (9300 total frames)
# Saved: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx (18083 total frames)
# Saved: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx (18083 total frames)
# Saved: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx (18060 total frames)
# Saved: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx (18060 total frames)
# Saved: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx (9116 total frames)
# Saved: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx (9116 total frames)
# Saved: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx (18064 total frames)
# Saved: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx (18064 total frames)
# Saved: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx (18699 total frames)
# Saved: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx (18699 total frames)
# Saved: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx (18015 total frames)
# Saved: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx (18015 total frames)
# Saved: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx (18405 total frames)
# Saved: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx (18405 total frames)
# Saved: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx (9053 total frames)
# Saved: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx (9053 total frames)
# Saved: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx (18095 total frames)
# Saved: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx (18095 total frames)
# Saved: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx (18153 total frames)
# Saved: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx (18153 total frames)
# Saved: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx (9065 total frames)
# Saved: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx (9065 total frames)
# Saved: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx (18062 total frames)
# Saved: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx (18062 total frames)
# Saved: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx (18263 total frames)
# Saved: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx (18263 total frames)
# Saved: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx (18158 total frames)
# Saved: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx (18158 total frames)
# Saved: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx (18065 total frames)
# Saved: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx (18065 total frames)
# Saved: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx (14654 total frames)
# Saved: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx (14654 total frames)
#
# Saved duration summary: 2025_08_04-15_38_34_individual_track_syllable_durations.xlsx
#
# ================================================================================
# INDIVIDUAL TRACK SYLLABLE DURATION SUMMARY (FRAMES)
# ================================================================================
# top-RI1_s1_1_p5_2_nRB6_20250622_143958 - Track 1:
#   Total frames: 9300
#   Valid frames: 9300
#   NaN frames: 0
#   Average syllable duration: 5.9 ± 8.0 frames
#   Total syllable bouts: 1569
#
# top-RI1_s1_1_p5_2_nRB6_20250622_143958 - Track 1:
#   Total frames: 9300
#   Valid frames: 9300
#   NaN frames: 0
#   Average syllable duration: 4.8 ± 6.0 frames
#   Total syllable bouts: 1927
#
# top-RI1_s1_2_p5_1_nRB6_20250622_170742 - Track 1:
#   Total frames: 18083
#   Valid frames: 18083
#   NaN frames: 0
#   Average syllable duration: 7.1 ± 13.3 frames
#   Total syllable bouts: 2532
#
# top-RI1_s1_2_p5_1_nRB6_20250622_170742 - Track 1:
#   Total frames: 18083
#   Valid frames: 18083
#   NaN frames: 0
#   Average syllable duration: 6.7 ± 11.8 frames
#   Total syllable bouts: 2710
#
# top-RI1_s2_3_p5_3_nRB3_20250622_104059 - Track 1:
#   Total frames: 18060
#   Valid frames: 18060
#   NaN frames: 0
#   Average syllable duration: 11.1 ± 22.9 frames
#   Total syllable bouts: 1625
#
# top-RI1_s2_3_p5_3_nRB3_20250622_104059 - Track 1:
#   Total frames: 18060
#   Valid frames: 18060
#   NaN frames: 0
#   Average syllable duration: 9.3 ± 16.8 frames
#   Total syllable bouts: 1944
#
# top-RI1_s2_4_p5_4_nRB3_20250622_123424 - Track 1:
#   Total frames: 9116
#   Valid frames: 9116
#   NaN frames: 0
#   Average syllable duration: 6.5 ± 9.8 frames
#   Total syllable bouts: 1410
#
# top-RI1_s2_4_p5_4_nRB3_20250622_123424 - Track 1:
#   Total frames: 9116
#   Valid frames: 9116
#   NaN frames: 0
#   Average syllable duration: 5.3 ± 7.7 frames
#   Total syllable bouts: 1723
#
# top-RI1_s3_6_p5_3_nRB3_20250621_125312 - Track 1:
#   Total frames: 18064
#   Valid frames: 18064
#   NaN frames: 0
#   Average syllable duration: 13.6 ± 25.9 frames
#   Total syllable bouts: 1329
#
# top-RI1_s3_6_p5_3_nRB3_20250621_125312 - Track 1:
#   Total frames: 18064
#   Valid frames: 18064
#   NaN frames: 0
#   Average syllable duration: 8.7 ± 15.4 frames
#   Total syllable bouts: 2068
#
# top-RI1_s4_7_p5_2_nRB3_20250621_150707 - Track 1:
#   Total frames: 18699
#   Valid frames: 18699
#   NaN frames: 0
#   Average syllable duration: 8.4 ± 15.2 frames
#   Total syllable bouts: 2238
#
# top-RI1_s4_7_p5_2_nRB3_20250621_150707 - Track 1:
#   Total frames: 18699
#   Valid frames: 18699
#   NaN frames: 0
#   Average syllable duration: 7.5 ± 9.6 frames
#   Total syllable bouts: 2501
#
# top-RI1_s4_8_p5_1_nRB3_20250621_165214 - Track 1:
#   Total frames: 18015
#   Valid frames: 18015
#   NaN frames: 0
#   Average syllable duration: 7.9 ± 10.9 frames
#   Total syllable bouts: 2268
#
# top-RI1_s4_8_p5_1_nRB3_20250621_165214 - Track 1:
#   Total frames: 18015
#   Valid frames: 18015
#   NaN frames: 0
#   Average syllable duration: 5.7 ± 6.8 frames
#   Total syllable bouts: 3179
#
# top-RI1_s5_13_p5_4_nRB3_20250622_181801 - Track 1:
#   Total frames: 18405
#   Valid frames: 18405
#   NaN frames: 0
#   Average syllable duration: 9.3 ± 15.6 frames
#   Total syllable bouts: 1977
#
# top-RI1_s5_13_p5_4_nRB3_20250622_181801 - Track 1:
#   Total frames: 18405
#   Valid frames: 18405
#   NaN frames: 0
#   Average syllable duration: 7.6 ± 15.0 frames
#   Total syllable bouts: 2430
#
# top-RI2_s1_1_p5_2_nRB6_20250622_150457 - Track 1:
#   Total frames: 9053
#   Valid frames: 9053
#   NaN frames: 0
#   Average syllable duration: 10.6 ± 25.4 frames
#   Total syllable bouts: 856
#
# top-RI2_s1_1_p5_2_nRB6_20250622_150457 - Track 1:
#   Total frames: 9053
#   Valid frames: 9053
#   NaN frames: 0
#   Average syllable duration: 5.1 ± 5.8 frames
#   Total syllable bouts: 1778
#
# top-RI2_s1_2_p5_1_nRB6_20250622_173049 - Track 1:
#   Total frames: 18095
#   Valid frames: 18095
#   NaN frames: 0
#   Average syllable duration: 21.2 ± 62.3 frames
#   Total syllable bouts: 854
#
# top-RI2_s1_2_p5_1_nRB6_20250622_173049 - Track 1:
#   Total frames: 18095
#   Valid frames: 18095
#   NaN frames: 0
#   Average syllable duration: 8.4 ± 12.2 frames
#   Total syllable bouts: 2143
#
# top-RI2_s2_3_p5_3_nRB3_20250622_110216 - Track 1:
#   Total frames: 18153
#   Valid frames: 18153
#   NaN frames: 0
#   Average syllable duration: 14.6 ± 56.7 frames
#   Total syllable bouts: 1243
#
# top-RI2_s2_3_p5_3_nRB3_20250622_110216 - Track 1:
#   Total frames: 18153
#   Valid frames: 18153
#   NaN frames: 0
#   Average syllable duration: 7.2 ± 10.1 frames
#   Total syllable bouts: 2504
#
# top-RI2_s2_4_p5_4_nRB3_20250622_125648 - Track 1:
#   Total frames: 9065
#   Valid frames: 9065
#   NaN frames: 0
#   Average syllable duration: 11.3 ± 29.7 frames
#   Total syllable bouts: 804
#
# top-RI2_s2_4_p5_4_nRB3_20250622_125648 - Track 1:
#   Total frames: 9065
#   Valid frames: 9065
#   NaN frames: 0
#   Average syllable duration: 5.8 ± 10.6 frames
#   Total syllable bouts: 1572
#
# top-RI2_s3_5_p5_4_nRB3_20250621_112618 - Track 1:
#   Total frames: 18062
#   Valid frames: 18062
#   NaN frames: 0
#   Average syllable duration: 15.3 ± 87.1 frames
#   Total syllable bouts: 1180
#
# top-RI2_s3_5_p5_4_nRB3_20250621_112618 - Track 1:
#   Total frames: 18062
#   Valid frames: 18062
#   NaN frames: 0
#   Average syllable duration: 6.3 ± 9.8 frames
#   Total syllable bouts: 2862
#
# top-RI2_s3_6_p_5_3_nRB3_20250621_131158 - Track 1:
#   Total frames: 18263
#   Valid frames: 18263
#   NaN frames: 0
#   Average syllable duration: 10.9 ± 41.2 frames
#   Total syllable bouts: 1679
#
# top-RI2_s3_6_p_5_3_nRB3_20250621_131158 - Track 1:
#   Total frames: 18263
#   Valid frames: 18263
#   NaN frames: 0
#   Average syllable duration: 6.8 ± 10.4 frames
#   Total syllable bouts: 2676
#
# top-RI2_s4_7_p5_2_nRB3_20250621_152519 - Track 1:
#   Total frames: 18158
#   Valid frames: 18158
#   NaN frames: 0
#   Average syllable duration: 8.1 ± 19.7 frames
#   Total syllable bouts: 2251
#
# top-RI2_s4_7_p5_2_nRB3_20250621_152519 - Track 1:
#   Total frames: 18158
#   Valid frames: 18158
#   NaN frames: 0
#   Average syllable duration: 6.3 ± 7.9 frames
#   Total syllable bouts: 2861
#
# top-RI2_s4_8_p5_1_nRB3_20250621_171318 - Track 1:
#   Total frames: 18065
#   Valid frames: 18065
#   NaN frames: 0
#   Average syllable duration: 10.4 ± 36.0 frames
#   Total syllable bouts: 1741
#
# top-RI2_s4_8_p5_1_nRB3_20250621_171318 - Track 1:
#   Total frames: 18065
#   Valid frames: 18065
#   NaN frames: 0
#   Average syllable duration: 6.4 ± 8.9 frames
#   Total syllable bouts: 2839
#
# top-RI2_s5_13_p5_4_nRB3_20250622_184136 - Track 1:
#   Total frames: 14654
#   Valid frames: 14654
#   NaN frames: 0
#   Average syllable duration: 10.3 ± 31.9 frames
#   Total syllable bouts: 1421
#
# top-RI2_s5_13_p5_4_nRB3_20250622_184136 - Track 1:
#   Total frames: 14654
#   Valid frames: 14654
#   NaN frames: 0
#   Average syllable duration: 6.6 ± 9.5 frames
#   Total syllable bouts: 2222
#
# Files saved to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2

# %%
import pandas as pd
import numpy as np
import keypoint_moseq as kpms
import os
import glob

# Set your project directory (updated to the correct path)
project_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2"
config = lambda: kpms.load_config(project_dir)

# Create subfolder for Excel files
excel_output_dir = os.path.join(project_dir, "Excel_Results")
if not os.path.exists(excel_output_dir):
    os.makedirs(excel_output_dir)
    print(f"Created folder: {excel_output_dir}")

# Use the specific model you mentioned
model_name = "2025_08_04-15_38_34"
print(f"Using model: {model_name}")

# Load the checkpoint
model, data, metadata, current_iter = kpms.load_checkpoint(project_dir, model_name)
print(f"Loaded checkpoint at iteration: {current_iter}")

# Try to load existing results first, if that fails, extract new ones with overwrite
try:
    results_path = os.path.join(project_dir, model_name, "results.h5")
    if os.path.exists(results_path):
        print("Loading existing results...")
        results = kpms.load_results(project_dir, model_name)
    else:
        print("No existing results found, extracting new results...")
        results = kpms.extract_results(model, metadata, project_dir, model_name)
except:
    print("Loading failed, extracting results with overwrite...")
    # Extract results with overwrite (modify the source or use a workaround)
    results_path = os.path.join(project_dir, model_name, "results.h5")
    if os.path.exists(results_path):
        os.remove(results_path)  # Delete existing file
    results = kpms.extract_results(model, metadata, project_dir, model_name)

print(f"Successfully loaded results for {len(results)} recordings")

# Define the function to create Excel files and calculate average syllable durations
def create_excel_files_and_calculate_avg_durations(results, excel_output_dir, model_name):
    """
    Create individual Excel files for each video/track with ALL frames and calculate average syllable duration for each individual track
    """
    duration_summary = []
    
    for video_key, result_data in results.items():
        # Extract video name and track info
        if 'track' in video_key.lower():
            # Extract track number from the key
            if 'track1' in video_key.lower():
                track_num = 1
            elif 'track2' in video_key.lower():
                track_num = 2
            else:
                track_num = 1  # default
        else:
            track_num = 1  # default if no track info
            
        # Extract clean video name (remove path and extension)
        video_name = video_key.split('\\')[-1].split('.')[0] if '\\' in video_key else video_key.split('.')[0]
        # Remove track info from video name if present
        video_name_clean = video_name.replace('_track1', '').replace('_track2', '').replace('track1', '').replace('track2', '')
        
        # Get ALL syllables (including NaN values)
        syllables = result_data['syllable']
        total_frames = len(syllables)
        
        # Create frame numbers for ALL frames
        all_frames = np.arange(total_frames)
        
        # Create DataFrame for this video/track with ALL frames
        df_data = {
            'frame_number': all_frames,
            'syllable': syllables,  # Keep NaN values
            'video_name': video_name_clean,
            'track_name': video_key,
            'track_number': track_num
        }
        
        df = pd.DataFrame(df_data)
        
        # Save individual Excel file with track number in filename IN THE SUBFOLDER
        excel_filename = f"{video_name_clean}_track{track_num}_syllables.xlsx"
        excel_path = os.path.join(excel_output_dir, excel_filename)
        df.to_excel(excel_path, index=False)
        print(f"Saved: Excel_Results/{excel_filename} ({total_frames} total frames)")
        
        # Calculate average syllable duration for THIS SPECIFIC video/track (excluding NaN frames)
        valid_mask = ~np.isnan(syllables)
        if np.any(valid_mask):
            clean_syllables = syllables[valid_mask].astype(int)
            
            all_durations = []
            current_syllable = clean_syllables[0]
            duration_start = 0
            
            for i in range(1, len(clean_syllables)):
                if clean_syllables[i] != current_syllable:
                    # End of current syllable bout
                    duration = i - duration_start
                    all_durations.append(duration)
                    
                    # Start new syllable bout
                    current_syllable = clean_syllables[i]
                    duration_start = i
            
            # Don't forget the last syllable bout
            final_duration = len(clean_syllables) - duration_start
            all_durations.append(final_duration)
            
            # Calculate average duration for THIS SPECIFIC video/track
            avg_duration = np.mean(all_durations)
            std_duration = np.std(all_durations)
            bout_count = len(all_durations)
            valid_frame_count = np.sum(valid_mask)
            nan_frame_count = np.sum(~valid_mask)
            
            duration_summary.append({
                'video_name': video_name_clean,
                'track_number': track_num,
                'track_name': video_key,
                'total_frames': total_frames,
                'valid_frames': valid_frame_count,
                'nan_frames': nan_frame_count,
                'average_syllable_duration_frames': avg_duration,
                'std_syllable_duration_frames': std_duration,
                'total_syllable_bouts': bout_count
            })
    
    return duration_summary

# Execute the function
print("Creating individual Excel files and calculating average syllable durations...")
duration_summary = create_excel_files_and_calculate_avg_durations(results, excel_output_dir, model_name)

# Create and save summary DataFrame IN THE SUBFOLDER
summary_df = pd.DataFrame(duration_summary)
summary_path = os.path.join(excel_output_dir, f"{model_name}_individual_track_syllable_durations.xlsx")
summary_df.to_excel(summary_path, index=False)
print(f"\nSaved duration summary: Excel_Results/{model_name}_individual_track_syllable_durations.xlsx")

# Display summary
print("\n" + "="*80)
print("INDIVIDUAL TRACK SYLLABLE DURATION SUMMARY (FRAMES)")
print("="*80)

for _, row in summary_df.iterrows():
    print(f"{row['video_name']} - Track {row['track_number']}:")
    print(f"  Total frames: {row['total_frames']}")
    print(f"  Valid frames: {row['valid_frames']}")
    print(f"  NaN frames: {row['nan_frames']}")
    print(f"  Average syllable duration: {row['average_syllable_duration_frames']:.1f} ± {row['std_syllable_duration_frames']:.1f} frames")
    print(f"  Total syllable bouts: {row['total_syllable_bouts']}")
    print()

print(f"All Excel files saved to: {excel_output_dir}")
# Out:
# Using model: 2025_08_04-15_38_34
# Loaded checkpoint at iteration: 550
# Loading existing results...
# Successfully loaded results for 34 recordings
# Creating individual Excel files and calculating average syllable durations...
# Saved: Excel_Results/top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx (9300 total frames)
# Saved: Excel_Results/top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx (9300 total frames)
# Saved: Excel_Results/top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx (18083 total frames)
# Saved: Excel_Results/top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx (18083 total frames)
# Saved: Excel_Results/top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx (18060 total frames)
# Saved: Excel_Results/top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx (18060 total frames)
# Saved: Excel_Results/top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx (9116 total frames)
# Saved: Excel_Results/top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx (9116 total frames)
# Saved: Excel_Results/top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx (18064 total frames)
# Saved: Excel_Results/top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx (18064 total frames)
# Saved: Excel_Results/top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx (18699 total frames)
# Saved: Excel_Results/top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx (18699 total frames)
# Saved: Excel_Results/top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx (18015 total frames)
# Saved: Excel_Results/top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx (18015 total frames)
# Saved: Excel_Results/top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx (18405 total frames)
# Saved: Excel_Results/top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx (18405 total frames)
# Saved: Excel_Results/top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx (9053 total frames)
# Saved: Excel_Results/top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx (9053 total frames)
# Saved: Excel_Results/top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx (18095 total frames)
# Saved: Excel_Results/top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx (18095 total frames)
# Saved: Excel_Results/top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx (18153 total frames)
# Saved: Excel_Results/top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx (18153 total frames)
# Saved: Excel_Results/top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx (9065 total frames)
# Saved: Excel_Results/top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx (9065 total frames)
# Saved: Excel_Results/top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx (18062 total frames)
# Saved: Excel_Results/top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx (18062 total frames)
# Saved: Excel_Results/top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx (18263 total frames)
# Saved: Excel_Results/top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx (18263 total frames)
# Saved: Excel_Results/top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx (18158 total frames)
# Saved: Excel_Results/top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx (18158 total frames)
# Saved: Excel_Results/top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx (18065 total frames)
# Saved: Excel_Results/top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx (18065 total frames)
# Saved: Excel_Results/top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx (14654 total frames)
# Saved: Excel_Results/top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx (14654 total frames)
#
# Saved duration summary: Excel_Results/2025_08_04-15_38_34_individual_track_syllable_durations.xlsx
#
# ================================================================================
# INDIVIDUAL TRACK SYLLABLE DURATION SUMMARY (FRAMES)
# ================================================================================
# top-RI1_s1_1_p5_2_nRB6_20250622_143958 - Track 1:
#   Total frames: 9300
#   Valid frames: 9300
#   NaN frames: 0
#   Average syllable duration: 5.9 ± 8.0 frames
#   Total syllable bouts: 1569
#
# top-RI1_s1_1_p5_2_nRB6_20250622_143958 - Track 1:
#   Total frames: 9300
#   Valid frames: 9300
#   NaN frames: 0
#   Average syllable duration: 4.8 ± 6.0 frames
#   Total syllable bouts: 1927
#
# top-RI1_s1_2_p5_1_nRB6_20250622_170742 - Track 1:
#   Total frames: 18083
#   Valid frames: 18083
#   NaN frames: 0
#   Average syllable duration: 7.1 ± 13.3 frames
#   Total syllable bouts: 2532
#
# top-RI1_s1_2_p5_1_nRB6_20250622_170742 - Track 1:
#   Total frames: 18083
#   Valid frames: 18083
#   NaN frames: 0
#   Average syllable duration: 6.7 ± 11.8 frames
#   Total syllable bouts: 2710
#
# top-RI1_s2_3_p5_3_nRB3_20250622_104059 - Track 1:
#   Total frames: 18060
#   Valid frames: 18060
#   NaN frames: 0
#   Average syllable duration: 11.1 ± 22.9 frames
#   Total syllable bouts: 1625
#
# top-RI1_s2_3_p5_3_nRB3_20250622_104059 - Track 1:
#   Total frames: 18060
#   Valid frames: 18060
#   NaN frames: 0
#   Average syllable duration: 9.3 ± 16.8 frames
#   Total syllable bouts: 1944
#
# top-RI1_s2_4_p5_4_nRB3_20250622_123424 - Track 1:
#   Total frames: 9116
#   Valid frames: 9116
#   NaN frames: 0
#   Average syllable duration: 6.5 ± 9.8 frames
#   Total syllable bouts: 1410
#
# top-RI1_s2_4_p5_4_nRB3_20250622_123424 - Track 1:
#   Total frames: 9116
#   Valid frames: 9116
#   NaN frames: 0
#   Average syllable duration: 5.3 ± 7.7 frames
#   Total syllable bouts: 1723
#
# top-RI1_s3_6_p5_3_nRB3_20250621_125312 - Track 1:
#   Total frames: 18064
#   Valid frames: 18064
#   NaN frames: 0
#   Average syllable duration: 13.6 ± 25.9 frames
#   Total syllable bouts: 1329
#
# top-RI1_s3_6_p5_3_nRB3_20250621_125312 - Track 1:
#   Total frames: 18064
#   Valid frames: 18064
#   NaN frames: 0
#   Average syllable duration: 8.7 ± 15.4 frames
#   Total syllable bouts: 2068
#
# top-RI1_s4_7_p5_2_nRB3_20250621_150707 - Track 1:
#   Total frames: 18699
#   Valid frames: 18699
#   NaN frames: 0
#   Average syllable duration: 8.4 ± 15.2 frames
#   Total syllable bouts: 2238
#
# top-RI1_s4_7_p5_2_nRB3_20250621_150707 - Track 1:
#   Total frames: 18699
#   Valid frames: 18699
#   NaN frames: 0
#   Average syllable duration: 7.5 ± 9.6 frames
#   Total syllable bouts: 2501
#
# top-RI1_s4_8_p5_1_nRB3_20250621_165214 - Track 1:
#   Total frames: 18015
#   Valid frames: 18015
#   NaN frames: 0
#   Average syllable duration: 7.9 ± 10.9 frames
#   Total syllable bouts: 2268
#
# top-RI1_s4_8_p5_1_nRB3_20250621_165214 - Track 1:
#   Total frames: 18015
#   Valid frames: 18015
#   NaN frames: 0
#   Average syllable duration: 5.7 ± 6.8 frames
#   Total syllable bouts: 3179
#
# top-RI1_s5_13_p5_4_nRB3_20250622_181801 - Track 1:
#   Total frames: 18405
#   Valid frames: 18405
#   NaN frames: 0
#   Average syllable duration: 9.3 ± 15.6 frames
#   Total syllable bouts: 1977
#
# top-RI1_s5_13_p5_4_nRB3_20250622_181801 - Track 1:
#   Total frames: 18405
#   Valid frames: 18405
#   NaN frames: 0
#   Average syllable duration: 7.6 ± 15.0 frames
#   Total syllable bouts: 2430
#
# top-RI2_s1_1_p5_2_nRB6_20250622_150457 - Track 1:
#   Total frames: 9053
#   Valid frames: 9053
#   NaN frames: 0
#   Average syllable duration: 10.6 ± 25.4 frames
#   Total syllable bouts: 856
#
# top-RI2_s1_1_p5_2_nRB6_20250622_150457 - Track 1:
#   Total frames: 9053
#   Valid frames: 9053
#   NaN frames: 0
#   Average syllable duration: 5.1 ± 5.8 frames
#   Total syllable bouts: 1778
#
# top-RI2_s1_2_p5_1_nRB6_20250622_173049 - Track 1:
#   Total frames: 18095
#   Valid frames: 18095
#   NaN frames: 0
#   Average syllable duration: 21.2 ± 62.3 frames
#   Total syllable bouts: 854
#
# top-RI2_s1_2_p5_1_nRB6_20250622_173049 - Track 1:
#   Total frames: 18095
#   Valid frames: 18095
#   NaN frames: 0
#   Average syllable duration: 8.4 ± 12.2 frames
#   Total syllable bouts: 2143
#
# top-RI2_s2_3_p5_3_nRB3_20250622_110216 - Track 1:
#   Total frames: 18153
#   Valid frames: 18153
#   NaN frames: 0
#   Average syllable duration: 14.6 ± 56.7 frames
#   Total syllable bouts: 1243
#
# top-RI2_s2_3_p5_3_nRB3_20250622_110216 - Track 1:
#   Total frames: 18153
#   Valid frames: 18153
#   NaN frames: 0
#   Average syllable duration: 7.2 ± 10.1 frames
#   Total syllable bouts: 2504
#
# top-RI2_s2_4_p5_4_nRB3_20250622_125648 - Track 1:
#   Total frames: 9065
#   Valid frames: 9065
#   NaN frames: 0
#   Average syllable duration: 11.3 ± 29.7 frames
#   Total syllable bouts: 804
#
# top-RI2_s2_4_p5_4_nRB3_20250622_125648 - Track 1:
#   Total frames: 9065
#   Valid frames: 9065
#   NaN frames: 0
#   Average syllable duration: 5.8 ± 10.6 frames
#   Total syllable bouts: 1572
#
# top-RI2_s3_5_p5_4_nRB3_20250621_112618 - Track 1:
#   Total frames: 18062
#   Valid frames: 18062
#   NaN frames: 0
#   Average syllable duration: 15.3 ± 87.1 frames
#   Total syllable bouts: 1180
#
# top-RI2_s3_5_p5_4_nRB3_20250621_112618 - Track 1:
#   Total frames: 18062
#   Valid frames: 18062
#   NaN frames: 0
#   Average syllable duration: 6.3 ± 9.8 frames
#   Total syllable bouts: 2862
#
# top-RI2_s3_6_p_5_3_nRB3_20250621_131158 - Track 1:
#   Total frames: 18263
#   Valid frames: 18263
#   NaN frames: 0
#   Average syllable duration: 10.9 ± 41.2 frames
#   Total syllable bouts: 1679
#
# top-RI2_s3_6_p_5_3_nRB3_20250621_131158 - Track 1:
#   Total frames: 18263
#   Valid frames: 18263
#   NaN frames: 0
#   Average syllable duration: 6.8 ± 10.4 frames
#   Total syllable bouts: 2676
#
# top-RI2_s4_7_p5_2_nRB3_20250621_152519 - Track 1:
#   Total frames: 18158
#   Valid frames: 18158
#   NaN frames: 0
#   Average syllable duration: 8.1 ± 19.7 frames
#   Total syllable bouts: 2251
#
# top-RI2_s4_7_p5_2_nRB3_20250621_152519 - Track 1:
#   Total frames: 18158
#   Valid frames: 18158
#   NaN frames: 0
#   Average syllable duration: 6.3 ± 7.9 frames
#   Total syllable bouts: 2861
#
# top-RI2_s4_8_p5_1_nRB3_20250621_171318 - Track 1:
#   Total frames: 18065
#   Valid frames: 18065
#   NaN frames: 0
#   Average syllable duration: 10.4 ± 36.0 frames
#   Total syllable bouts: 1741
#
# top-RI2_s4_8_p5_1_nRB3_20250621_171318 - Track 1:
#   Total frames: 18065
#   Valid frames: 18065
#   NaN frames: 0
#   Average syllable duration: 6.4 ± 8.9 frames
#   Total syllable bouts: 2839
#
# top-RI2_s5_13_p5_4_nRB3_20250622_184136 - Track 1:
#   Total frames: 14654
#   Valid frames: 14654
#   NaN frames: 0
#   Average syllable duration: 10.3 ± 31.9 frames
#   Total syllable bouts: 1421
#
# top-RI2_s5_13_p5_4_nRB3_20250622_184136 - Track 1:
#   Total frames: 14654
#   Valid frames: 14654
#   NaN frames: 0
#   Average syllable duration: 6.6 ± 9.5 frames
#   Total syllable bouts: 2222
#
# All Excel files saved to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results

# %%
# First, let's see what the actual video keys are
print("Checking all video keys in results:")
for i, video_key in enumerate(results.keys()):
    print(f"{i+1}: {video_key}")
    
print(f"\nTotal number of tracks/videos: {len(results)}")
# Out:
# Checking all video keys in results:
# 1: top-RI1_s1_1_p5_2_nRB6_20250622_143958.1.analysis_track0
# 2: top-RI1_s1_1_p5_2_nRB6_20250622_143958.1.analysis_track1
# 3: top-RI1_s1_2_p5_1_nRB6_20250622_170742.1.analysis_track0
# 4: top-RI1_s1_2_p5_1_nRB6_20250622_170742.1.analysis_track1
# 5: top-RI1_s2_3_p5_3_nRB3_20250622_104059.1.analysis_track0
# 6: top-RI1_s2_3_p5_3_nRB3_20250622_104059.1.analysis_track1
# 7: top-RI1_s2_4_p5_4_nRB3_20250622_123424.1.analysis_track0
# 8: top-RI1_s2_4_p5_4_nRB3_20250622_123424.1.analysis_track1
# 9: top-RI1_s3_6_p5_3_nRB3_20250621_125312.1.analysis_track0
# 10: top-RI1_s3_6_p5_3_nRB3_20250621_125312.1.analysis_track1
# 11: top-RI1_s4_7_p5_2_nRB3_20250621_150707.1.analysis_track0
# 12: top-RI1_s4_7_p5_2_nRB3_20250621_150707.1.analysis_track1
# 13: top-RI1_s4_8_p5_1_nRB3_20250621_165214.1.analysis_track0
# 14: top-RI1_s4_8_p5_1_nRB3_20250621_165214.1.analysis_track1
# 15: top-RI1_s5_13_p5_4_nRB3_20250622_181801.1.analysis_track0
# 16: top-RI1_s5_13_p5_4_nRB3_20250622_181801.1.analysis_track1
# 17: top-RI2_s1_1_p5_2_nRB6_20250622_150457.1.analysis_track0
# 18: top-RI2_s1_1_p5_2_nRB6_20250622_150457.1.analysis_track1
# 19: top-RI2_s1_2_p5_1_nRB6_20250622_173049.1.analysis_track0
# 20: top-RI2_s1_2_p5_1_nRB6_20250622_173049.1.analysis_track1
# 21: top-RI2_s2_3_p5_3_nRB3_20250622_110216.1.analysis_track0
# 22: top-RI2_s2_3_p5_3_nRB3_20250622_110216.1.analysis_track1
# 23: top-RI2_s2_4_p5_4_nRB3_20250622_125648.1.analysis_track0
# 24: top-RI2_s2_4_p5_4_nRB3_20250622_125648.1.analysis_track1
# 25: top-RI2_s3_5_p5_4_nRB3_20250621_112618.1.analysis_track0
# 26: top-RI2_s3_5_p5_4_nRB3_20250621_112618.1.analysis_track1
# 27: top-RI2_s3_6_p_5_3_nRB3_20250621_131158.1.analysis_track0
# 28: top-RI2_s3_6_p_5_3_nRB3_20250621_131158.1.analysis_track1
# 29: top-RI2_s4_7_p5_2_nRB3_20250621_152519.1.analysis_track0
# 30: top-RI2_s4_7_p5_2_nRB3_20250621_152519.1.analysis_track1
# 31: top-RI2_s4_8_p5_1_nRB3_20250621_171318.1.analysis_track0
# 32: top-RI2_s4_8_p5_1_nRB3_20250621_171318.1.analysis_track1
# 33: top-RI2_s5_13_p5_4_nRB3_20250622_184136.1.analysis_track0
# 34: top-RI2_s5_13_p5_4_nRB3_20250622_184136.1.analysis_track1
#
# Total number of tracks/videos: 34

# %%
import pandas as pd
import numpy as np
import keypoint_moseq as kpms
import os
import glob

project_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2"
config = lambda: kpms.load_config(project_dir)

excel_output_dir = os.path.join(project_dir, "Excel_Results")
if not os.path.exists(excel_output_dir):
    os.makedirs(excel_output_dir)
    print(f"Created folder: {excel_output_dir}")

model_name = "2025_08_04-15_38_34"
print(f"Using model: {model_name}")

model, data, metadata, current_iter = kpms.load_checkpoint(project_dir, model_name)
print(f"Loaded checkpoint at iteration: {current_iter}")

try:
    results_path = os.path.join(project_dir, model_name, "results.h5")
    if os.path.exists(results_path):
        print("Loading existing results...")
        results = kpms.load_results(project_dir, model_name)
    else:
        print("No existing results found, extracting new results...")
        results = kpms.extract_results(model, metadata, project_dir, model_name)
except:
    print("Loading failed, extracting results with overwrite...")
    results_path = os.path.join(project_dir, model_name, "results.h5")
    if os.path.exists(results_path):
        os.remove(results_path)
    results = kpms.extract_results(model, metadata, project_dir, model_name)

print(f"Successfully loaded results for {len(results)} recordings")

def process_results(results, excel_output_dir, model_name):
    duration_data = []
    
    for video_key, result_data in results.items():
        if 'track0' in video_key.lower():
            track_num = 0
        elif 'track1' in video_key.lower():
            track_num = 1
        else:
            track_num = 0
            
        video_name = video_key.split('\\')[-1].split('.')[0] if '\\' in video_key else video_key.split('.')[0]
        video_name_clean = video_name.replace('_track0', '').replace('_track1', '').replace('track0', '').replace('track1', '')
        
        syllables = result_data['syllable']
        total_frames = len(syllables)
        all_frames = np.arange(total_frames)
        
        frame_data = {
            'frame_number': all_frames,
            'syllable': syllables,
            'video_name': video_name_clean,
            'track_name': video_key,
            'track_number': track_num
        }
        
        df = pd.DataFrame(frame_data)
        
        excel_filename = f"{video_name_clean}_track{track_num}_syllables.xlsx"
        excel_path = os.path.join(excel_output_dir, excel_filename)
        df.to_excel(excel_path, index=False)
        print(f"Saved: Excel_Results/{excel_filename} ({total_frames} total frames)")
        
        valid_mask = ~np.isnan(syllables)
        if np.any(valid_mask):
            clean_syllables = syllables[valid_mask].astype(int)
            
            durations = []
            current_syl = clean_syllables[0]
            start_idx = 0
            
            for i in range(1, len(clean_syllables)):
                if clean_syllables[i] != current_syl:
                    duration = i - start_idx
                    durations.append(duration)
                    current_syl = clean_syllables[i]
                    start_idx = i
            
            final_dur = len(clean_syllables) - start_idx
            durations.append(final_dur)
            
            avg_dur = np.mean(durations)
            std_dur = np.std(durations)
            bout_count = len(durations)
            valid_count = np.sum(valid_mask)
            nan_count = np.sum(~valid_mask)
            
            duration_data.append({
                'video_name': video_name_clean,
                'track_number': track_num,
                'track_name': video_key,
                'total_frames': total_frames,
                'valid_frames': valid_count,
                'nan_frames': nan_count,
                'average_syllable_duration_frames': avg_dur,
                'std_syllable_duration_frames': std_dur,
                'total_syllable_bouts': bout_count
            })
    
    return duration_data

print("Creating Excel files and calculating durations...")
duration_data = process_results(results, excel_output_dir, model_name)

summary_df = pd.DataFrame(duration_data)
summary_path = os.path.join(excel_output_dir, f"{model_name}_track_syllable_durations.xlsx")
summary_df.to_excel(summary_path, index=False)
print(f"\nSaved summary: Excel_Results/{model_name}_track_syllable_durations.xlsx")

print("\n" + "="*60)
print("TRACK SYLLABLE DURATION SUMMARY")
print("="*60)

for _, row in summary_df.iterrows():
    print(f"{row['video_name']} - Track {row['track_number']}:")
    print(f"  Total frames: {row['total_frames']}")
    print(f"  Valid frames: {row['valid_frames']}")
    print(f"  NaN frames: {row['nan_frames']}")
    print(f"  Avg syllable duration: {row['average_syllable_duration_frames']:.1f} ± {row['std_syllable_duration_frames']:.1f} frames")
    print(f"  Total bouts: {row['total_syllable_bouts']}")
    print()

print(f"Files saved to: {excel_output_dir}")
# Out:
# Using model: 2025_08_04-15_38_34
# Loaded checkpoint at iteration: 550
# Loading existing results...
# Successfully loaded results for 34 recordings
# Creating individual Excel files and calculating average syllable durations...
# Saved: Excel_Results/top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx (9300 total frames)
# Saved: Excel_Results/top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx (9300 total frames)
# Saved: Excel_Results/top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx (18083 total frames)
# Saved: Excel_Results/top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx (18083 total frames)
# Saved: Excel_Results/top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx (18060 total frames)
# Saved: Excel_Results/top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx (18060 total frames)
# Saved: Excel_Results/top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx (9116 total frames)
# Saved: Excel_Results/top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx (9116 total frames)
# Saved: Excel_Results/top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx (18064 total frames)
# Saved: Excel_Results/top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx (18064 total frames)
# Saved: Excel_Results/top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx (18699 total frames)
# Saved: Excel_Results/top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx (18699 total frames)
# Saved: Excel_Results/top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx (18015 total frames)
# Saved: Excel_Results/top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx (18015 total frames)
# Saved: Excel_Results/top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx (18405 total frames)
# Saved: Excel_Results/top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx (18405 total frames)
# Saved: Excel_Results/top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx (9053 total frames)
# Saved: Excel_Results/top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx (9053 total frames)
# Saved: Excel_Results/top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx (18095 total frames)
# Saved: Excel_Results/top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx (18095 total frames)
# Saved: Excel_Results/top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx (18153 total frames)
# Saved: Excel_Results/top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx (18153 total frames)
# Saved: Excel_Results/top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx (9065 total frames)
# Saved: Excel_Results/top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx (9065 total frames)
# Saved: Excel_Results/top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx (18062 total frames)
# Saved: Excel_Results/top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx (18062 total frames)
# Saved: Excel_Results/top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx (18263 total frames)
# Saved: Excel_Results/top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx (18263 total frames)
# Saved: Excel_Results/top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx (18158 total frames)
# Saved: Excel_Results/top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx (18158 total frames)
# Saved: Excel_Results/top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx (18065 total frames)
# Saved: Excel_Results/top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx (18065 total frames)
# Saved: Excel_Results/top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx (14654 total frames)
# Saved: Excel_Results/top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx (14654 total frames)
#
# Saved duration summary: Excel_Results/2025_08_04-15_38_34_individual_track_syllable_durations.xlsx
#
# ================================================================================
# INDIVIDUAL TRACK SYLLABLE DURATION SUMMARY (FRAMES)
# ================================================================================
# top-RI1_s1_1_p5_2_nRB6_20250622_143958 - Track 0:
#   Total frames: 9300
#   Valid frames: 9300
#   NaN frames: 0
#   Average syllable duration: 5.9 ± 8.0 frames
#   Total syllable bouts: 1569
#
# top-RI1_s1_1_p5_2_nRB6_20250622_143958 - Track 1:
#   Total frames: 9300
#   Valid frames: 9300
#   NaN frames: 0
#   Average syllable duration: 4.8 ± 6.0 frames
#   Total syllable bouts: 1927
#
# top-RI1_s1_2_p5_1_nRB6_20250622_170742 - Track 0:
#   Total frames: 18083
#   Valid frames: 18083
#   NaN frames: 0
#   Average syllable duration: 7.1 ± 13.3 frames
#   Total syllable bouts: 2532
#
# top-RI1_s1_2_p5_1_nRB6_20250622_170742 - Track 1:
#   Total frames: 18083
#   Valid frames: 18083
#   NaN frames: 0
#   Average syllable duration: 6.7 ± 11.8 frames
#   Total syllable bouts: 2710
#
# top-RI1_s2_3_p5_3_nRB3_20250622_104059 - Track 0:
#   Total frames: 18060
#   Valid frames: 18060
#   NaN frames: 0
#   Average syllable duration: 11.1 ± 22.9 frames
#   Total syllable bouts: 1625
#
# top-RI1_s2_3_p5_3_nRB3_20250622_104059 - Track 1:
#   Total frames: 18060
#   Valid frames: 18060
#   NaN frames: 0
#   Average syllable duration: 9.3 ± 16.8 frames
#   Total syllable bouts: 1944
#
# top-RI1_s2_4_p5_4_nRB3_20250622_123424 - Track 0:
#   Total frames: 9116
#   Valid frames: 9116
#   NaN frames: 0
#   Average syllable duration: 6.5 ± 9.8 frames
#   Total syllable bouts: 1410
#
# top-RI1_s2_4_p5_4_nRB3_20250622_123424 - Track 1:
#   Total frames: 9116
#   Valid frames: 9116
#   NaN frames: 0
#   Average syllable duration: 5.3 ± 7.7 frames
#   Total syllable bouts: 1723
#
# top-RI1_s3_6_p5_3_nRB3_20250621_125312 - Track 0:
#   Total frames: 18064
#   Valid frames: 18064
#   NaN frames: 0
#   Average syllable duration: 13.6 ± 25.9 frames
#   Total syllable bouts: 1329
#
# top-RI1_s3_6_p5_3_nRB3_20250621_125312 - Track 1:
#   Total frames: 18064
#   Valid frames: 18064
#   NaN frames: 0
#   Average syllable duration: 8.7 ± 15.4 frames
#   Total syllable bouts: 2068
#
# top-RI1_s4_7_p5_2_nRB3_20250621_150707 - Track 0:
#   Total frames: 18699
#   Valid frames: 18699
#   NaN frames: 0
#   Average syllable duration: 8.4 ± 15.2 frames
#   Total syllable bouts: 2238
#
# top-RI1_s4_7_p5_2_nRB3_20250621_150707 - Track 1:
#   Total frames: 18699
#   Valid frames: 18699
#   NaN frames: 0
#   Average syllable duration: 7.5 ± 9.6 frames
#   Total syllable bouts: 2501
#
# top-RI1_s4_8_p5_1_nRB3_20250621_165214 - Track 0:
#   Total frames: 18015
#   Valid frames: 18015
#   NaN frames: 0
#   Average syllable duration: 7.9 ± 10.9 frames
#   Total syllable bouts: 2268
#
# top-RI1_s4_8_p5_1_nRB3_20250621_165214 - Track 1:
#   Total frames: 18015
#   Valid frames: 18015
#   NaN frames: 0
#   Average syllable duration: 5.7 ± 6.8 frames
#   Total syllable bouts: 3179
#
# top-RI1_s5_13_p5_4_nRB3_20250622_181801 - Track 0:
#   Total frames: 18405
#   Valid frames: 18405
#   NaN frames: 0
#   Average syllable duration: 9.3 ± 15.6 frames
#   Total syllable bouts: 1977
#
# top-RI1_s5_13_p5_4_nRB3_20250622_181801 - Track 1:
#   Total frames: 18405
#   Valid frames: 18405
#   NaN frames: 0
#   Average syllable duration: 7.6 ± 15.0 frames
#   Total syllable bouts: 2430
#
# top-RI2_s1_1_p5_2_nRB6_20250622_150457 - Track 0:
#   Total frames: 9053
#   Valid frames: 9053
#   NaN frames: 0
#   Average syllable duration: 10.6 ± 25.4 frames
#   Total syllable bouts: 856
#
# top-RI2_s1_1_p5_2_nRB6_20250622_150457 - Track 1:
#   Total frames: 9053
#   Valid frames: 9053
#   NaN frames: 0
#   Average syllable duration: 5.1 ± 5.8 frames
#   Total syllable bouts: 1778
#
# top-RI2_s1_2_p5_1_nRB6_20250622_173049 - Track 0:
#   Total frames: 18095
#   Valid frames: 18095
#   NaN frames: 0
#   Average syllable duration: 21.2 ± 62.3 frames
#   Total syllable bouts: 854
#
# top-RI2_s1_2_p5_1_nRB6_20250622_173049 - Track 1:
#   Total frames: 18095
#   Valid frames: 18095
#   NaN frames: 0
#   Average syllable duration: 8.4 ± 12.2 frames
#   Total syllable bouts: 2143
#
# top-RI2_s2_3_p5_3_nRB3_20250622_110216 - Track 0:
#   Total frames: 18153
#   Valid frames: 18153
#   NaN frames: 0
#   Average syllable duration: 14.6 ± 56.7 frames
#   Total syllable bouts: 1243
#
# top-RI2_s2_3_p5_3_nRB3_20250622_110216 - Track 1:
#   Total frames: 18153
#   Valid frames: 18153
#   NaN frames: 0
#   Average syllable duration: 7.2 ± 10.1 frames
#   Total syllable bouts: 2504
#
# top-RI2_s2_4_p5_4_nRB3_20250622_125648 - Track 0:
#   Total frames: 9065
#   Valid frames: 9065
#   NaN frames: 0
#   Average syllable duration: 11.3 ± 29.7 frames
#   Total syllable bouts: 804
#
# top-RI2_s2_4_p5_4_nRB3_20250622_125648 - Track 1:
#   Total frames: 9065
#   Valid frames: 9065
#   NaN frames: 0
#   Average syllable duration: 5.8 ± 10.6 frames
#   Total syllable bouts: 1572
#
# top-RI2_s3_5_p5_4_nRB3_20250621_112618 - Track 0:
#   Total frames: 18062
#   Valid frames: 18062
#   NaN frames: 0
#   Average syllable duration: 15.3 ± 87.1 frames
#   Total syllable bouts: 1180
#
# top-RI2_s3_5_p5_4_nRB3_20250621_112618 - Track 1:
#   Total frames: 18062
#   Valid frames: 18062
#   NaN frames: 0
#   Average syllable duration: 6.3 ± 9.8 frames
#   Total syllable bouts: 2862
#
# top-RI2_s3_6_p_5_3_nRB3_20250621_131158 - Track 0:
#   Total frames: 18263
#   Valid frames: 18263
#   NaN frames: 0
#   Average syllable duration: 10.9 ± 41.2 frames
#   Total syllable bouts: 1679
#
# top-RI2_s3_6_p_5_3_nRB3_20250621_131158 - Track 1:
#   Total frames: 18263
#   Valid frames: 18263
#   NaN frames: 0
#   Average syllable duration: 6.8 ± 10.4 frames
#   Total syllable bouts: 2676
#
# top-RI2_s4_7_p5_2_nRB3_20250621_152519 - Track 0:
#   Total frames: 18158
#   Valid frames: 18158
#   NaN frames: 0
#   Average syllable duration: 8.1 ± 19.7 frames
#   Total syllable bouts: 2251
#
# top-RI2_s4_7_p5_2_nRB3_20250621_152519 - Track 1:
#   Total frames: 18158
#   Valid frames: 18158
#   NaN frames: 0
#   Average syllable duration: 6.3 ± 7.9 frames
#   Total syllable bouts: 2861
#
# top-RI2_s4_8_p5_1_nRB3_20250621_171318 - Track 0:
#   Total frames: 18065
#   Valid frames: 18065
#   NaN frames: 0
#   Average syllable duration: 10.4 ± 36.0 frames
#   Total syllable bouts: 1741
#
# top-RI2_s4_8_p5_1_nRB3_20250621_171318 - Track 1:
#   Total frames: 18065
#   Valid frames: 18065
#   NaN frames: 0
#   Average syllable duration: 6.4 ± 8.9 frames
#   Total syllable bouts: 2839
#
# top-RI2_s5_13_p5_4_nRB3_20250622_184136 - Track 0:
#   Total frames: 14654
#   Valid frames: 14654
#   NaN frames: 0
#   Average syllable duration: 10.3 ± 31.9 frames
#   Total syllable bouts: 1421
#
# top-RI2_s5_13_p5_4_nRB3_20250622_184136 - Track 1:
#   Total frames: 14654
#   Valid frames: 14654
#   NaN frames: 0
#   Average syllable duration: 6.6 ± 9.5 frames
#   Total syllable bouts: 2222
#
# All Excel files saved to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results

# %%
import keypoint_moseq as kpms

project_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2"
config = kpms.load_config(project_dir)

print("Current config parameters:")
for key, value in config.items():
    print(f"{key}: {value}")
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# Current config parameters:
# bodyparts: ['nose', 'head', 'left_ear', 'right_ear', 'middle', 'left_mid', 'right_mid', 'tail_base']
# use_bodyparts: ['nose', 'right_ear', 'left_ear', 'middle', 'head', 'right_mid', 'left_mid', 'tail_base']
# skeleton: [['nose', 'head'], ['nose', 'left_ear'], ['nose', 'right_ear'], ['head', 'middle'], ['left_ear', 'head'], ['right_ear', 'head'], ['left_mid', 'middle'], ['right_mid', 'middle'], ['head', 'left_mid'], ['head', 'right_mid'], ['middle', 'tail_base'], ['left_mid', 'tail_base'], ['right_mid', 'tail_base']]
# anterior_bodyparts: ['nose']
# posterior_bodyparts: ['tail_base']
# added_noise_level: 0.1
# PCA_fitting_num_frames: 1000000
# conf_threshold: 0.5
# error_estimator: {'intercept': 0.25, 'slope': -0.5}
# obs_hypparams: {'nu_s': 5, 'nu_sigma': 100000.0, 'sigmasq_0': 0.1, 'sigmasq_C': 0.1}
# ar_hypparams: {'K_0_scale': 10.0, 'S_0_scale': 0.01, 'latent_dim': 4, 'nlags': 3}
# trans_hypparams: {'alpha': 5.7, 'gamma': 1000.0, 'kappa': 1000000.0, 'num_states': 100}
# cen_hypparams: {'sigmasq_loc': 0.5}
# recording_name_suffix:
# verbose: False
# conf_pseudocount: 0.001
# video_dir: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2
# keypoint_colormap: autumn
# whiten: True
# fix_heading: False
# fps: 30
# anterior_idxs: [0]
# posterior_idxs: [7]

# %%
import os
import h5py
import numpy as np

# Updated file path
resp_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"

# List all files in the directory
print("Files in Resp_h5 directory:")
for file in os.listdir(resp_path):
    print(f"  {file}")

# Find h5 files specifically
h5_files = [f for f in os.listdir(resp_path) if f.endswith('.h5')]
print(f"\nFound {len(h5_files)} h5 files:")
for h5_file in h5_files:
    print(f"  {h5_file}")

# Examine structure of first h5 file
if h5_files:
    first_file = os.path.join(resp_path, h5_files[0])
    print(f"\nExamining structure of: {h5_files[0]}")
    
    with h5py.File(first_file, 'r') as f:
        def print_structure(name, obj):
            indent = "  " * name.count('/')
            if hasattr(obj, 'shape'):
                print(f"{indent}{name}: {obj.shape} {obj.dtype}")
            else:
                print(f"{indent}{name}: Group")
        
        f.visititems(print_structure)
        
        # Also print top-level keys
        print(f"\nTop-level keys: {list(f.keys())}")

# Function to examine a specific h5 file in detail
def examine_resp_file(filepath):
    """Detailed examination of respiratory h5 file"""
    print(f"\n=== Examining {os.path.basename(filepath)} ===")
    
    with h5py.File(filepath, 'r') as f:
        for key in f.keys():
            data = f[key]
            if hasattr(data, 'shape'):
                print(f"{key}:")
                print(f"  Shape: {data.shape}")
                print(f"  Dtype: {data.dtype}")
                if len(data.shape) == 1 and data.shape[0] < 20:
                    print(f"  Values: {data[:]}")
                elif len(data.shape) == 1:
                    print(f"  First 10 values: {data[:10]}")
                    print(f"  Last 10 values: {data[-10:]}")
                    print(f"  Min/Max: {np.min(data[:])} / {np.max(data[:])}")

# Run detailed examination on first file
if h5_files:
    examine_resp_file(os.path.join(resp_path, h5_files[0]))
# Out:
# Files in Resp_h5 directory:
#   RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
#   RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
#   RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
#   RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
#   RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
#   RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
#   RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
#   RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
#   RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
#   RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
#   RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
#   RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
#   RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
#   RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
#   RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
#   RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
#   RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
#   RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
#
# Found 18 h5 files:
#   RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
#   RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
#   RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
#   RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
#   RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
#   RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
#   RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
#   RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
#   RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
#   RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
#   RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
#   RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
#   RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
#   RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
#   RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
#   RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
#   RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
#   RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
#
# Examining structure of: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# ekg: (12425270,) int16
# ekg_metadata: Group
# metadata: Group
# resp: (12425270, 1) float64
# resp_metadata: Group
#
# Top-level keys: ['ekg', 'ekg_metadata', 'metadata', 'resp', 'resp_metadata']
#
# === Examining RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5 ===
# ekg:
#   Shape: (12425270,)
#   Dtype: int16
#   First 10 values: [1332 1411 1459 1483 1539 1503 1403 1255 1171 1171]
#   Last 10 values: [17239 17210 17205 17164 17127 17114 17169 17128 17103 17102]
#   Min/Max: -24747 / 29392
# resp:
#   Shape: (12425270, 1)
#   Dtype: float64

# %%
import os
import h5py
import numpy as np
from scipy import signal
import pandas as pd
import matplotlib.pyplot as plt

def process_respiratory_file(file_path, original_fs=20000, target_fs=100):
    """
    Process a single respiratory h5 file: filter and calculate breathing rate
    """
    print(f"Processing: {os.path.basename(file_path)}")
    
    # Load respiratory data
    with h5py.File(file_path, 'r') as f:
        resp_data = f['resp'][:].flatten()  # Remove extra dimension
    
    print(f"  Original data: {len(resp_data)} samples at {original_fs}Hz")
    print(f"  Duration: {len(resp_data)/original_fs:.2f} seconds")
    
    # Design low-pass filter for 100Hz cutoff
    nyquist = original_fs / 2
    cutoff = target_fs / 2  
    b, a = signal.butter(5, cutoff/nyquist, 'low')
    
    # Filter the data
    filtered_resp = signal.filtfilt(b, a, resp_data)
    
    # Downsample to 100Hz
    downsample_factor = original_fs // target_fs  # 200
    downsampled_resp = filtered_resp[::downsample_factor]
    
    print(f"  Filtered data: {len(downsampled_resp)} samples at {target_fs}Hz")
    
    # Calculate breathing rate (1/IBI)
    breathing_rate, breath_times = calculate_breathing_rate(downsampled_resp, target_fs)
    
    return downsampled_resp, breathing_rate, breath_times

def calculate_breathing_rate(resp_signal, fs=100):
    """
    Calculate 1/IBI (breathing rate) from respiratory signal
    """
    # Normalize signal for peak detection
    normalized_resp = (resp_signal - np.mean(resp_signal)) / np.std(resp_signal)
    
    # Find breathing peaks (inspiration peaks)
    # Adjust parameters based on your breathing rate expectations
    min_distance = fs // 4  # Minimum 0.25s between breaths (240 BPM max)
    prominence = 0.5  # Adjust based on signal quality
    
    peaks, properties = signal.find_peaks(normalized_resp, 
                                        distance=min_distance,
                                        prominence=prominence,
                                        height=0.1)
    
    print(f"  Found {len(peaks)} breathing peaks")
    
    if len(peaks) < 2:
        print("  Warning: Not enough peaks found for IBI calculation")
        return np.array([]), np.array([])
    
    # Calculate inter-breath intervals (IBI)
    ibi_samples = np.diff(peaks)  # IBI in samples
    ibi_seconds = ibi_samples / fs  # IBI in seconds
    breathing_rate = 1 / ibi_seconds  # 1/IBI (breaths per second)
    
    # Convert to breaths per minute for interpretation
    breaths_per_minute = breathing_rate * 60
    
    # Timestamps for breathing rate (at each breath after the first)
    breath_times = peaks[1:] / fs
    
    print(f"  Mean breathing rate: {np.mean(breaths_per_minute):.1f} breaths/min")
    print(f"  Range: {np.min(breaths_per_minute):.1f} - {np.max(breaths_per_minute):.1f} breaths/min")
    
    return breathing_rate, breath_times

def process_all_respiratory_files(resp_dir):
    """
    Process all respiratory h5 files in directory
    """
    h5_files = [f for f in os.listdir(resp_dir) if f.endswith('.h5')]
    
    results = {}
    
    for h5_file in h5_files:
        file_path = os.path.join(resp_dir, h5_file)
        
        try:
            filtered_resp, breathing_rate, breath_times = process_respiratory_file(file_path)
            
            results[h5_file] = {
                'filtered_signal': filtered_resp,
                'breathing_rate': breathing_rate,
                'breath_times': breath_times,
                'file_path': file_path
            }
        except Exception as e:
            print(f"Error processing {h5_file}: {e}")
    
    return results

# Main processing
resp_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
respiratory_data = process_all_respiratory_files(resp_path)
# Out:
# Processing: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
#   Original data: 12425270 samples at 20000Hz
#   Duration: 621.26 seconds
#   Filtered data: 62127 samples at 100Hz
#   Found 1586 breathing peaks
#   Mean breathing rate: 167.6 breaths/min
#   Range: 29.1 - 240.0 breaths/min
# Processing: RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
#   Original data: 12089585 samples at 20000Hz
#   Duration: 604.48 seconds
#   Filtered data: 60448 samples at 100Hz
#   Found 1516 breathing peaks
#   Mean breathing rate: 167.0 breaths/min
#   Range: 10.7 - 240.0 breaths/min
# Processing: RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
#   Original data: 12058916 samples at 20000Hz
#   Duration: 602.95 seconds
#   Filtered data: 60295 samples at 100Hz
#   Found 1439 breathing peaks
#   Mean breathing rate: 165.8 breaths/min
#   Range: 2.7 - 240.0 breaths/min
# Processing: RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
#   Original data: 12181909 samples at 20000Hz
#   Duration: 609.10 seconds
#   Filtered data: 60910 samples at 100Hz
#   Found 1656 breathing peaks
#   Mean breathing rate: 173.1 breaths/min
#   Range: 41.7 - 240.0 breaths/min
# Processing: RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
#   Original data: 12474615 samples at 20000Hz
#   Duration: 623.73 seconds
#   Filtered data: 62374 samples at 100Hz
#   Found 1534 breathing peaks
#   Mean breathing rate: 163.2 breaths/min
#   Range: 42.0 - 240.0 breaths/min
# Processing: RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
#   Original data: 12065446 samples at 20000Hz
#   Duration: 603.27 seconds
#   Filtered data: 60328 samples at 100Hz
#   Found 1509 breathing peaks
#   Mean breathing rate: 164.5 breaths/min
#   Range: 11.2 - 240.0 breaths/min
# Processing: RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
#   Original data: 12583112 samples at 20000Hz
#   Duration: 629.16 seconds
#   Filtered data: 62916 samples at 100Hz
#   Found 1624 breathing peaks
#   Mean breathing rate: 166.7 breaths/min
#   Range: 29.1 - 240.0 breaths/min
# Processing: RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
#   Original data: 12096714 samples at 20000Hz
#   Duration: 604.84 seconds
#   Filtered data: 60484 samples at 100Hz
#   Found 1548 breathing peaks
#   Mean breathing rate: 170.1 breaths/min
#   Range: 5.7 - 240.0 breaths/min
# Processing: RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
#   Original data: 12301849 samples at 20000Hz
#   Duration: 615.09 seconds
#   Filtered data: 61510 samples at 100Hz
#   Found 72 breathing peaks
#   Mean breathing rate: 87.9 breaths/min
#   Range: 0.3 - 240.0 breaths/min
# Processing: RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
#   Original data: 12095837 samples at 20000Hz
#   Duration: 604.79 seconds
#   Filtered data: 60480 samples at 100Hz
#   Found 1583 breathing peaks
#   Mean breathing rate: 168.7 breaths/min
#   Range: 39.2 - 240.0 breaths/min
# Processing: RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
#   Original data: 12085347 samples at 20000Hz
#   Duration: 604.27 seconds
#   Filtered data: 60427 samples at 100Hz
#   Found 1390 breathing peaks
#   Mean breathing rate: 165.9 breaths/min
#   Range: 1.6 - 240.0 breaths/min
# Processing: RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
#   Original data: 12184065 samples at 20000Hz
#   Duration: 609.20 seconds
#   Filtered data: 60921 samples at 100Hz
#   Found 1443 breathing peaks
#   Mean breathing rate: 167.0 breaths/min
#   Range: 1.2 - 240.0 breaths/min
# Processing: RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
#   Original data: 12108968 samples at 20000Hz
#   Duration: 605.45 seconds
#   Filtered data: 60545 samples at 100Hz
#   Found 1306 breathing peaks
#   Mean breathing rate: 163.5 breaths/min
#   Range: 1.6 - 240.0 breaths/min
# Processing: RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
#   Original data: 4266732 samples at 20000Hz
#   Duration: 213.34 seconds
#   Filtered data: 21334 samples at 100Hz
#   Found 556 breathing peaks
#   Mean breathing rate: 168.6 breaths/min
#   Range: 69.0 - 240.0 breaths/min
# Processing: RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
#   Original data: 12200094 samples at 20000Hz
#   Duration: 610.00 seconds
#   Filtered data: 61001 samples at 100Hz
#   Found 1502 breathing peaks
#   Mean breathing rate: 161.2 breaths/min
#   Range: 29.4 - 240.0 breaths/min
# Processing: RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
#   Original data: 12129332 samples at 20000Hz
#   Duration: 606.47 seconds
#   Filtered data: 60647 samples at 100Hz
#   Found 1559 breathing peaks
#   Mean breathing rate: 166.5 breaths/min
#   Range: 43.5 - 240.0 breaths/min
# Processing: RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
#   Original data: 12064729 samples at 20000Hz
#   Duration: 603.24 seconds
#   Filtered data: 60324 samples at 100Hz
#   Found 1494 breathing peaks
#   Mean breathing rate: 160.0 breaths/min
#   Range: 46.2 - 240.0 breaths/min
# Processing: RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
#   Original data: 9780589 samples at 20000Hz
#   Duration: 489.03 seconds
#   Filtered data: 48903 samples at 100Hz
#   Found 808 breathing peaks
#   Mean breathing rate: 145.5 breaths/min
#   Range: 4.2 - 240.0 breaths/min

# %%
resp

# %%
import os
import h5py
import numpy as np
import pandas as pd
from scipy import signal
import matplotlib.pyplot as plt
from glob import glob

def process_respiratory_file(file_path, original_fs=20000, target_fs=100):
    """Process respiratory h5 file and return filtered data + breathing rate"""
    print(f"Processing: {os.path.basename(file_path)}")
    
    with h5py.File(file_path, 'r') as f:
        resp_data = f['resp'][:].flatten()
    
    # Filter and downsample
    nyquist = original_fs / 2
    cutoff = target_fs / 2
    b, a = signal.butter(5, cutoff/nyquist, 'low')
    filtered_resp = signal.filtfilt(b, a, resp_data)
    downsampled_resp = filtered_resp[::original_fs//target_fs]
    
    # Calculate breathing rate
    breathing_rate, breath_times = calculate_breathing_rate(downsampled_resp, target_fs)
    
    # Create time vector for full signal
    time_vector = np.arange(len(downsampled_resp)) / target_fs
    
    return {
        'filtered_signal': downsampled_resp,
        'time_vector': time_vector,
        'breathing_rate': breathing_rate,
        'breath_times': breath_times,
        'sampling_rate': target_fs
    }

def calculate_breathing_rate(resp_signal, fs=100):
    """Calculate 1/IBI from respiratory signal"""
    normalized_resp = (resp_signal - np.mean(resp_signal)) / np.std(resp_signal)
    
    peaks, _ = signal.find_peaks(normalized_resp, 
                                distance=fs//4,
                                prominence=0.5,
                                height=0.1)
    
    if len(peaks) < 2:
        return np.array([]), np.array([])
    
    ibi_seconds = np.diff(peaks) / fs
    breathing_rate = 1 / ibi_seconds
    breath_times = peaks[1:] / fs
    
    return breathing_rate, breath_times

def overlay_resp_on_syllables(resp_data, excel_file_path):
    """Overlay respiratory data on MoSeq syllables from Excel"""
    
    # Load syllable data from Excel
    try:
        syllable_df = pd.read_excel(excel_file_path)
        print(f"Loaded syllable data: {syllable_df.shape}")
        print(f"Columns: {list(syllable_df.columns)}")
    except Exception as e:
        print(f"Error loading Excel file: {e}")
        return None
    
    # Interpolate respiratory signal to match syllable timestamps
    if 'time' in syllable_df.columns or 'timestamp' in syllable_df.columns:
        time_col = 'time' if 'time' in syllable_df.columns else 'timestamp'
        syllable_times = syllable_df[time_col].values
        
        # Interpolate filtered respiratory signal
        interp_resp = np.interp(syllable_times, resp_data['time_vector'], 
                               resp_data['filtered_signal'])
        
        # Interpolate breathing rate if available
        if len(resp_data['breathing_rate']) > 0:
            interp_breathing_rate = np.interp(syllable_times, 
                                            resp_data['breath_times'], 
                                            resp_data['breathing_rate'])
        else:
            interp_breathing_rate = np.nan * np.ones_like(syllable_times)
        
        # Add respiratory data to syllable DataFrame
        syllable_df['resp_signal'] = interp_resp
        syllable_df['breathing_rate_1_over_IBI'] = interp_breathing_rate
        syllable_df['breathing_rate_BPM'] = interp_breathing_rate * 60
        
        return syllable_df
    
    else:
        print("No time column found in Excel file")
        return None

def process_matching_files(resp_dir, excel_dir):
    """Process respiratory h5 files and match with Excel syllable files"""
    
    # Get all h5 files
    h5_files = glob(os.path.join(resp_dir, "*.h5"))
    excel_files = glob(os.path.join(excel_dir, "*.xlsx")) + glob(os.path.join(excel_dir, "*.xls"))
    
    results = {}
    
    for h5_file in h5_files:
        h5_basename = os.path.basename(h5_file).replace('.h5', '')
        print(f"\n=== Processing {h5_basename} ===")
        
        # Process respiratory data
        resp_data = process_respiratory_file(h5_file)
        
        # Find matching Excel file (you may need to adjust matching logic)
        matching_excel = None
        for excel_file in excel_files:
            excel_basename = os.path.basename(excel_file).replace('.xlsx', '').replace('.xls', '')
            # Adjust this matching logic based on your file naming
            if h5_basename in excel_basename or excel_basename in h5_basename:
                matching_excel = excel_file
                break
        
        if matching_excel:
            print(f"Found matching Excel: {os.path.basename(matching_excel)}")
            overlaid_data = overlay_resp_on_syllables(resp_data, matching_excel)
            
            if overlaid_data is not None:
                # Save combined data
                output_file = f"{h5_basename}_with_respiration.xlsx"
                overlaid_data.to_excel(output_file, index=False)
                print(f"Saved: {output_file}")
                
                results[h5_basename] = overlaid_data
        else:
            print(f"No matching Excel file found for {h5_basename}")
    
    return results

# Usage
resp_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
excel_path = r"path\to\your\excel\files"  # Update this path!

# Process all files
combined_data = process_matching_files(resp_path, excel_path)
# Out:
# === Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged ===
# Processing: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# No matching Excel file found for RI1_s1_1_p5_2_nRB6_20250622_143958_merged
#
# === Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged ===
# Processing: RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
# No matching Excel file found for RI1_s1_2_p5_1_nRB6_20250622_170742_merged
#
# === Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged ===
# Processing: RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
# No matching Excel file found for RI1_s2_3_p5_3_nRB3_20250622_104059_merged
#
# === Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged ===
# Processing: RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
# No matching Excel file found for RI1_s2_4_p5_4_nRB3_20250622_123424_merged
#
# === Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged ===
# Processing: RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
# No matching Excel file found for RI1_s3_5_p5_4_nRB3_20250621_105014_merged
#
# === Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged ===
# Processing: RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
# No matching Excel file found for RI1_s3_6_p5_3_nRB3_20250621_125312_merged
#
# === Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged ===
# Processing: RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
# No matching Excel file found for RI1_s4_7_p5_2_nRB3_20250621_150707_merged
#
# === Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged ===
# Processing: RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
# No matching Excel file found for RI1_s4_8_p5_1_nRB3_20250621_165214_merged
#
# === Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged ===
# Processing: RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
# No matching Excel file found for RI1_s5_13_p5_4_nRB3_20250622_181801_merged
#
# === Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged ===
# Processing: RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
# No matching Excel file found for RI2_s1_1_p5_2_nRB6_20250622_150457_merged
#
# === Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged ===
# Processing: RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
# No matching Excel file found for RI2_s1_2_p5_1_nRB6_20250622_173049_merged
#
# === Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged ===
# Processing: RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
# No matching Excel file found for RI2_s2_3_p5_3_nRB3_20250622_110216_merged
#
# === Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged ===
# Processing: RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
# No matching Excel file found for RI2_s2_4_p5_4_nRB3_20250622_125648_merged
#
# === Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged ===
# Processing: RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
# No matching Excel file found for RI2_s3_5_p5_4_nRB3_20250621_112618_merged
#
# === Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged ===
# Processing: RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
# No matching Excel file found for RI2_s3_6_p5_3_nRB3_20250621_131158_merged
#
# === Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged ===
# Processing: RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
# No matching Excel file found for RI2_s4_7_p5_2_nRB3_20250621_152519_merged
#
# === Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged ===
# Processing: RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
# No matching Excel file found for RI2_s4_8_p5_1_nRB3_20250621_171318_merged
#
# === Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged ===
# Processing: RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
# No matching Excel file found for RI2_s5_13_p5_4_nRB3_20250622_184136_merged

# %%
import os
import h5py
import numpy as np
import pandas as pd
from scipy import signal
import matplotlib.pyplot as plt
from glob import glob

def process_respiratory_file(file_path, original_fs=20000, target_fs=100):
    """Process respiratory h5 file and return filtered data + breathing rate"""
    print(f"Processing: {os.path.basename(file_path)}")
    
    with h5py.File(file_path, 'r') as f:
        resp_data = f['resp'][:].flatten()
    
    # Filter and downsample
    nyquist = original_fs / 2
    cutoff = target_fs / 2
    b, a = signal.butter(5, cutoff/nyquist, 'low')
    filtered_resp = signal.filtfilt(b, a, resp_data)
    downsampled_resp = filtered_resp[::original_fs//target_fs]
    
    # Calculate breathing rate
    breathing_rate, breath_times = calculate_breathing_rate(downsampled_resp, target_fs)
    
    # Create time vector for full signal
    time_vector = np.arange(len(downsampled_resp)) / target_fs
    
    return {
        'filtered_signal': downsampled_resp,
        'time_vector': time_vector,
        'breathing_rate': breathing_rate,
        'breath_times': breath_times,
        'sampling_rate': target_fs
    }

def calculate_breathing_rate(resp_signal, fs=100):
    """Calculate 1/IBI from respiratory signal"""
    normalized_resp = (resp_signal - np.mean(resp_signal)) / np.std(resp_signal)
    
    peaks, _ = signal.find_peaks(normalized_resp, 
                                distance=fs//4,
                                prominence=0.5,
                                height=0.1)
    
    if len(peaks) < 2:
        return np.array([]), np.array([])
    
    ibi_seconds = np.diff(peaks) / fs
    breathing_rate = 1 / ibi_seconds
    breath_times = peaks[1:] / fs
    
    print(f"  Found {len(peaks)} breathing peaks")
    print(f"  Mean breathing rate: {np.mean(breathing_rate*60):.1f} BPM")
    
    return breathing_rate, breath_times

def overlay_resp_on_syllables(resp_data, excel_file_path):
    """Overlay respiratory data on MoSeq syllables from Excel"""
    
    # Load syllable data from Excel
    try:
        syllable_df = pd.read_excel(excel_file_path)
        print(f"  Loaded syllable data: {syllable_df.shape}")
        print(f"  Columns: {list(syllable_df.columns)}")
    except Exception as e:
        print(f"  Error loading Excel file: {e}")
        return None
    
    # Find time column (adjust based on your Excel structure)
    time_cols = ['time', 'timestamp', 'Time', 'frame_time', 'seconds']
    time_col = None
    for col in time_cols:
        if col in syllable_df.columns:
            time_col = col
            break
    
    if time_col is None:
        print(f"  No time column found. Available columns: {list(syllable_df.columns)}")
        return None
    
    syllable_times = syllable_df[time_col].values
    print(f"  Time range: {syllable_times.min():.2f} - {syllable_times.max():.2f} seconds")
    
    # Interpolate filtered respiratory signal
    interp_resp = np.interp(syllable_times, resp_data['time_vector'], 
                           resp_data['filtered_signal'])
    
    # Interpolate breathing rate if available
    if len(resp_data['breathing_rate']) > 0:
        interp_breathing_rate = np.interp(syllable_times, 
                                        resp_data['breath_times'], 
                                        resp_data['breathing_rate'])
    else:
        interp_breathing_rate = np.nan * np.ones_like(syllable_times)
    
    # Add respiratory data to syllable DataFrame
    syllable_df['resp_signal_100hz'] = interp_resp
    syllable_df['breathing_rate_1_over_IBI'] = interp_breathing_rate
    syllable_df['breathing_rate_BPM'] = interp_breathing_rate * 60
    
    return syllable_df

def match_files_by_name(h5_basename, excel_files):
    """Match h5 file with Excel file based on filename patterns"""
    
    # Extract key identifiers from h5 filename
    # e.g., RI1_s1_1_p5_2_nRB6_20250622_143958_merged -> look for RI1_s1_1
    parts = h5_basename.split('_')
    if len(parts) >= 3:
        session_id = '_'.join(parts[:3])  # e.g., "RI1_s1_1"
    else:
        session_id = h5_basename
    
    print(f"  Looking for Excel files containing: '{session_id}'")
    
    # Find matching Excel files
    matches = []
    for excel_file in excel_files:
        excel_basename = os.path.basename(excel_file).replace('.xlsx', '').replace('.xls', '')
        if session_id in excel_basename:
            matches.append(excel_file)
    
    return matches

def process_matching_files(resp_dir, excel_dir):
    """Process respiratory h5 files and match with Excel syllable files"""
    
    # Get all files
    h5_files = glob(os.path.join(resp_dir, "*.h5"))
    excel_files = glob(os.path.join(excel_dir, "*.xlsx")) + glob(os.path.join(excel_dir, "*.xls"))
    
    print(f"Found {len(h5_files)} h5 files and {len(excel_files)} Excel files")
    print("Excel files:")
    for excel in excel_files[:5]:
        print(f"  {os.path.basename(excel)}")
    
    results = {}
    
    for h5_file in h5_files:
        h5_basename = os.path.basename(h5_file).replace('.h5', '')
        print(f"\n=== Processing {h5_basename} ===")
        
        # Process respiratory data
        resp_data = process_respiratory_file(h5_file)
        
        # Find matching Excel files
        matching_excel_files = match_files_by_name(h5_basename, excel_files)
        
        if matching_excel_files:
            for excel_file in matching_excel_files:
                print(f"  Matching with: {os.path.basename(excel_file)}")
                overlaid_data = overlay_resp_on_syllables(resp_data, excel_file)
                
                if overlaid_data is not None:
                    # Create output filename
                    excel_basename = os.path.basename(excel_file).replace('.xlsx', '').replace('.xls', '')
                    output_file = f"{excel_basename}_with_respiration.xlsx"
                    
                    overlaid_data.to_excel(output_file, index=False)
                    print(f"  Saved: {output_file}")
                    
                    results[f"{h5_basename}_{excel_basename}"] = overlaid_data
        else:
            print(f"  No matching Excel file found")
    
    return results

# Updated paths
resp_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"

# Process all files
combined_data = process_matching_files(resp_path, excel_path)
# Out:
# Found 18 h5 files and 42 Excel files
# Excel files:
#   2025_08_04-15_38_34_individual_track_syllable_durations.xlsx
#   2025_08_04-15_38_34_overall_top_20_syllable_half_second_bout_percentages.xlsx
#   2025_08_04-15_38_34_overall_top_20_syllable_long_bout_percentages.xlsx
#   2025_08_04-15_38_34_overall_top_syllable_long_bout_percentages.xlsx
#   2025_08_04-15_38_34_per_video_top_20_syllable_half_second_bout_percentages.xlsx
#
# === Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged ===
# Processing: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
#   Found 1586 breathing peaks
#   Mean breathing rate: 167.6 BPM
#   Looking for Excel files containing: 'RI1_s1_1'
#   Matching with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
#   Loaded syllable data: (9300, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx
#   Loaded syllable data: (9300, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged ===
# Processing: RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
#   Found 1516 breathing peaks
#   Mean breathing rate: 167.0 BPM
#   Looking for Excel files containing: 'RI1_s1_2'
#   Matching with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
#   Loaded syllable data: (18083, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx
#   Loaded syllable data: (18083, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged ===
# Processing: RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
#   Found 1439 breathing peaks
#   Mean breathing rate: 165.8 BPM
#   Looking for Excel files containing: 'RI1_s2_3'
#   Matching with: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
#   Loaded syllable data: (18060, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx
#   Loaded syllable data: (18060, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged ===
# Processing: RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
#   Found 1656 breathing peaks
#   Mean breathing rate: 173.1 BPM
#   Looking for Excel files containing: 'RI1_s2_4'
#   Matching with: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
#   Loaded syllable data: (9116, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx
#   Loaded syllable data: (9116, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged ===
# Processing: RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
#   Found 1534 breathing peaks
#   Mean breathing rate: 163.2 BPM
#   Looking for Excel files containing: 'RI1_s3_5'
#   No matching Excel file found
#
# === Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged ===
# Processing: RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
#   Found 1509 breathing peaks
#   Mean breathing rate: 164.5 BPM
#   Looking for Excel files containing: 'RI1_s3_6'
#   Matching with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
#   Loaded syllable data: (18064, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx
#   Loaded syllable data: (18064, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged ===
# Processing: RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
#   Found 1624 breathing peaks
#   Mean breathing rate: 166.7 BPM
#   Looking for Excel files containing: 'RI1_s4_7'
#   Matching with: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
#   Loaded syllable data: (18699, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx
#   Loaded syllable data: (18699, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged ===
# Processing: RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
#   Found 1548 breathing peaks
#   Mean breathing rate: 170.1 BPM
#   Looking for Excel files containing: 'RI1_s4_8'
#   Matching with: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
#   Loaded syllable data: (18015, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx
#   Loaded syllable data: (18015, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged ===
# Processing: RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
#   Found 72 breathing peaks
#   Mean breathing rate: 87.9 BPM
#   Looking for Excel files containing: 'RI1_s5_13'
#   Matching with: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
#   Loaded syllable data: (18405, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx
#   Loaded syllable data: (18405, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged ===
# Processing: RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
#   Found 1583 breathing peaks
#   Mean breathing rate: 168.7 BPM
#   Looking for Excel files containing: 'RI2_s1_1'
#   Matching with: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
#   Loaded syllable data: (9053, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx
#   Loaded syllable data: (9053, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged ===
# Processing: RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
#   Found 1390 breathing peaks
#   Mean breathing rate: 165.9 BPM
#   Looking for Excel files containing: 'RI2_s1_2'
#   Matching with: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
#   Loaded syllable data: (18095, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx
#   Loaded syllable data: (18095, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged ===
# Processing: RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
#   Found 1443 breathing peaks
#   Mean breathing rate: 167.0 BPM
#   Looking for Excel files containing: 'RI2_s2_3'
#   Matching with: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
#   Loaded syllable data: (18153, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx
#   Loaded syllable data: (18153, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged ===
# Processing: RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
#   Found 1306 breathing peaks
#   Mean breathing rate: 163.5 BPM
#   Looking for Excel files containing: 'RI2_s2_4'
#   Matching with: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
#   Loaded syllable data: (9065, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx
#   Loaded syllable data: (9065, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged ===
# Processing: RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
#   Found 556 breathing peaks
#   Mean breathing rate: 168.6 BPM
#   Looking for Excel files containing: 'RI2_s3_5'
#   Matching with: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
#   Loaded syllable data: (18062, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx
#   Loaded syllable data: (18062, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged ===
# Processing: RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
#   Found 1502 breathing peaks
#   Mean breathing rate: 161.2 BPM
#   Looking for Excel files containing: 'RI2_s3_6'
#   Matching with: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
#   Loaded syllable data: (18263, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx
#   Loaded syllable data: (18263, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged ===
# Processing: RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
#   Found 1559 breathing peaks
#   Mean breathing rate: 166.5 BPM
#   Looking for Excel files containing: 'RI2_s4_7'
#   Matching with: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
#   Loaded syllable data: (18158, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx
#   Loaded syllable data: (18158, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged ===
# Processing: RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
#   Found 1494 breathing peaks
#   Mean breathing rate: 160.0 BPM
#   Looking for Excel files containing: 'RI2_s4_8'
#   Matching with: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
#   Loaded syllable data: (18065, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx
#   Loaded syllable data: (18065, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#
# === Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged ===
# Processing: RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
#   Found 808 breathing peaks
#   Mean breathing rate: 145.5 BPM
#   Looking for Excel files containing: 'RI2_s5_13'
#   Matching with: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
#   Loaded syllable data: (14654, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   Matching with: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx
#   Loaded syllable data: (14654, 5)
#   Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
#   No time column found. Available columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']

# %%
def get_fps_for_file(filename):
    """Get the correct FPS based on filename"""
    fps_map = {
        "RI1_s1_1": 15,
        "RI1_s2_3": 15, 
        "RI1_s3_6": 29,
        "RI2_s1_1": 15,
        "RI2_s2_4": 15
    }
    
    # Check each pattern in the filename
    for pattern, fps in fps_map.items():
        if pattern in filename:
            return fps
    
    return 30  # Default FPS

def overlay_resp_on_syllables_adaptive_fps(resp_data, excel_file_path):
    """Overlay respiratory data with adaptive FPS detection"""
    
    # Load syllable data
    try:
        syllable_df = pd.read_excel(excel_file_path)
        print(f"  Loaded syllable data: {syllable_df.shape}")
    except Exception as e:
        print(f"  Error loading Excel file: {e}")
        return None
    
    # Determine FPS from filename
    excel_basename = os.path.basename(excel_file_path)
    video_fps = get_fps_for_file(excel_basename)
    print(f"  Using {video_fps} FPS for this file")
    
    # Convert frame numbers to time
    if 'frame_number' in syllable_df.columns:
        syllable_times = syllable_df['frame_number'].values / video_fps
        print(f"  Time range: {syllable_times.min():.2f} - {syllable_times.max():.2f} seconds")
        
        # Add time column
        syllable_df['time_seconds'] = syllable_times
        syllable_df['fps_used'] = video_fps
        
    else:
        print(f"  No frame_number column found")
        return None
    
    # Check timing alignment
    resp_duration = len(resp_data['filtered_signal']) / resp_data['sampling_rate']
    print(f"  Respiratory duration: {resp_duration:.2f}s, Syllable duration: {syllable_times.max():.2f}s")
    
    # Interpolate respiratory data
    interp_resp = np.interp(syllable_times, resp_data['time_vector'], 
                           resp_data['filtered_signal'])
    
    # Interpolate breathing rate
    if len(resp_data['breathing_rate']) > 0:
        interp_breathing_rate = np.interp(syllable_times, 
                                        resp_data['breath_times'], 
                                        resp_data['breathing_rate'])
    else:
        interp_breathing_rate = np.nan * np.ones_like(syllable_times)
    
    # Add respiratory data
    syllable_df['resp_signal_100hz'] = interp_resp
    syllable_df['breathing_rate_1_over_IBI'] = interp_breathing_rate
    syllable_df['breathing_rate_BPM'] = interp_breathing_rate * 60
    
    return syllable_df

# CORRECTED: Use excel_path instead of excel_dir
print("Testing FPS detection in processing...")
resp_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"

h5_files = glob(os.path.join(resp_path, "*.h5"))
excel_files = glob(os.path.join(excel_path, "*.xlsx")) + glob(os.path.join(excel_path, "*.xls"))  # FIXED

# Test with one file from each FPS category
test_h5_files = [
    "RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5",  # Should be 15 FPS
    "RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5",  # Should be 29 FPS
    "RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5"   # Should be 30 FPS
]

for test_file in test_h5_files:
    full_path = os.path.join(resp_path, test_file)
    if os.path.exists(full_path):
        h5_basename = test_file.replace('.h5', '')
        print(f"\n=== Testing {h5_basename} ===")
        
        resp_data = process_respiratory_file(full_path)
        matching_excel_files = match_files_by_name(h5_basename, excel_files)
        
        if matching_excel_files:
            for excel_file in matching_excel_files[:1]:  # Just test first match
                print(f"  Testing with: {os.path.basename(excel_file)}")
                overlaid_data = overlay_resp_on_syllables_adaptive_fps(resp_data, excel_file)
                
                if overlaid_data is not None:
                    fps_used = overlaid_data['fps_used'].iloc[0]
                    print(f"  ✓ Successfully used {fps_used} FPS")
                    
                    # Save test file to verify
                    test_output = f"TEST_{os.path.basename(excel_file)}_with_respiration.xlsx"
                    overlaid_data.to_excel(test_output, index=False)
                    print(f"  Saved test file: {test_output}")
                    break
        else:
            print(f"  No matching Excel files found")
# Out:
# Testing FPS detection in processing...
#
# === Testing RI1_s1_1_p5_2_nRB6_20250622_143958_merged ===
# Processing: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
#   Found 1586 breathing peaks
#   Mean breathing rate: 167.6 BPM
#   Looking for Excel files containing: 'RI1_s1_1'
#   Testing with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
#   Loaded syllable data: (9300, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 619.93 seconds
#   Respiratory duration: 621.27s, Syllable duration: 619.93s
#   ✓ Successfully used 15 FPS
#   Saved test file: TEST_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx_with_respiration.xlsx
#
# === Testing RI1_s3_6_p5_3_nRB3_20250621_125312_merged ===
# Processing: RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
#   Found 1509 breathing peaks
#   Mean breathing rate: 164.5 BPM
#   Looking for Excel files containing: 'RI1_s3_6'
#   Testing with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
#   Loaded syllable data: (18064, 5)
#   Using 29 FPS for this file
#   Time range: 0.00 - 622.86 seconds
#   Respiratory duration: 603.28s, Syllable duration: 622.86s
#   ✓ Successfully used 29 FPS
#   Saved test file: TEST_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx_with_respiration.xlsx
#
# === Testing RI1_s1_2_p5_1_nRB6_20250622_170742_merged ===
# Processing: RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
#   Found 1516 breathing peaks
#   Mean breathing rate: 167.0 BPM
#   Looking for Excel files containing: 'RI1_s1_2'
#   Testing with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
#   Loaded syllable data: (18083, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 602.73 seconds
#   Respiratory duration: 604.48s, Syllable duration: 602.73s
#   ✓ Successfully used 30 FPS
#   Saved test file: TEST_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx_with_respiration.xlsx

# %%
def process_all_with_correct_fps(resp_dir, excel_dir):
    """Process all files with corrected FPS detection"""
    
    h5_files = glob(os.path.join(resp_dir, "*.h5"))
    excel_files = glob(os.path.join(excel_dir, "*.xlsx")) + glob(os.path.join(excel_dir, "*.xls"))
    
    print(f"Found {len(h5_files)} h5 files and {len(excel_files)} Excel files")
    
    results = {}
    fps_usage = {}
    
    for h5_file in h5_files:
        h5_basename = os.path.basename(h5_file).replace('.h5', '')
        print(f"\n=== Processing {h5_basename} ===")
        
        # Process respiratory data
        resp_data = process_respiratory_file(h5_file)
        
        # Find matching Excel files
        matching_excel_files = match_files_by_name(h5_basename, excel_files)
        
        if matching_excel_files:
            for excel_file in matching_excel_files:
                print(f"  Processing: {os.path.basename(excel_file)}")
                overlaid_data = overlay_resp_on_syllables_adaptive_fps(resp_data, excel_file)
                
                if overlaid_data is not None:
                    # Create output filename
                    excel_basename = os.path.basename(excel_file).replace('.xlsx', '').replace('.xls', '')
                    output_file = f"FINAL_{excel_basename}_with_respiration.xlsx"
                    
                    overlaid_data.to_excel(output_file, index=False)
                    print(f"  ✓ Saved: {output_file}")
                    
                    # Track FPS usage
                    fps_used = overlaid_data['fps_used'].iloc[0]
                    fps_usage[fps_used] = fps_usage.get(fps_used, 0) + 1
                    
                    # Show stats
                    if not overlaid_data['breathing_rate_BPM'].isna().all():
                        mean_bpm = overlaid_data['breathing_rate_BPM'].mean()
                        std_bpm = overlaid_data['breathing_rate_BPM'].std()
                        print(f"  Breathing rate: {mean_bpm:.1f} ± {std_bpm:.1f} BPM")
                    
                    results[f"{h5_basename}_{excel_basename}"] = overlaid_data
        else:
            print(f"  No matching Excel files found")
    
    return results, fps_usage

# Run full processing
print("Running full processing with corrected FPS...")
resp_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"

final_results, fps_stats = process_all_with_correct_fps(resp_path, excel_path)

print(f"\n🎉 PROCESSING COMPLETE! 🎉")
print(f"Generated {len(final_results)} files with respiratory data overlaid on syllables")

print(f"\nFPS usage summary (CORRECTED):")
for fps, count in sorted(fps_stats.items()):
    print(f"  {fps} FPS: {count} files")

print(f"\nYour files now contain:")
print(f"  - Original syllable data (frame_number, syllable, etc.)")
print(f"  - time_seconds (converted from frames using correct FPS)")
print(f"  - resp_signal_100hz (filtered respiratory signal)")
print(f"  - breathing_rate_1_over_IBI (instantaneous breathing rate)")
print(f"  - breathing_rate_BPM (breathing rate in breaths per minute)")
print(f"  - fps_used (FPS used for conversion)")

# Quick verification
print(f"\nFiles are saved with 'FINAL_' prefix to distinguish from previous versions.")
# Out:
# Running full processing with corrected FPS...
# Found 18 h5 files and 42 Excel files
#
# === Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged ===
# Processing: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
#   Found 1586 breathing peaks
#   Mean breathing rate: 167.6 BPM
#   Looking for Excel files containing: 'RI1_s1_1'
#   Processing: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
#   Loaded syllable data: (9300, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 619.93 seconds
#   Respiratory duration: 621.27s, Syllable duration: 619.93s
#   ✓ Saved: FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables_with_respiration.xlsx
#   Breathing rate: 159.7 ± 38.4 BPM
#   Processing: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx
#   Loaded syllable data: (9300, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 619.93 seconds
#   Respiratory duration: 621.27s, Syllable duration: 619.93s
#   ✓ Saved: FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables_with_respiration.xlsx
#   Breathing rate: 159.7 ± 38.4 BPM
#
# === Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged ===
# Processing: RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
#   Found 1516 breathing peaks
#   Mean breathing rate: 167.0 BPM
#   Looking for Excel files containing: 'RI1_s1_2'
#   Processing: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
#   Loaded syllable data: (18083, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 602.73 seconds
#   Respiratory duration: 604.48s, Syllable duration: 602.73s
#   ✓ Saved: FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables_with_respiration.xlsx
#   Breathing rate: 157.8 ± 40.3 BPM
#   Processing: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx
#   Loaded syllable data: (18083, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 602.73 seconds
#   Respiratory duration: 604.48s, Syllable duration: 602.73s
#   ✓ Saved: FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables_with_respiration.xlsx
#   Breathing rate: 157.8 ± 40.3 BPM
#
# === Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged ===
# Processing: RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
#   Found 1439 breathing peaks
#   Mean breathing rate: 165.8 BPM
#   Looking for Excel files containing: 'RI1_s2_3'
#   Processing: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
#   Loaded syllable data: (18060, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 1203.93 seconds
#   Respiratory duration: 602.95s, Syllable duration: 1203.93s
#   ✓ Saved: FINAL_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables_with_respiration.xlsx
#   Breathing rate: 135.9 ± 35.8 BPM
#   Processing: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx
#   Loaded syllable data: (18060, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 1203.93 seconds
#   Respiratory duration: 602.95s, Syllable duration: 1203.93s
#   ✓ Saved: FINAL_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables_with_respiration.xlsx
#   Breathing rate: 135.9 ± 35.8 BPM
#
# === Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged ===
# Processing: RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
#   Found 1656 breathing peaks
#   Mean breathing rate: 173.1 BPM
#   Looking for Excel files containing: 'RI1_s2_4'
#   Processing: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
#   Loaded syllable data: (9116, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 303.83 seconds
#   Respiratory duration: 609.10s, Syllable duration: 303.83s
#   ✓ Saved: FINAL_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables_with_respiration.xlsx
#   Breathing rate: 169.4 ± 33.2 BPM
#   Processing: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx
#   Loaded syllable data: (9116, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 303.83 seconds
#   Respiratory duration: 609.10s, Syllable duration: 303.83s
#   ✓ Saved: FINAL_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables_with_respiration.xlsx
#   Breathing rate: 169.4 ± 33.2 BPM
#
# === Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged ===
# Processing: RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
#   Found 1534 breathing peaks
#   Mean breathing rate: 163.2 BPM
#   Looking for Excel files containing: 'RI1_s3_5'
#   No matching Excel files found
#
# === Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged ===
# Processing: RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
#   Found 1509 breathing peaks
#   Mean breathing rate: 164.5 BPM
#   Looking for Excel files containing: 'RI1_s3_6'
#   Processing: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
#   Loaded syllable data: (18064, 5)
#   Using 29 FPS for this file
#   Time range: 0.00 - 622.86 seconds
#   Respiratory duration: 603.28s, Syllable duration: 622.86s
#   ✓ Saved: FINAL_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables_with_respiration.xlsx
#   Breathing rate: 157.5 ± 38.5 BPM
#   Processing: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx
#   Loaded syllable data: (18064, 5)
#   Using 29 FPS for this file
#   Time range: 0.00 - 622.86 seconds
#   Respiratory duration: 603.28s, Syllable duration: 622.86s
#   ✓ Saved: FINAL_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables_with_respiration.xlsx
#   Breathing rate: 157.5 ± 38.5 BPM
#
# === Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged ===
# Processing: RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
#   Found 1624 breathing peaks
#   Mean breathing rate: 166.7 BPM
#   Looking for Excel files containing: 'RI1_s4_7'
#   Processing: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
#   Loaded syllable data: (18699, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 623.27 seconds
#   Respiratory duration: 629.16s, Syllable duration: 623.27s
#   ✓ Saved: FINAL_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables_with_respiration.xlsx
#   Breathing rate: 160.6 ± 34.9 BPM
#   Processing: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx
#   Loaded syllable data: (18699, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 623.27 seconds
#   Respiratory duration: 629.16s, Syllable duration: 623.27s
#   ✓ Saved: FINAL_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables_with_respiration.xlsx
#   Breathing rate: 160.6 ± 34.9 BPM
#
# === Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged ===
# Processing: RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
#   Found 1548 breathing peaks
#   Mean breathing rate: 170.1 BPM
#   Looking for Excel files containing: 'RI1_s4_8'
#   Processing: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
#   Loaded syllable data: (18015, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 600.47 seconds
#   Respiratory duration: 604.84s, Syllable duration: 600.47s
#   ✓ Saved: FINAL_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables_with_respiration.xlsx
#   Breathing rate: 161.5 ± 38.5 BPM
#   Processing: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx
#   Loaded syllable data: (18015, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 600.47 seconds
#   Respiratory duration: 604.84s, Syllable duration: 600.47s
#   ✓ Saved: FINAL_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables_with_respiration.xlsx
#   Breathing rate: 161.5 ± 38.5 BPM
#
# === Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged ===
# Processing: RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
#   Found 72 breathing peaks
#   Mean breathing rate: 87.9 BPM
#   Looking for Excel files containing: 'RI1_s5_13'
#   Processing: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
#   Loaded syllable data: (18405, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 613.47 seconds
#   Respiratory duration: 615.10s, Syllable duration: 613.47s
#   ✓ Saved: FINAL_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables_with_respiration.xlsx
#   Breathing rate: 53.0 ± 56.5 BPM
#   Processing: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx
#   Loaded syllable data: (18405, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 613.47 seconds
#   Respiratory duration: 615.10s, Syllable duration: 613.47s
#   ✓ Saved: FINAL_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables_with_respiration.xlsx
#   Breathing rate: 53.0 ± 56.5 BPM
#
# === Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged ===
# Processing: RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
#   Found 1583 breathing peaks
#   Mean breathing rate: 168.7 BPM
#   Looking for Excel files containing: 'RI2_s1_1'
#   Processing: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
#   Loaded syllable data: (9053, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 603.47 seconds
#   Respiratory duration: 604.80s, Syllable duration: 603.47s
#   ✓ Saved: FINAL_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables_with_respiration.xlsx
#   Breathing rate: 162.1 ± 35.9 BPM
#   Processing: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx
#   Loaded syllable data: (9053, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 603.47 seconds
#   Respiratory duration: 604.80s, Syllable duration: 603.47s
#   ✓ Saved: FINAL_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables_with_respiration.xlsx
#   Breathing rate: 162.1 ± 35.9 BPM
#
# === Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged ===
# Processing: RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
#   Found 1390 breathing peaks
#   Mean breathing rate: 165.9 BPM
#   Looking for Excel files containing: 'RI2_s1_2'
#   Processing: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
#   Loaded syllable data: (18095, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 603.13 seconds
#   Respiratory duration: 604.27s, Syllable duration: 603.13s
#   ✓ Saved: FINAL_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables_with_respiration.xlsx
#   Breathing rate: 145.6 ± 54.2 BPM
#   Processing: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx
#   Loaded syllable data: (18095, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 603.13 seconds
#   Respiratory duration: 604.27s, Syllable duration: 603.13s
#   ✓ Saved: FINAL_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables_with_respiration.xlsx
#   Breathing rate: 145.6 ± 54.2 BPM
#
# === Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged ===
# Processing: RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
#   Found 1443 breathing peaks
#   Mean breathing rate: 167.0 BPM
#   Looking for Excel files containing: 'RI2_s2_3'
#   Processing: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
#   Loaded syllable data: (18153, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 605.07 seconds
#   Respiratory duration: 609.21s, Syllable duration: 605.07s
#   ✓ Saved: FINAL_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables_with_respiration.xlsx
#   Breathing rate: 153.3 ± 43.5 BPM
#   Processing: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx
#   Loaded syllable data: (18153, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 605.07 seconds
#   Respiratory duration: 609.21s, Syllable duration: 605.07s
#   ✓ Saved: FINAL_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables_with_respiration.xlsx
#   Breathing rate: 153.3 ± 43.5 BPM
#
# === Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged ===
# Processing: RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
#   Found 1306 breathing peaks
#   Mean breathing rate: 163.5 BPM
#   Looking for Excel files containing: 'RI2_s2_4'
#   Processing: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
#   Loaded syllable data: (9065, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 604.27 seconds
#   Respiratory duration: 605.45s, Syllable duration: 604.27s
#   ✓ Saved: FINAL_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables_with_respiration.xlsx
#   Breathing rate: 138.2 ± 58.3 BPM
#   Processing: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx
#   Loaded syllable data: (9065, 5)
#   Using 15 FPS for this file
#   Time range: 0.00 - 604.27 seconds
#   Respiratory duration: 605.45s, Syllable duration: 604.27s
#   ✓ Saved: FINAL_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables_with_respiration.xlsx
#   Breathing rate: 138.2 ± 58.3 BPM
#
# === Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged ===
# Processing: RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
#   Found 556 breathing peaks
#   Mean breathing rate: 168.6 BPM
#   Looking for Excel files containing: 'RI2_s3_5'
#   Processing: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
#   Loaded syllable data: (18062, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 602.03 seconds
#   Respiratory duration: 213.34s, Syllable duration: 602.03s
#   ✓ Saved: FINAL_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables_with_respiration.xlsx
#   Breathing rate: 212.3 ± 43.3 BPM
#   Processing: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx
#   Loaded syllable data: (18062, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 602.03 seconds
#   Respiratory duration: 213.34s, Syllable duration: 602.03s
#   ✓ Saved: FINAL_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables_with_respiration.xlsx
#   Breathing rate: 212.3 ± 43.3 BPM
#
# === Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged ===
# Processing: RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
#   Found 1502 breathing peaks
#   Mean breathing rate: 161.2 BPM
#   Looking for Excel files containing: 'RI2_s3_6'
#   Processing: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
#   Loaded syllable data: (18263, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 608.73 seconds
#   Respiratory duration: 610.01s, Syllable duration: 608.73s
#   ✓ Saved: FINAL_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables_with_respiration.xlsx
#   Breathing rate: 153.5 ± 36.9 BPM
#   Processing: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx
#   Loaded syllable data: (18263, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 608.73 seconds
#   Respiratory duration: 610.01s, Syllable duration: 608.73s
#   ✓ Saved: FINAL_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables_with_respiration.xlsx
#   Breathing rate: 153.5 ± 36.9 BPM
#
# === Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged ===
# Processing: RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
#   Found 1559 breathing peaks
#   Mean breathing rate: 166.5 BPM
#   Looking for Excel files containing: 'RI2_s4_7'
#   Processing: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
#   Loaded syllable data: (18158, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 605.23 seconds
#   Respiratory duration: 606.47s, Syllable duration: 605.23s
#   ✓ Saved: FINAL_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables_with_respiration.xlsx
#   Breathing rate: 160.0 ± 35.7 BPM
#   Processing: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx
#   Loaded syllable data: (18158, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 605.23 seconds
#   Respiratory duration: 606.47s, Syllable duration: 605.23s
#   ✓ Saved: FINAL_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables_with_respiration.xlsx
#   Breathing rate: 160.0 ± 35.7 BPM
#
# === Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged ===
# Processing: RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
#   Found 1494 breathing peaks
#   Mean breathing rate: 160.0 BPM
#   Looking for Excel files containing: 'RI2_s4_8'
#   Processing: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
#   Loaded syllable data: (18065, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 602.13 seconds
#   Respiratory duration: 603.24s, Syllable duration: 602.13s
#   ✓ Saved: FINAL_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables_with_respiration.xlsx
#   Breathing rate: 153.5 ± 35.0 BPM
#   Processing: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx
#   Loaded syllable data: (18065, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 602.13 seconds
#   Respiratory duration: 603.24s, Syllable duration: 602.13s
#   ✓ Saved: FINAL_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables_with_respiration.xlsx
#   Breathing rate: 153.5 ± 35.0 BPM
#
# === Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged ===
# Processing: RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
#   Found 808 breathing peaks
#   Mean breathing rate: 145.5 BPM
#   Looking for Excel files containing: 'RI2_s5_13'
#   Processing: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
#   Loaded syllable data: (14654, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 488.43 seconds
#   Respiratory duration: 489.03s, Syllable duration: 488.43s
#   ✓ Saved: FINAL_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables_with_respiration.xlsx
#   Breathing rate: 120.6 ± 53.6 BPM
#   Processing: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx
#   Loaded syllable data: (14654, 5)
#   Using 30 FPS for this file
#   Time range: 0.00 - 488.43 seconds
#   Respiratory duration: 489.03s, Syllable duration: 488.43s
#   ✓ Saved: FINAL_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables_with_respiration.xlsx
#   Breathing rate: 120.6 ± 53.6 BPM
#
# 🎉 PROCESSING COMPLETE! 🎉
# Generated 34 files with respiratory data overlaid on syllables
#
# FPS usage summary (CORRECTED):
#   15 FPS: 8 files
#   29 FPS: 2 files
#   30 FPS: 24 files
#
# Your files now contain:
#   - Original syllable data (frame_number, syllable, etc.)
#   - time_seconds (converted from frames using correct FPS)
#   - resp_signal_100hz (filtered respiratory signal)
#   - breathing_rate_1_over_IBI (instantaneous breathing rate)
#   - breathing_rate_BPM (breathing rate in breaths per minute)
#   - fps_used (FPS used for conversion)
#
# Files are saved with 'FINAL_' prefix to distinguish from previous versions.

# %%
import pandas as pd
import glob
import numpy as np

# Check all your final files
final_files = glob.glob("FINAL_*_with_respiration.xlsx")
print(f"🎉 Found {len(final_files)} final processed files!")

# Create summary statistics
fps_summary = {}
breathing_stats = []

print("\n=== SUMMARY OF PROCESSED FILES ===")
for i, file in enumerate(final_files[:5]):  # Show first 5 as examples
    try:
        df = pd.read_excel(file)
        fps_used = df['fps_used'].iloc[0]
        fps_summary[fps_used] = fps_summary.get(fps_used, 0) + 1
        
        # Get breathing rate stats
        bpm_data = df['breathing_rate_BPM'].dropna()
        if len(bpm_data) > 0:
            mean_bpm = bpm_data.mean()
            breathing_stats.append(mean_bpm)
            
        print(f"{i+1}. {file[:50]}...")
        print(f"   Shape: {df.shape}, FPS: {fps_used}, Mean BPM: {mean_bpm:.1f}")
        
    except Exception as e:
        print(f"Error reading {file}: {e}")

if len(final_files) > 5:
    print(f"   ... and {len(final_files)-5} more files")

print(f"\n=== FPS USAGE VERIFICATION ===")
for fps, count in sorted(fps_summary.items()):
    expected = "✓ Expected" if fps in [15, 29, 30] else "⚠️ Unexpected"
    print(f"  {fps} FPS: {count} files {expected}")

print(f"\n=== BREATHING RATE OVERVIEW ===")
if breathing_stats:
    print(f"  Overall mean breathing rate: {np.mean(breathing_stats):.1f} BPM")
    print(f"  Range: {np.min(breathing_stats):.1f} - {np.max(breathing_stats):.1f} BPM")

print(f"\n=== WHAT YOU NOW HAVE ===")
print(f"✓ {len(final_files)} Excel files with respiratory data overlaid on MoSeq syllables")
print(f"✓ Respiratory signals filtered from 20kHz → 100Hz")
print(f"✓ 1/IBI breathing rates calculated for each syllable frame")
print(f"✓ Correct FPS used for time conversion (15/29/30 FPS)")
print(f"✓ All data synchronized between respiratory recordings and behavioral syllables")

print(f"\n🔬 READY FOR ANALYSIS!")
print(f"You can now analyze:")
print(f"  - Breathing patterns during specific syllables")
print(f"  - Respiratory-behavioral coupling")
print(f"  - Changes in breathing rate across different behaviors")
print(f"  - Correlations between syllable types and respiratory dynamics")
# Out:
# 🎉 Found 34 final processed files!
#
# === SUMMARY OF PROCESSED FILES ===
# 1. FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track...
#    Shape: (9300, 10), FPS: 15, Mean BPM: 159.7
# 2. FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track...
#    Shape: (9300, 10), FPS: 15, Mean BPM: 159.7
# 3. FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track...
#    Shape: (18083, 10), FPS: 30, Mean BPM: 157.8
# 4. FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track...
#    Shape: (18083, 10), FPS: 30, Mean BPM: 157.8
# 5. FINAL_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track...
#    Shape: (18060, 10), FPS: 15, Mean BPM: 135.9
#    ... and 29 more files
#
# === FPS USAGE VERIFICATION ===
#   15 FPS: 3 files ✓ Expected
#   30 FPS: 2 files ✓ Expected
#
# === BREATHING RATE OVERVIEW ===
#   Overall mean breathing rate: 154.2 BPM
#   Range: 135.9 - 159.7 BPM
#
# === WHAT YOU NOW HAVE ===
# ✓ 34 Excel files with respiratory data overlaid on MoSeq syllables
# ✓ Respiratory signals filtered from 20kHz → 100Hz
# ✓ 1/IBI breathing rates calculated for each syllable frame
# ✓ Correct FPS used for time conversion (15/29/30 FPS)
# ✓ All data synchronized between respiratory recordings and behavioral syllables
#
# 🔬 READY FOR ANALYSIS!
# You can now analyze:
#   - Breathing patterns during specific syllables
#   - Respiratory-behavioral coupling
#   - Changes in breathing rate across different behaviors
#   - Correlations between syllable types and respiratory dynamics

# %%
import os
print("Current working directory:", os.getcwd())
print("\nFINAL files in current directory:")
final_files = [f for f in os.listdir('.') if f.startswith('FINAL_') and f.endswith('.xlsx')]
for file in final_files:
    print(f"  {file}")
# Out:
# Current working directory: c:\Users\Padilla-Coreano\Documents\tanish
#
# FINAL files in current directory:
#   FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables_with_respiration.xlsx

# %%
import pandas as pd
import glob
import os

def create_master_files_with_sheets():
    """Create master Excel files with separate sheets for each video"""
    
    # Get all FINAL files
    final_files = glob.glob("FINAL_*_with_respiration.xlsx")
    
    # Fix the pattern matching - your files have "-RI1_" not "_RI1_"
    ri1_files = [f for f in final_files if "-RI1_" in f]
    ri2_files = [f for f in final_files if "-RI2_" in f]
    
    print(f"Found {len(ri1_files)} RI1 files and {len(ri2_files)} RI2 files")
    
    # Show some examples to verify
    if ri1_files:
        print(f"RI1 examples: {ri1_files[0][:60]}...")
    if ri2_files:
        print(f"RI2 examples: {ri2_files[0][:60]}...")
    
    def create_master_file(files, output_name):
        """Create master file with multiple sheets"""
        print(f"\nCreating {output_name}...")
        
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                # Load data
                df = pd.read_excel(file)
                
                # Create sheet name from filename
                filename = os.path.basename(file)
                
                # Extract the key parts - FIXED: use dash not underscore
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                # Get session and track info
                session_info = session_part.split("_")[0:3]  # s1, 1, p5 etc
                track_info = "track0" if "track0" in filename else "track1"
                
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_{track_info}"
                
                # Excel sheet names can't be longer than 31 characters
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                # Write to sheet
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"  Added sheet: {sheet_name} ({df.shape[0]} rows)")
        
        print(f"✅ Saved: {output_name}")
    
    # Create master files
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_All_Sessions_With_Respiration.xlsx")
    
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_All_Sessions_With_Respiration.xlsx")
    
    return len(ri1_files), len(ri2_files)

# Create the master files
ri1_count, ri2_count = create_master_files_with_sheets()

print(f"\n🎉 MASTER FILES CREATED! 🎉")
print(f"📁 RI1_MASTER_All_Sessions_With_Respiration.xlsx ({ri1_count} sheets)")
print(f"📁 RI2_MASTER_All_Sessions_With_Respiration.xlsx ({ri2_count} sheets)")

# Verify the master files
print(f"\n📋 SHEET VERIFICATION:")
for master_file in ["RI1_MASTER_All_Sessions_With_Respiration.xlsx", "RI2_MASTER_All_Sessions_With_Respiration.xlsx"]:
    if os.path.exists(master_file):
        xl_file = pd.ExcelFile(master_file)
        print(f"\n{master_file}:")
        print(f"  Total sheets: {len(xl_file.sheet_names)}")
        for sheet in xl_file.sheet_names:
            print(f"    - {sheet}")
# Out:
# Found 16 RI1 files and 18 RI2 files
# RI1 examples: FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllable...
# RI2 examples: FINAL_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllable...
#
# Creating RI1_MASTER_All_Sessions_With_Respiration.xlsx...
#   Added sheet: RI1_s1_1_p5_track0 (9300 rows)
#   Added sheet: RI1_s1_1_p5_track1 (9300 rows)
#   Added sheet: RI1_s1_2_p5_track0 (18083 rows)
#   Added sheet: RI1_s1_2_p5_track1 (18083 rows)
#   Added sheet: RI1_s2_3_p5_track0 (18060 rows)
#   Added sheet: RI1_s2_3_p5_track1 (18060 rows)
#   Added sheet: RI1_s2_4_p5_track0 (9116 rows)
#   Added sheet: RI1_s2_4_p5_track1 (9116 rows)
#   Added sheet: RI1_s3_6_p5_track0 (18064 rows)
#   Added sheet: RI1_s3_6_p5_track1 (18064 rows)
#   Added sheet: RI1_s4_7_p5_track0 (18699 rows)
#   Added sheet: RI1_s4_7_p5_track1 (18699 rows)
#   Added sheet: RI1_s4_8_p5_track0 (18015 rows)
#   Added sheet: RI1_s4_8_p5_track1 (18015 rows)
#   Added sheet: RI1_s5_13_p5_track0 (18405 rows)
#   Added sheet: RI1_s5_13_p5_track1 (18405 rows)
# ✅ Saved: RI1_MASTER_All_Sessions_With_Respiration.xlsx
#
# Creating RI2_MASTER_All_Sessions_With_Respiration.xlsx...
#   Added sheet: RI2_s1_1_p5_track0 (9053 rows)
#   Added sheet: RI2_s1_1_p5_track1 (9053 rows)
#   Added sheet: RI2_s1_2_p5_track0 (18095 rows)
#   Added sheet: RI2_s1_2_p5_track1 (18095 rows)
#   Added sheet: RI2_s2_3_p5_track0 (18153 rows)
#   Added sheet: RI2_s2_3_p5_track1 (18153 rows)
#   Added sheet: RI2_s2_4_p5_track0 (9065 rows)
#   Added sheet: RI2_s2_4_p5_track1 (9065 rows)
#   Added sheet: RI2_s3_5_p5_track0 (18062 rows)
#   Added sheet: RI2_s3_5_p5_track1 (18062 rows)
#   Added sheet: RI2_s3_6_p_track0 (18263 rows)
#   Added sheet: RI2_s3_6_p_track1 (18263 rows)
#   Added sheet: RI2_s4_7_p5_track0 (18158 rows)
#   Added sheet: RI2_s4_7_p5_track1 (18158 rows)
#   Added sheet: RI2_s4_8_p5_track0 (18065 rows)
#   Added sheet: RI2_s4_8_p5_track1 (18065 rows)
#   Added sheet: RI2_s5_13_p5_track0 (14654 rows)
#   Added sheet: RI2_s5_13_p5_track1 (14654 rows)
# ✅ Saved: RI2_MASTER_All_Sessions_With_Respiration.xlsx
#
# 🎉 MASTER FILES CREATED! 🎉
# 📁 RI1_MASTER_All_Sessions_With_Respiration.xlsx (16 sheets)
# 📁 RI2_MASTER_All_Sessions_With_Respiration.xlsx (18 sheets)
#
# 📋 SHEET VERIFICATION:
#
# RI1_MASTER_All_Sessions_With_Respiration.xlsx:
#   Total sheets: 16
#     - RI1_s1_1_p5_track0
#     - RI1_s1_1_p5_track1
#     - RI1_s1_2_p5_track0
#     - RI1_s1_2_p5_track1
#     - RI1_s2_3_p5_track0
#     - RI1_s2_3_p5_track1
#     - RI1_s2_4_p5_track0
#     - RI1_s2_4_p5_track1
#     - RI1_s3_6_p5_track0
#     - RI1_s3_6_p5_track1
#     - RI1_s4_7_p5_track0
#     - RI1_s4_7_p5_track1
#     - RI1_s4_8_p5_track0
#     - RI1_s4_8_p5_track1
#     - RI1_s5_13_p5_track0
#     - RI1_s5_13_p5_track1
#
# RI2_MASTER_All_Sessions_With_Respiration.xlsx:
#   Total sheets: 18
#     - RI2_s1_1_p5_track0
#     - RI2_s1_1_p5_track1
#     - RI2_s1_2_p5_track0
#     - RI2_s1_2_p5_track1
#     - RI2_s2_3_p5_track0
#     - RI2_s2_3_p5_track1
#     - RI2_s2_4_p5_track0
#     - RI2_s2_4_p5_track1
#     - RI2_s3_5_p5_track0
#     - RI2_s3_5_p5_track1
#     - RI2_s3_6_p_track0
#     - RI2_s3_6_p_track1
#     - RI2_s4_7_p5_track0
#     - RI2_s4_7_p5_track1
#     - RI2_s4_8_p5_track0
#     - RI2_s4_8_p5_track1
#     - RI2_s5_13_p5_track0
#     - RI2_s5_13_p5_track1

# %%
import pandas as pd
import numpy as np
import glob
import os
from scipy import signal
import h5py

def process_syllable_instances(resp_data, excel_file_path):
    """Process respiratory data per syllable instance, not per frame"""
    
    # Load syllable data
    syllable_df = pd.read_excel(excel_file_path)
    print(f"  Loaded syllable data: {syllable_df.shape}")
    
    # Get FPS and convert frames to time
    video_fps = get_fps_for_file(os.path.basename(excel_file_path))
    syllable_df['time_seconds'] = syllable_df['frame_number'] / video_fps
    
    print(f"  Using {video_fps} FPS for time conversion")
    
    # Group consecutive frames with same syllable to find syllable instances
    syllable_df['syllable_group'] = (syllable_df['syllable'] != syllable_df['syllable'].shift()).cumsum()
    
    syllable_instances = []
    
    for group_id, group in syllable_df.groupby('syllable_group'):
        syllable_id = group['syllable'].iloc[0]
        start_frame = group['frame_number'].min()
        end_frame = group['frame_number'].max()
        start_time = group['time_seconds'].min()
        end_time = group['time_seconds'].max()
        duration_ms = (end_time - start_time) * 1000  # Convert to milliseconds
        
        # Skip syllables under 500ms
        if duration_ms < 500:
            continue
            
        num_frames = len(group)
        
        # Get respiratory data for this syllable duration
        # Find respiratory data points within this time window
        time_mask = (resp_data['time_vector'] >= start_time) & (resp_data['time_vector'] <= end_time)
        syllable_resp_signal = resp_data['filtered_signal'][time_mask]
        
        if len(syllable_resp_signal) == 0:
            continue
            
        # Calculate respiratory metrics for this syllable instance
        mean_resp_signal = np.mean(syllable_resp_signal)
        std_resp_signal = np.std(syllable_resp_signal)
        min_resp_signal = np.min(syllable_resp_signal)
        max_resp_signal = np.max(syllable_resp_signal)
        
        # Get breathing rate during this syllable
        # Find breath times that fall within this syllable
        if len(resp_data['breathing_rate']) > 0:
            breath_mask = (resp_data['breath_times'] >= start_time) & (resp_data['breath_times'] <= end_time)
            syllable_breathing_rates = resp_data['breathing_rate'][breath_mask]
            
            if len(syllable_breathing_rates) > 0:
                mean_breathing_rate_per_sec = np.mean(syllable_breathing_rates)  # Already in breaths/sec
                mean_breathing_rate_bpm = mean_breathing_rate_per_sec * 60
                std_breathing_rate_per_sec = np.std(syllable_breathing_rates)
                
                # Calculate IBI for this syllable
                mean_ibi = 1 / mean_breathing_rate_per_sec if mean_breathing_rate_per_sec > 0 else np.nan
            else:
                # No breathing events during this syllable, interpolate from nearest
                interp_rate = np.interp((start_time + end_time) / 2, 
                                      resp_data['breath_times'], 
                                      resp_data['breathing_rate'])
                mean_breathing_rate_per_sec = interp_rate
                mean_breathing_rate_bpm = interp_rate * 60
                std_breathing_rate_per_sec = np.nan
                mean_ibi = 1 / interp_rate if interp_rate > 0 else np.nan
        else:
            mean_breathing_rate_per_sec = np.nan
            mean_breathing_rate_bpm = np.nan
            std_breathing_rate_per_sec = np.nan
            mean_ibi = np.nan
        
        syllable_instances.append({
            'syllable_id': syllable_id,
            'start_frame': start_frame,
            'end_frame': end_frame,
            'start_time_sec': start_time,
            'end_time_sec': end_time,
            'duration_ms': duration_ms,
            'num_frames': num_frames,
            'fps_used': video_fps,
            'mean_resp_signal_100hz': mean_resp_signal,
            'std_resp_signal_100hz': std_resp_signal,
            'min_resp_signal_100hz': min_resp_signal,
            'max_resp_signal_100hz': max_resp_signal,
            'mean_breathing_rate_per_sec': mean_breathing_rate_per_sec,
            'mean_breathing_rate_bpm': mean_breathing_rate_bpm,
            'std_breathing_rate_per_sec': std_breathing_rate_per_sec,
            'mean_ibi_seconds': mean_ibi,
            'video_name': group['video_name'].iloc[0],
            'track_name': group['track_name'].iloc[0]
        })
    
    result_df = pd.DataFrame(syllable_instances)
    print(f"  Created {len(result_df)} syllable instances (≥500ms) from {len(syllable_df)} frames")
    
    if len(result_df) > 0:
        print(f"  Duration range: {result_df['duration_ms'].min():.0f} - {result_df['duration_ms'].max():.0f} ms")
        print(f"  Mean syllable duration: {result_df['duration_ms'].mean():.0f} ms")
    
    return result_df

def process_track0_only_with_syllable_instances(resp_dir, excel_dir):
    """Process only track0 files with syllable instance analysis"""
    
    h5_files = glob.glob(os.path.join(resp_dir, "*.h5"))
    excel_files = glob.glob(os.path.join(excel_dir, "*.xlsx")) + glob.glob(os.path.join(excel_dir, "*.xls"))
    
    # Filter to only track0 files
    track0_excel_files = [f for f in excel_files if "track0" in f]
    
    print(f"Found {len(h5_files)} h5 files and {len(track0_excel_files)} track0 Excel files")
    
    results = {}
    
    for h5_file in h5_files:
        h5_basename = os.path.basename(h5_file).replace('.h5', '')
        print(f"\n=== Processing {h5_basename} ===")
        
        # Process respiratory data
        resp_data = process_respiratory_file(h5_file)
        
        # Find matching track0 Excel files only
        matching_excel_files = [f for f in track0_excel_files 
                               if match_files_by_name(h5_basename, [f])]
        
        if matching_excel_files:
            for excel_file in matching_excel_files:
                print(f"  Processing: {os.path.basename(excel_file)}")
                syllable_instances_df = process_syllable_instances(resp_data, excel_file)
                
                if syllable_instances_df is not None and len(syllable_instances_df) > 0:
                    # Create output filename
                    excel_basename = os.path.basename(excel_file).replace('.xlsx', '').replace('.xls', '')
                    output_file = f"SYLLABLE_INSTANCES_{excel_basename}_with_respiration.xlsx"
                    
                    syllable_instances_df.to_excel(output_file, index=False)
                    print(f"  ✓ Saved: {output_file}")
                    
                    # Show stats
                    valid_bpm = syllable_instances_df['mean_breathing_rate_bpm'].dropna()
                    if len(valid_bpm) > 0:
                        print(f"  Breathing rate: {valid_bpm.mean():.1f} ± {valid_bpm.std():.1f} BPM")
                        print(f"  Breathing rate: {valid_bpm.mean()/60:.3f} ± {valid_bpm.std()/60:.3f} breaths/sec")
                    
                    results[f"{h5_basename}_{excel_basename}"] = syllable_instances_df
                else:
                    print(f"  No valid syllable instances found (all <500ms)")
        else:
            print(f"  No matching track0 Excel files found")
    
    return results

# Updated processing
resp_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"

print("Processing TRACK0 ONLY with SYLLABLE INSTANCES (≥500ms)...")
syllable_results = process_track0_only_with_syllable_instances(resp_path, excel_path)

print(f"\n🎉 SYLLABLE INSTANCE PROCESSING COMPLETE! 🎉")
print(f"Generated {len(syllable_results)} files")

print(f"\nYour new files contain:")
print(f"  ✓ One row per syllable instance (not per frame)")
print(f"  ✓ Only syllables lasting ≥500ms")
print(f"  ✓ Only track0 data")
print(f"  ✓ Breathing rate in breaths/second AND BPM")
print(f"  ✓ IBI (Inter-Breath Interval) in seconds")
print(f"  ✓ Respiratory signal statistics per syllable")
# Out:
# Processing TRACK0 ONLY with SYLLABLE INSTANCES (≥500ms)...
# Found 18 h5 files and 17 track0 Excel files
#
# === Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged ===
# Processing: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
#   Found 1586 breathing peaks
#   Mean breathing rate: 167.6 BPM
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Looking for Excel files containing: 'RI1_s1_1'
#   Processing: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
#   Loaded syllable data: (9300, 5)
#   Using 15 FPS for time conversion
#   Created 303 syllable instances (≥500ms) from 9300 frames
#   Duration range: 533 - 5533 ms
#   Mean syllable duration: 1128 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables_with_respiration.xlsx
#   Breathing rate: 160.8 ± 34.7 BPM
#   Breathing rate: 2.679 ± 0.579 breaths/sec
#
# === Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged ===
# Processing: RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
#   Found 1516 breathing peaks
#   Mean breathing rate: 167.0 BPM
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Looking for Excel files containing: 'RI1_s1_2'
#   Processing: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
#   Loaded syllable data: (18083, 5)
#   Using 30 FPS for time conversion
#   Created 266 syllable instances (≥500ms) from 18083 frames
#   Duration range: 500 - 9300 ms
#   Mean syllable duration: 1083 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables_with_respiration.xlsx
#   Breathing rate: 156.7 ± 38.2 BPM
#   Breathing rate: 2.611 ± 0.637 breaths/sec
#
# === Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged ===
# Processing: RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
#   Found 1439 breathing peaks
#   Mean breathing rate: 165.8 BPM
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Looking for Excel files containing: 'RI1_s2_3'
#   Processing: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
#   Loaded syllable data: (18060, 5)
#   Using 15 FPS for time conversion
#   Created 284 syllable instances (≥500ms) from 18060 frames
#   Duration range: 533 - 14667 ms
#   Mean syllable duration: 1554 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables_with_respiration.xlsx
#   Breathing rate: 156.7 ± 40.9 BPM
#   Breathing rate: 2.611 ± 0.682 breaths/sec
#
# === Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged ===
# Processing: RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
#   Found 1656 breathing peaks
#   Mean breathing rate: 173.1 BPM
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Looking for Excel files containing: 'RI1_s2_4'
#   Processing: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
#   Loaded syllable data: (9116, 5)
#   Using 30 FPS for time conversion
#   Created 132 syllable instances (≥500ms) from 9116 frames
#   Duration range: 500 - 6133 ms
#   Mean syllable duration: 892 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables_with_respiration.xlsx
#   Breathing rate: 170.4 ± 30.5 BPM
#   Breathing rate: 2.840 ± 0.508 breaths/sec
#
# === Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged ===
# Processing: RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
#   Found 1534 breathing peaks
#   Mean breathing rate: 163.2 BPM
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   Looking for Excel files containing: 'RI1_s3_5'
#   No matching track0 Excel files found
#
# === Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged ===
# Processing: RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
#   Found 1509 breathing peaks
#   Mean breathing rate: 164.5 BPM
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Looking for Excel files containing: 'RI1_s3_6'
#   Processing: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
#   Loaded syllable data: (18064, 5)
#   Using 29 FPS for time conversion
#   Created 284 syllable instances (≥500ms) from 18064 frames
#   Duration range: 517 - 8759 ms
#   Mean syllable duration: 1547 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables_with_respiration.xlsx
#   Breathing rate: 159.8 ± 29.8 BPM
#   Breathing rate: 2.664 ± 0.496 breaths/sec
#
# === Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged ===
# Processing: RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
#   Found 1624 breathing peaks
#   Mean breathing rate: 166.7 BPM
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Looking for Excel files containing: 'RI1_s4_7'
#   Processing: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
#   Loaded syllable data: (18699, 5)
#   Using 30 FPS for time conversion
#   Created 305 syllable instances (≥500ms) from 18699 frames
#   Duration range: 500 - 13633 ms
#   Mean syllable duration: 1078 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables_with_respiration.xlsx
#   Breathing rate: 161.9 ± 30.4 BPM
#   Breathing rate: 2.699 ± 0.506 breaths/sec
#
# === Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged ===
# Processing: RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
#   Found 1548 breathing peaks
#   Mean breathing rate: 170.1 BPM
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Looking for Excel files containing: 'RI1_s4_8'
#   Processing: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
#   Loaded syllable data: (18015, 5)
#   Using 30 FPS for time conversion
#   Created 303 syllable instances (≥500ms) from 18015 frames
#   Duration range: 500 - 3867 ms
#   Mean syllable duration: 949 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables_with_respiration.xlsx
#   Breathing rate: 163.2 ± 36.3 BPM
#   Breathing rate: 2.720 ± 0.605 breaths/sec
#
# === Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged ===
# Processing: RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
#   Found 72 breathing peaks
#   Mean breathing rate: 87.9 BPM
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Looking for Excel files containing: 'RI1_s5_13'
#   Processing: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
#   Loaded syllable data: (18405, 5)
#   Using 30 FPS for time conversion
#   Created 315 syllable instances (≥500ms) from 18405 frames
#   Duration range: 500 - 8733 ms
#   Mean syllable duration: 1131 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables_with_respiration.xlsx
#   Breathing rate: 52.6 ± 56.2 BPM
#   Breathing rate: 0.877 ± 0.937 breaths/sec
#
# === Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged ===
# Processing: RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
#   Found 1583 breathing peaks
#   Mean breathing rate: 168.7 BPM
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Looking for Excel files containing: 'RI2_s1_1'
#   Processing: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
#   Loaded syllable data: (9053, 5)
#   Using 15 FPS for time conversion
#   Created 221 syllable instances (≥500ms) from 9053 frames
#   Duration range: 533 - 24000 ms
#   Mean syllable duration: 2091 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables_with_respiration.xlsx
#   Breathing rate: 165.9 ± 27.9 BPM
#   Breathing rate: 2.766 ± 0.465 breaths/sec
#
# === Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged ===
# Processing: RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
#   Found 1390 breathing peaks
#   Mean breathing rate: 165.9 BPM
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Looking for Excel files containing: 'RI2_s1_2'
#   Processing: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
#   Loaded syllable data: (18095, 5)
#   Using 30 FPS for time conversion
#   Created 198 syllable instances (≥500ms) from 18095 frames
#   Duration range: 500 - 36500 ms
#   Mean syllable duration: 2532 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables_with_respiration.xlsx
#   Breathing rate: 145.6 ± 53.1 BPM
#   Breathing rate: 2.427 ± 0.885 breaths/sec
#
# === Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged ===
# Processing: RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
#   Found 1443 breathing peaks
#   Mean breathing rate: 167.0 BPM
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Looking for Excel files containing: 'RI2_s2_3'
#   Processing: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
#   Loaded syllable data: (18153, 5)
#   Using 30 FPS for time conversion
#   Created 188 syllable instances (≥500ms) from 18153 frames
#   Duration range: 500 - 36900 ms
#   Mean syllable duration: 2433 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables_with_respiration.xlsx
#   Breathing rate: 160.5 ± 41.3 BPM
#   Breathing rate: 2.675 ± 0.689 breaths/sec
#
# === Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged ===
# Processing: RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
#   Found 1306 breathing peaks
#   Mean breathing rate: 163.5 BPM
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Looking for Excel files containing: 'RI2_s2_4'
#   Processing: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
#   Loaded syllable data: (9065, 5)
#   Using 15 FPS for time conversion
#   Created 201 syllable instances (≥500ms) from 9065 frames
#   Duration range: 533 - 28133 ms
#   Mean syllable duration: 2350 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables_with_respiration.xlsx
#   Breathing rate: 153.5 ± 43.7 BPM
#   Breathing rate: 2.558 ± 0.728 breaths/sec
#
# === Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged ===
# Processing: RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
#   Found 556 breathing peaks
#   Mean breathing rate: 168.6 BPM
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Looking for Excel files containing: 'RI2_s3_5'
#   Processing: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
#   Loaded syllable data: (18062, 5)
#   Using 30 FPS for time conversion
#   Created 42 syllable instances (≥500ms) from 18062 frames
#   Duration range: 500 - 55767 ms
#   Mean syllable duration: 3694 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables_with_respiration.xlsx
#   Breathing rate: 167.7 ± 25.9 BPM
#   Breathing rate: 2.794 ± 0.432 breaths/sec
#
# === Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged ===
# Processing: RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
#   Found 1502 breathing peaks
#   Mean breathing rate: 161.2 BPM
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Looking for Excel files containing: 'RI2_s3_6'
#   Processing: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
#   Loaded syllable data: (18263, 5)
#   Using 30 FPS for time conversion
#   Created 180 syllable instances (≥500ms) from 18263 frames
#   Duration range: 500 - 26667 ms
#   Mean syllable duration: 2327 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables_with_respiration.xlsx
#   Breathing rate: 160.4 ± 30.1 BPM
#   Breathing rate: 2.673 ± 0.501 breaths/sec
#
# === Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged ===
# Processing: RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
#   Found 1559 breathing peaks
#   Mean breathing rate: 166.5 BPM
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Looking for Excel files containing: 'RI2_s4_7'
#   Processing: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
#   Loaded syllable data: (18158, 5)
#   Using 30 FPS for time conversion
#   Created 238 syllable instances (≥500ms) from 18158 frames
#   Duration range: 500 - 11567 ms
#   Mean syllable duration: 1446 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables_with_respiration.xlsx
#   Breathing rate: 165.8 ± 29.4 BPM
#   Breathing rate: 2.764 ± 0.490 breaths/sec
#
# === Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged ===
# Processing: RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
#   Found 1494 breathing peaks
#   Mean breathing rate: 160.0 BPM
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Looking for Excel files containing: 'RI2_s4_8'
#   Processing: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
#   Loaded syllable data: (18065, 5)
#   Using 30 FPS for time conversion
#   Created 197 syllable instances (≥500ms) from 18065 frames
#   Duration range: 500 - 22000 ms
#   Mean syllable duration: 2011 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables_with_respiration.xlsx
#   Breathing rate: 160.2 ± 28.3 BPM
#   Breathing rate: 2.671 ± 0.471 breaths/sec
#
# === Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged ===
# Processing: RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
#   Found 808 breathing peaks
#   Mean breathing rate: 145.5 BPM
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Looking for Excel files containing: 'RI2_s5_13'
#   Processing: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
#   Loaded syllable data: (14654, 5)
#   Using 30 FPS for time conversion
#   Created 188 syllable instances (≥500ms) from 14654 frames
#   Duration range: 500 - 25600 ms
#   Mean syllable duration: 1616 ms
#   ✓ Saved: SYLLABLE_INSTANCES_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables_with_respiration.xlsx
#   Breathing rate: 129.2 ± 45.9 BPM
#   Breathing rate: 2.153 ± 0.765 breaths/sec
#
# 🎉 SYLLABLE INSTANCE PROCESSING COMPLETE! 🎉
# Generated 17 files
#
# Your new files contain:
#   ✓ One row per syllable instance (not per frame)
#   ✓ Only syllables lasting ≥500ms
#   ✓ Only track0 data
#   ✓ Breathing rate in breaths/second AND BPM
#   ✓ IBI (Inter-Breath Interval) in seconds
#   ✓ Respiratory signal statistics per syllable

# %%
def create_master_files_with_respiratory_data():
    aligned_files = glob.glob("ALIGNED_*_respiratory_data.xlsx")
    
    ri1_files = [f for f in aligned_files if "-RI1_" in f]
    ri2_files = [f for f in aligned_files if "-RI2_" in f]
    
    print(f"Found {len(ri1_files)} RI1 files and {len(ri2_files)} RI2 files")
    
    def create_master_file(files, output_name):
        print(f"\nCreating {output_name}...")
        
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                track_info = "track0"
                
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_{track_info}"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"  Added sheet: {sheet_name} ({df.shape[0]} syllable instances)")
        
        print(f"✅ Saved: {output_name}")
    
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_Respiratory_Syllable_Data.xlsx")
    
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_Respiratory_Syllable_Data.xlsx")
    
    return len(ri1_files), len(ri2_files)

ri1_count, ri2_count = create_master_files_with_respiratory_data()

print(f"\n🎉 MASTER FILES CREATED! 🎉")
print(f"📁 RI1_MASTER_Respiratory_Syllable_Data.xlsx ({ri1_count} sheets)")
print(f"📁 RI2_MASTER_Respiratory_Syllable_Data.xlsx ({ri2_count} sheets)")
print(f"  ✓ Respiratory signal statistics per syllable")
print(f"  ✓ IBI and breathing rates per syllable instance")
print(f"  ✓ Only syllables ≥500ms duration")
print(f"  ✓ Only track0 data")
# Out:
# Found 0 RI1 files and 0 RI2 files
#
# 🎉 MASTER FILES CREATED! 🎉
# 📁 RI1_MASTER_Respiratory_Syllable_Data.xlsx (0 sheets)
# 📁 RI2_MASTER_Respiratory_Syllable_Data.xlsx (0 sheets)
#   ✓ Respiratory signal statistics per syllable
#   ✓ IBI and breathing rates per syllable instance
#   ✓ Only syllables ≥500ms duration
#   ✓ Only track0 data

# %%
import glob
import os

print("Current directory:", os.getcwd())

print("\nAll Excel files in current directory:")
all_excel = glob.glob("*.xlsx")
for file in all_excel[:10]:
    print(f"  {file}")
if len(all_excel) > 10:
    print(f"  ... and {len(all_excel)-10} more")

print(f"\nLooking for ALIGNED files:")
aligned_files = glob.glob("ALIGNED_*_respiratory_data.xlsx")
print(f"Found {len(aligned_files)} ALIGNED files")

print(f"\nLooking for FINAL files:")
final_files = glob.glob("FINAL_*_with_respiration.xlsx")
print(f"Found {len(final_files)} FINAL files")

print(f"\nLooking for any files with 'respiratory' in name:")
resp_files = glob.glob("*respiratory*.xlsx")
for file in resp_files:
    print(f"  {file}")
# Out:
# Current directory: c:\Users\Padilla-Coreano\Documents\tanish
#
# All Excel files in current directory:
#   FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables_with_respiration.xlsx
#   FINAL_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables_with_respiration.xlsx
#   ... and 83 more
#
# Looking for ALIGNED files:
# Found 0 ALIGNED files
#
# Looking for FINAL files:
# Found 34 FINAL files
#
# Looking for any files with 'respiratory' in name:

# %%
import h5py
import numpy as np
import pandas as pd
from scipy import signal
import glob
import os
import matplotlib.pyplot as plt

def extract_breathing_signal(h5_file_path):
    with h5py.File(h5_file_path, 'r') as f:
        breathing_data = f['resp'][:].flatten()
        print(f"Extracted breathing signal: {len(breathing_data)} samples")
        print(f"Signal range: {breathing_data.min():.1f} to {breathing_data.max():.1f}")
    return breathing_data

def apply_signal_filtering(breathing_data, source_fs=20000, output_fs=100):
    print(f"Source sampling rate: {source_fs} Hz")
    print(f"Output sampling rate: {output_fs} Hz")
    
    nyquist_freq = source_fs / 2
    filter_cutoff = output_fs / 2
    
    filter_b, filter_a = signal.butter(5, filter_cutoff/nyquist_freq, 'low')
    
    clean_signal = signal.filtfilt(filter_b, filter_a, breathing_data)
    print(f"Signal filtered with cutoff: {filter_cutoff} Hz")
    
    reduction_factor = source_fs // output_fs
    reduced_signal = clean_signal[::reduction_factor]
    
    print(f"Signal reduced by factor {reduction_factor}: {len(reduced_signal)} samples at {output_fs} Hz")
    print(f"Total duration: {len(reduced_signal) / output_fs:.2f} seconds")
    
    return reduced_signal, output_fs

def generate_timestamp_array(clean_signal, sample_rate):
    timestamp_array = np.arange(len(clean_signal)) / sample_rate
    print(f"Timestamp array: 0.00 to {timestamp_array[-1]:.2f} seconds")
    return timestamp_array

def find_breath_cycles(breathing_signal, fs=100):
    standardized_signal = (breathing_signal - np.mean(breathing_signal)) / np.std(breathing_signal)
    
    min_peak_distance = fs // 4
    peak_prominence = 0.5
    min_height = 0.1
    
    breath_peaks, peak_properties = signal.find_peaks(standardized_signal,
                                                     distance=min_peak_distance,
                                                     prominence=peak_prominence,
                                                     height=min_height)
    
    print(f"Detected {len(breath_peaks)} breath cycles")
    
    if len(breath_peaks) < 2:
        print("Warning: Insufficient breath cycles for interval calculation")
        return np.array([]), np.array([]), np.array([])
    
    cycle_timestamps = breath_peaks / fs
    interval_durations = np.diff(cycle_timestamps)
    interval_timestamps = cycle_timestamps[1:]
    
    print(f"Breath interval range: {interval_durations.min():.3f} to {interval_durations.max():.3f} seconds")
    print(f"Average breath interval: {interval_durations.mean():.3f} seconds")
    
    return breath_peaks, interval_durations, interval_timestamps

def compute_breath_frequencies(interval_durations, interval_timestamps):
    frequency_per_second = 1 / interval_durations
    
    frequency_per_minute = frequency_per_second * 60
    
    print(f"Breath frequency range: {frequency_per_second.min():.3f} to {frequency_per_second.max():.3f} breaths/sec")
    print(f"Breath frequency range: {frequency_per_minute.min():.1f} to {frequency_per_minute.max():.1f} breaths/min")
    print(f"Average breath frequency: {frequency_per_second.mean():.3f} breaths/sec ({frequency_per_minute.mean():.1f} breaths/min)")
    
    return frequency_per_second, frequency_per_minute

def determine_video_framerate(filename):
    framerate_mapping = {
        "RI1_s1_1": 15,
        "RI1_s2_3": 15, 
        "RI1_s3_6": 29,
        "RI2_s1_1": 15,
        "RI2_s2_4": 15
    }
    
    for pattern, fps in framerate_mapping.items():
        if pattern in filename:
            return fps
    return 30

def import_behavior_data_with_timing(excel_file_path):
    behavior_df = pd.read_excel(excel_file_path)
    print(f"Imported behavior data: {behavior_df.shape}")
    print(f"Data columns: {list(behavior_df.columns)}")
    
    video_framerate = determine_video_framerate(os.path.basename(excel_file_path))
    print(f"Applied {video_framerate} FPS for frame-to-time conversion")
    
    behavior_df['timestamp_seconds'] = behavior_df['frame_number'] / video_framerate
    behavior_df['framerate_applied'] = video_framerate
    
    print(f"Behavior timestamp range: {behavior_df['timestamp_seconds'].min():.2f} to {behavior_df['timestamp_seconds'].max():.2f} seconds")
    
    return behavior_df, video_framerate

def create_behavior_episodes(behavior_df, minimum_duration_ms=500):
    behavior_df['behavior_transition'] = (behavior_df['syllable'] != behavior_df['syllable'].shift()).astype(int)
    behavior_df['episode_group'] = behavior_df['behavior_transition'].cumsum()
    
    behavior_episodes = []
    
    for group_id, episode_group in behavior_df.groupby('episode_group'):
        behavior_type = episode_group['syllable'].iloc[0]
        episode_start_frame = episode_group['frame_number'].min()
        episode_end_frame = episode_group['frame_number'].max()
        episode_start_time = episode_group['timestamp_seconds'].min()
        episode_end_time = episode_group['timestamp_seconds'].max()
        episode_duration_ms = (episode_end_time - episode_start_time) * 1000
        episode_frame_count = len(episode_group)
        applied_framerate = episode_group['framerate_applied'].iloc[0]
        
        if episode_duration_ms >= minimum_duration_ms:
            behavior_episodes.append({
                'behavior_type': behavior_type,
                'episode_start_frame': episode_start_frame,
                'episode_end_frame': episode_end_frame,
                'episode_start_time': episode_start_time,
                'episode_end_time': episode_end_time,
                'episode_duration_ms': episode_duration_ms,
                'episode_frame_count': episode_frame_count,
                'framerate_applied': applied_framerate,
                'source_video': episode_group['video_name'].iloc[0] if 'video_name' in episode_group.columns else 'unknown',
                'tracking_id': episode_group['track_name'].iloc[0] if 'track_name' in episode_group.columns else 'track0'
            })
    
    episodes_df = pd.DataFrame(behavior_episodes)
    print(f"Generated {len(episodes_df)} behavior episodes ≥{minimum_duration_ms}ms from {len(behavior_df)} frames")
    
    if len(episodes_df) > 0:
        print(f"Episode duration range: {episodes_df['episode_duration_ms'].min():.0f} - {episodes_df['episode_duration_ms'].max():.0f} ms")
    
    return episodes_df

def synchronize_breathing_with_behaviors(episodes_df, breathing_timestamps, breathing_signal, 
                                       breath_frequency_per_sec, breath_frequency_per_min, 
                                       breath_intervals, interval_timestamps):
    synchronized_data = []
    
    for idx, episode in episodes_df.iterrows():
        episode_start = episode['episode_start_time']
        episode_end = episode['episode_end_time']
        
        time_window = (breathing_timestamps >= episode_start) & (breathing_timestamps <= episode_end)
        episode_breathing_signal = breathing_signal[time_window]
        
        if len(episode_breathing_signal) > 0:
            signal_mean = np.mean(episode_breathing_signal)
            signal_std = np.std(episode_breathing_signal)
            signal_min = np.min(episode_breathing_signal)
            signal_max = np.max(episode_breathing_signal)
            signal_span = signal_max - signal_min
        else:
            signal_mean = signal_std = signal_min = signal_max = signal_span = np.nan
        
        breath_window = (interval_timestamps >= episode_start) & (interval_timestamps <= episode_end)
        episode_frequencies_per_sec = breath_frequency_per_sec[breath_window]
        episode_frequencies_per_min = breath_frequency_per_min[breath_window]
        episode_intervals = breath_intervals[breath_window]
        
        if len(episode_frequencies_per_sec) > 0:
            avg_frequency_per_sec = np.mean(episode_frequencies_per_sec)
            avg_frequency_per_min = np.mean(episode_frequencies_per_min)
            frequency_std_per_sec = np.std(episode_frequencies_per_sec)
            avg_breath_interval = np.mean(episode_intervals)
            interval_std = np.std(episode_intervals)
            breath_count = len(episode_frequencies_per_sec)
        else:
            episode_midpoint = (episode_start + episode_end) / 2
            if len(interval_timestamps) > 0:
                avg_frequency_per_sec = np.interp(episode_midpoint, interval_timestamps, breath_frequency_per_sec)
                avg_frequency_per_min = avg_frequency_per_sec * 60
                avg_breath_interval = 1 / avg_frequency_per_sec if avg_frequency_per_sec > 0 else np.nan
            else:
                avg_frequency_per_sec = avg_frequency_per_min = avg_breath_interval = np.nan
            
            frequency_std_per_sec = interval_std = np.nan
            breath_count = 0
        
        episode_data = {
            **episode.to_dict(),
            'avg_breathing_signal_100hz': signal_mean,
            'std_breathing_signal_100hz': signal_std,
            'min_breathing_signal_100hz': signal_min,
            'max_breathing_signal_100hz': signal_max,
            'breathing_signal_span': signal_span,
            'avg_breath_frequency_per_sec': avg_frequency_per_sec,
            'avg_breath_frequency_per_min': avg_frequency_per_min,
            'std_breath_frequency_per_sec': frequency_std_per_sec,
            'avg_breath_interval_seconds': avg_breath_interval,
            'std_breath_interval_seconds': interval_std,
            'complete_breath_count': breath_count
        }
        
        synchronized_data.append(episode_data)
    
    synchronized_df = pd.DataFrame(synchronized_data)
    print(f"Synchronized breathing data with {len(synchronized_df)} behavior episodes")
    
    return synchronized_df

def execute_full_synchronization_pipeline(h5_file, excel_file, minimum_duration_ms=500):
    print(f"=== Executing synchronization for {os.path.basename(h5_file)} with {os.path.basename(excel_file)} ===")
    
    raw_breathing_data = extract_breathing_signal(h5_file)
    
    filtered_breathing, target_sampling_rate = apply_signal_filtering(raw_breathing_data)
    
    breathing_timestamps = generate_timestamp_array(filtered_breathing, target_sampling_rate)
    
    breath_peaks, breath_intervals, interval_timestamps = find_breath_cycles(filtered_breathing, target_sampling_rate)
    
    if len(breath_intervals) > 0:
        breath_frequency_per_sec, breath_frequency_per_min = compute_breath_frequencies(breath_intervals, interval_timestamps)
    else:
        breath_frequency_per_sec = breath_frequency_per_min = np.array([])
    
    behavior_df, video_framerate = import_behavior_data_with_timing(excel_file)
    
    episodes_df = create_behavior_episodes(behavior_df, minimum_duration_ms)
    
    if len(episodes_df) > 0 and len(breath_intervals) > 0:
        final_synchronized_df = synchronize_breathing_with_behaviors(episodes_df, breathing_timestamps, filtered_breathing,
                                                   breath_frequency_per_sec, breath_frequency_per_min,
                                                   breath_intervals, interval_timestamps)
    else:
        print("No valid data for synchronization")
        return None
    
    h5_base_name = os.path.basename(h5_file).replace('.h5', '')
    excel_base_name = os.path.basename(excel_file).replace('.xlsx', '').replace('.xls', '')
    output_filename = f"SYNCHRONIZED_{excel_base_name}_breathing_data.xlsx"
    
    final_synchronized_df.to_excel(output_filename, index=False)
    print(f"✅ Saved synchronized data: {output_filename}")
    
    if len(final_synchronized_df) > 0:
        valid_frequencies = final_synchronized_df['avg_breath_frequency_per_min'].dropna()
        if len(valid_frequencies) > 0:
            print(f"Summary - Average breath frequency: {valid_frequencies.mean():.1f} breaths/min")
            print(f"Summary - Breath frequency range: {valid_frequencies.min():.1f} - {valid_frequencies.max():.1f} breaths/min")
    
    return final_synchronized_df

def execute_complete_processing_pipeline():
    breathing_data_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
    behavior_data_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
    
    h5_file_list = glob.glob(os.path.join(breathing_data_path, "*.h5"))
    excel_track0_files = glob.glob(os.path.join(behavior_data_path, "*track0*.xlsx"))
    
    print(f"Located {len(h5_file_list)} h5 files and {len(excel_track0_files)} track0 Excel files")
    
    processing_results = {}
    
    for h5_file in h5_file_list:
        h5_identifier = os.path.basename(h5_file).replace('.h5', '')
        
        matched_excel = None
        for excel_file in excel_track0_files:
            identifier_parts = h5_identifier.split('_')
            if len(identifier_parts) >= 3:
                session_identifier = '_'.join(identifier_parts[:3])
                if session_identifier in excel_file:
                    matched_excel = excel_file
                    break
        
        if matched_excel:
            try:
                processing_result = execute_full_synchronization_pipeline(h5_file, matched_excel)
                if processing_result is not None:
                    processing_results[h5_identifier] = processing_result
            except Exception as e:
                print(f"Error processing {h5_identifier}: {e}")
        else:
            print(f"No matching Excel file found for {h5_identifier}")
    
    print(f"\n🎉 COMPLETE PROCESSING PIPELINE FINISHED! 🎉")
    print(f"Successfully processed {len(processing_results)} file pairs")
    
    return processing_results

all_processing_results = execute_complete_processing_pipeline()
# Out:
# Located 18 h5 files and 17 track0 Excel files
# === Executing synchronization for RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5 with top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx ===
# Extracted breathing signal: 12425270 samples
# Signal range: -2873.0 to 5785.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 62127 samples at 100 Hz
# Total duration: 621.27 seconds
# Timestamp array: 0.00 to 621.26 seconds
# Detected 1586 breath cycles
# Breath interval range: 0.250 to 2.060 seconds
# Average breath interval: 0.392 seconds
# Breath frequency range: 0.485 to 4.000 breaths/sec
# Breath frequency range: 29.1 to 240.0 breaths/min
# Average breath frequency: 2.793 breaths/sec (167.6 breaths/min)
# Imported behavior data: (9300, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 15 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 619.93 seconds
# Generated 303 behavior episodes ≥500ms from 9300 frames
# Episode duration range: 533 - 5533 ms
# Synchronized breathing data with 303 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 160.8 breaths/min
# Summary - Breath frequency range: 39.5 - 231.1 breaths/min
# === Executing synchronization for RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5 with top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx ===
# Extracted breathing signal: 12089585 samples
# Signal range: -3505.0 to 6281.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60448 samples at 100 Hz
# Total duration: 604.48 seconds
# Timestamp array: 0.00 to 604.47 seconds
# Detected 1516 breath cycles
# Breath interval range: 0.250 to 5.620 seconds
# Average breath interval: 0.399 seconds
# Breath frequency range: 0.178 to 4.000 breaths/sec
# Breath frequency range: 10.7 to 240.0 breaths/min
# Average breath frequency: 2.783 breaths/sec (167.0 breaths/min)
# Imported behavior data: (18083, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 602.73 seconds
# Generated 266 behavior episodes ≥500ms from 18083 frames
# Episode duration range: 500 - 9300 ms
# Synchronized breathing data with 266 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 156.7 breaths/min
# Summary - Breath frequency range: 10.7 - 228.4 breaths/min
# === Executing synchronization for RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5 with top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx ===
# Extracted breathing signal: 12058916 samples
# Signal range: -2545.0 to 12114.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60295 samples at 100 Hz
# Total duration: 602.95 seconds
# Timestamp array: 0.00 to 602.94 seconds
# Detected 1439 breath cycles
# Breath interval range: 0.250 to 22.320 seconds
# Average breath interval: 0.419 seconds
# Breath frequency range: 0.045 to 4.000 breaths/sec
# Breath frequency range: 2.7 to 240.0 breaths/min
# Average breath frequency: 2.764 breaths/sec (165.8 breaths/min)
# Imported behavior data: (18060, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 15 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 1203.93 seconds
# Generated 504 behavior episodes ≥500ms from 18060 frames
# Episode duration range: 533 - 30333 ms
# Synchronized breathing data with 504 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 139.6 breaths/min
# Summary - Breath frequency range: 2.7 - 240.0 breaths/min
# === Executing synchronization for RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5 with top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx ===
# Extracted breathing signal: 12181909 samples
# Signal range: -2385.0 to 12507.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60910 samples at 100 Hz
# Total duration: 609.10 seconds
# Timestamp array: 0.00 to 609.09 seconds
# Detected 1656 breath cycles
# Breath interval range: 0.250 to 1.440 seconds
# Average breath interval: 0.368 seconds
# Breath frequency range: 0.694 to 4.000 breaths/sec
# Breath frequency range: 41.7 to 240.0 breaths/min
# Average breath frequency: 2.885 breaths/sec (173.1 breaths/min)
# Imported behavior data: (9116, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 303.83 seconds
# Generated 132 behavior episodes ≥500ms from 9116 frames
# Episode duration range: 500 - 6133 ms
# Synchronized breathing data with 132 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 170.4 breaths/min
# Summary - Breath frequency range: 95.2 - 226.7 breaths/min
# No matching Excel file found for RI1_s3_5_p5_4_nRB3_20250621_105014_merged
# === Executing synchronization for RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5 with top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx ===
# Extracted breathing signal: 12065446 samples
# Signal range: -2345.0 to 11978.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60328 samples at 100 Hz
# Total duration: 603.28 seconds
# Timestamp array: 0.00 to 603.27 seconds
# Detected 1509 breath cycles
# Breath interval range: 0.250 to 5.360 seconds
# Average breath interval: 0.400 seconds
# Breath frequency range: 0.187 to 4.000 breaths/sec
# Breath frequency range: 11.2 to 240.0 breaths/min
# Average breath frequency: 2.742 breaths/sec (164.5 breaths/min)
# Imported behavior data: (18064, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 29 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 622.86 seconds
# Generated 289 behavior episodes ≥500ms from 18064 frames
# Episode duration range: 517 - 8759 ms
# Synchronized breathing data with 289 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 160.4 breaths/min
# Summary - Breath frequency range: 12.5 - 240.0 breaths/min
# === Executing synchronization for RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5 with top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx ===
# Extracted breathing signal: 12583112 samples
# Signal range: -1521.0 to 5761.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 62916 samples at 100 Hz
# Total duration: 629.16 seconds
# Timestamp array: 0.00 to 629.15 seconds
# Detected 1624 breath cycles
# Breath interval range: 0.250 to 2.060 seconds
# Average breath interval: 0.388 seconds
# Breath frequency range: 0.485 to 4.000 breaths/sec
# Breath frequency range: 29.1 to 240.0 breaths/min
# Average breath frequency: 2.779 breaths/sec (166.7 breaths/min)
# Imported behavior data: (18699, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 623.27 seconds
# Generated 305 behavior episodes ≥500ms from 18699 frames
# Episode duration range: 500 - 13633 ms
# Synchronized breathing data with 305 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 161.9 breaths/min
# Summary - Breath frequency range: 63.8 - 235.4 breaths/min
# === Executing synchronization for RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5 with top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx ===
# Extracted breathing signal: 12096714 samples
# Signal range: -2777.0 to 6145.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60484 samples at 100 Hz
# Total duration: 604.84 seconds
# Timestamp array: 0.00 to 604.83 seconds
# Detected 1548 breath cycles
# Breath interval range: 0.250 to 10.470 seconds
# Average breath interval: 0.391 seconds
# Breath frequency range: 0.096 to 4.000 breaths/sec
# Breath frequency range: 5.7 to 240.0 breaths/min
# Average breath frequency: 2.835 breaths/sec (170.1 breaths/min)
# Imported behavior data: (18015, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 600.47 seconds
# Generated 303 behavior episodes ≥500ms from 18015 frames
# Episode duration range: 500 - 3867 ms
# Synchronized breathing data with 303 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 163.2 breaths/min
# Summary - Breath frequency range: 8.6 - 240.0 breaths/min
# === Executing synchronization for RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5 with top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx ===
# Extracted breathing signal: 12301849 samples
# Signal range: -2081.0 to 32767.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 61510 samples at 100 Hz
# Total duration: 615.10 seconds
# Timestamp array: 0.00 to 615.09 seconds
# Detected 72 breath cycles
# Breath interval range: 0.250 to 173.820 seconds
# Average breath interval: 7.974 seconds
# Breath frequency range: 0.006 to 4.000 breaths/sec
# Breath frequency range: 0.3 to 240.0 breaths/min
# Average breath frequency: 1.464 breaths/sec (87.9 breaths/min)
# Imported behavior data: (18405, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 613.47 seconds
# Generated 315 behavior episodes ≥500ms from 18405 frames
# Episode duration range: 500 - 8733 ms
# Synchronized breathing data with 315 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 52.6 breaths/min
# Summary - Breath frequency range: 0.6 - 218.6 breaths/min
# === Executing synchronization for RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5 with top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx ===
# Extracted breathing signal: 12095837 samples
# Signal range: -3705.0 to 6065.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60480 samples at 100 Hz
# Total duration: 604.80 seconds
# Timestamp array: 0.00 to 604.79 seconds
# Detected 1583 breath cycles
# Breath interval range: 0.250 to 1.530 seconds
# Average breath interval: 0.382 seconds
# Breath frequency range: 0.654 to 4.000 breaths/sec
# Breath frequency range: 39.2 to 240.0 breaths/min
# Average breath frequency: 2.812 breaths/sec (168.7 breaths/min)
# Imported behavior data: (9053, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 15 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 603.47 seconds
# Generated 221 behavior episodes ≥500ms from 9053 frames
# Episode duration range: 533 - 24000 ms
# Synchronized breathing data with 221 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 165.9 breaths/min
# Summary - Breath frequency range: 70.6 - 231.1 breaths/min
# === Executing synchronization for RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5 with top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx ===
# Extracted breathing signal: 12085347 samples
# Signal range: -1785.0 to 7329.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60427 samples at 100 Hz
# Total duration: 604.27 seconds
# Timestamp array: 0.00 to 604.26 seconds
# Detected 1390 breath cycles
# Breath interval range: 0.250 to 36.810 seconds
# Average breath interval: 0.430 seconds
# Breath frequency range: 0.027 to 4.000 breaths/sec
# Breath frequency range: 1.6 to 240.0 breaths/min
# Average breath frequency: 2.765 breaths/sec (165.9 breaths/min)
# Imported behavior data: (18095, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 603.13 seconds
# Generated 198 behavior episodes ≥500ms from 18095 frames
# Episode duration range: 500 - 36500 ms
# Synchronized breathing data with 198 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 145.6 breaths/min
# Summary - Breath frequency range: 4.4 - 240.0 breaths/min
# === Executing synchronization for RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5 with top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx ===
# Extracted breathing signal: 12184065 samples
# Signal range: -2689.0 to 6329.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60921 samples at 100 Hz
# Total duration: 609.21 seconds
# Timestamp array: 0.00 to 609.20 seconds
# Detected 1443 breath cycles
# Breath interval range: 0.250 to 49.990 seconds
# Average breath interval: 0.420 seconds
# Breath frequency range: 0.020 to 4.000 breaths/sec
# Breath frequency range: 1.2 to 240.0 breaths/min
# Average breath frequency: 2.784 breaths/sec (167.0 breaths/min)
# Imported behavior data: (18153, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 605.07 seconds
# Generated 188 behavior episodes ≥500ms from 18153 frames
# Episode duration range: 500 - 36900 ms
# Synchronized breathing data with 188 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 160.5 breaths/min
# Summary - Breath frequency range: 9.1 - 231.1 breaths/min
# === Executing synchronization for RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5 with top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx ===
# Extracted breathing signal: 12108968 samples
# Signal range: -9387.0 to 13427.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60545 samples at 100 Hz
# Total duration: 605.45 seconds
# Timestamp array: 0.00 to 605.44 seconds
# Detected 1306 breath cycles
# Breath interval range: 0.250 to 37.220 seconds
# Average breath interval: 0.464 seconds
# Breath frequency range: 0.027 to 4.000 breaths/sec
# Breath frequency range: 1.6 to 240.0 breaths/min
# Average breath frequency: 2.725 breaths/sec (163.5 breaths/min)
# Imported behavior data: (9065, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 15 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 604.27 seconds
# Generated 201 behavior episodes ≥500ms from 9065 frames
# Episode duration range: 533 - 28133 ms
# Synchronized breathing data with 201 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 153.5 breaths/min
# Summary - Breath frequency range: 1.8 - 231.1 breaths/min
# === Executing synchronization for RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5 with top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx ===
# Extracted breathing signal: 4266732 samples
# Signal range: -5826.0 to 6193.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 21334 samples at 100 Hz
# Total duration: 213.34 seconds
# Timestamp array: 0.00 to 213.33 seconds
# Detected 556 breath cycles
# Breath interval range: 0.250 to 0.870 seconds
# Average breath interval: 0.382 seconds
# Breath frequency range: 1.149 to 4.000 breaths/sec
# Breath frequency range: 69.0 to 240.0 breaths/min
# Average breath frequency: 2.810 breaths/sec (168.6 breaths/min)
# Imported behavior data: (18062, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 602.03 seconds
# Generated 115 behavior episodes ≥500ms from 18062 frames
# Episode duration range: 500 - 55767 ms
# Synchronized breathing data with 115 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 213.6 breaths/min
# Summary - Breath frequency range: 101.7 - 240.0 breaths/min
# === Executing synchronization for RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5 with top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx ===
# Extracted breathing signal: 12200094 samples
# Signal range: -3001.0 to 14467.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 61001 samples at 100 Hz
# Total duration: 610.01 seconds
# Timestamp array: 0.00 to 610.00 seconds
# Detected 1502 breath cycles
# Breath interval range: 0.250 to 2.040 seconds
# Average breath interval: 0.406 seconds
# Breath frequency range: 0.490 to 4.000 breaths/sec
# Breath frequency range: 29.4 to 240.0 breaths/min
# Average breath frequency: 2.687 breaths/sec (161.2 breaths/min)
# Imported behavior data: (18263, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 608.73 seconds
# Generated 180 behavior episodes ≥500ms from 18263 frames
# Episode duration range: 500 - 26667 ms
# Synchronized breathing data with 180 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 160.4 breaths/min
# Summary - Breath frequency range: 53.6 - 240.0 breaths/min
# === Executing synchronization for RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5 with top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx ===
# Extracted breathing signal: 12129332 samples
# Signal range: -5386.0 to 8602.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60647 samples at 100 Hz
# Total duration: 606.47 seconds
# Timestamp array: 0.00 to 606.46 seconds
# Detected 1559 breath cycles
# Breath interval range: 0.250 to 1.380 seconds
# Average breath interval: 0.389 seconds
# Breath frequency range: 0.725 to 4.000 breaths/sec
# Breath frequency range: 43.5 to 240.0 breaths/min
# Average breath frequency: 2.776 breaths/sec (166.5 breaths/min)
# Imported behavior data: (18158, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 605.23 seconds
# Generated 238 behavior episodes ≥500ms from 18158 frames
# Episode duration range: 500 - 11567 ms
# Synchronized breathing data with 238 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 165.8 breaths/min
# Summary - Breath frequency range: 76.9 - 240.0 breaths/min
# === Executing synchronization for RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5 with top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx ===
# Extracted breathing signal: 12064729 samples
# Signal range: -4834.0 to 5785.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 60324 samples at 100 Hz
# Total duration: 603.24 seconds
# Timestamp array: 0.00 to 603.23 seconds
# Detected 1494 breath cycles
# Breath interval range: 0.250 to 1.300 seconds
# Average breath interval: 0.404 seconds
# Breath frequency range: 0.769 to 4.000 breaths/sec
# Breath frequency range: 46.2 to 240.0 breaths/min
# Average breath frequency: 2.667 breaths/sec (160.0 breaths/min)
# Imported behavior data: (18065, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 602.13 seconds
# Generated 197 behavior episodes ≥500ms from 18065 frames
# Episode duration range: 500 - 22000 ms
# Synchronized breathing data with 197 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 160.2 breaths/min
# Summary - Breath frequency range: 88.2 - 227.1 breaths/min
# === Executing synchronization for RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5 with top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx ===
# Extracted breathing signal: 9780589 samples
# Signal range: 904.0 to 984.0
# Source sampling rate: 20000 Hz
# Output sampling rate: 100 Hz
# Signal filtered with cutoff: 50.0 Hz
# Signal reduced by factor 200: 48903 samples at 100 Hz
# Total duration: 489.03 seconds
# Timestamp array: 0.00 to 489.02 seconds
# Detected 808 breath cycles
# Breath interval range: 0.250 to 14.400 seconds
# Average breath interval: 0.601 seconds
# Breath frequency range: 0.069 to 4.000 breaths/sec
# Breath frequency range: 4.2 to 240.0 breaths/min
# Average breath frequency: 2.425 breaths/sec (145.5 breaths/min)
# Imported behavior data: (14654, 5)
# Data columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Applied 30 FPS for frame-to-time conversion
# Behavior timestamp range: 0.00 to 488.43 seconds
# Generated 188 behavior episodes ≥500ms from 14654 frames
# Episode duration range: 500 - 25600 ms
# Synchronized breathing data with 188 behavior episodes
# ✅ Saved synchronized data: SYNCHRONIZED_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables_breathing_data.xlsx
# Summary - Average breath frequency: 129.2 breaths/min
# Summary - Breath frequency range: 4.8 - 218.8 breaths/min
#
# 🎉 COMPLETE PROCESSING PIPELINE FINISHED! 🎉
# Successfully processed 17 file pairs

# %%
def create_master_synchronized_files():
    synchronized_files = glob.glob("SYNCHRONIZED_*_breathing_data.xlsx")
    
    ri1_files = [f for f in synchronized_files if "-RI1_" in f]
    ri2_files = [f for f in synchronized_files if "-RI2_" in f]
    
    print(f"Found {len(ri1_files)} RI1 synchronized files and {len(ri2_files)} RI2 synchronized files")
    
    def create_master_synchronized_file(files, output_name):
        print(f"\nCreating {output_name}...")
        
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"  Added sheet: {sheet_name} ({df.shape[0]} behavior episodes)")
        
        print(f"✅ Saved: {output_name}")
    
    if ri1_files:
        create_master_synchronized_file(ri1_files, "RI1_MASTER_Synchronized_Breathing_Behavior.xlsx")
    
    if ri2_files:
        create_master_synchronized_file(ri2_files, "RI2_MASTER_Synchronized_Breathing_Behavior.xlsx")
    
    return len(ri1_files), len(ri2_files)

ri1_count, ri2_count = create_master_synchronized_files()

print(f"\n🎉 MASTER SYNCHRONIZED FILES CREATED! 🎉")
print(f"📁 RI1_MASTER_Synchronized_Breathing_Behavior.xlsx ({ri1_count} sheets)")
print(f"📁 RI2_MASTER_Synchronized_Breathing_Behavior.xlsx ({ri2_count} sheets)")
print(f"\nEach sheet contains behavior EPISODES (≥500ms) with:")
print(f"  ✓ Breathing signal statistics per behavior episode")
print(f"  ✓ Breath frequency in breaths/sec AND breaths/min")
print(f"  ✓ Inter-breath intervals (IBI) in seconds")
print(f"  ✓ Only track0 data")
print(f"  ✓ Proper FPS conversion (15/29/30 FPS)")
print(f"  ✓ Episode duration, frame count, and timing info")
# Out:
# Found 8 RI1 synchronized files and 9 RI2 synchronized files
#
# Creating RI1_MASTER_Synchronized_Breathing_Behavior.xlsx...
#   Added sheet: RI1_s1_1_p5_track0 (303 behavior episodes)
#   Added sheet: RI1_s1_2_p5_track0 (266 behavior episodes)
#   Added sheet: RI1_s2_3_p5_track0 (504 behavior episodes)
#   Added sheet: RI1_s2_4_p5_track0 (132 behavior episodes)
#   Added sheet: RI1_s3_6_p5_track0 (289 behavior episodes)
#   Added sheet: RI1_s4_7_p5_track0 (305 behavior episodes)
#   Added sheet: RI1_s4_8_p5_track0 (303 behavior episodes)
#   Added sheet: RI1_s5_13_p5_track0 (315 behavior episodes)
# ✅ Saved: RI1_MASTER_Synchronized_Breathing_Behavior.xlsx
#
# Creating RI2_MASTER_Synchronized_Breathing_Behavior.xlsx...
#   Added sheet: RI2_s1_1_p5_track0 (221 behavior episodes)
#   Added sheet: RI2_s1_2_p5_track0 (198 behavior episodes)
#   Added sheet: RI2_s2_3_p5_track0 (188 behavior episodes)
#   Added sheet: RI2_s2_4_p5_track0 (201 behavior episodes)
#   Added sheet: RI2_s3_5_p5_track0 (115 behavior episodes)
#   Added sheet: RI2_s3_6_p_track0 (180 behavior episodes)
#   Added sheet: RI2_s4_7_p5_track0 (238 behavior episodes)
#   Added sheet: RI2_s4_8_p5_track0 (197 behavior episodes)
#   Added sheet: RI2_s5_13_p5_track0 (188 behavior episodes)
# ✅ Saved: RI2_MASTER_Synchronized_Breathing_Behavior.xlsx
#
# 🎉 MASTER SYNCHRONIZED FILES CREATED! 🎉
# 📁 RI1_MASTER_Synchronized_Breathing_Behavior.xlsx (8 sheets)
# 📁 RI2_MASTER_Synchronized_Breathing_Behavior.xlsx (9 sheets)
#
# Each sheet contains behavior EPISODES (≥500ms) with:
#   ✓ Breathing signal statistics per behavior episode
#   ✓ Breath frequency in breaths/sec AND breaths/min
#   ✓ Inter-breath intervals (IBI) in seconds
#   ✓ Only track0 data
#   ✓ Proper FPS conversion (15/29/30 FPS)
#   ✓ Episode duration, frame count, and timing info

# %%
import h5py
import numpy as np
import pandas as pd
from scipy import signal
import glob
import os
import matplotlib.pyplot as plt

def load_respiratory_data(h5_file_path):
    with h5py.File(h5_file_path, 'r') as f:
        data = f['resp'][:].flatten()
        print(f"Loaded respiratory data: {len(data)} samples")
        print(f"Data range: {data.min():.1f} to {data.max():.1f}")
    return data

def filter_respiratory_signal(data, original_fs=20000, target_fs=100):
    print(f"Original sampling rate: {original_fs} Hz")
    print(f"Target sampling rate: {target_fs} Hz")
    
    nyquist = original_fs / 2
    cutoff = target_fs / 2
    
    b, a = signal.butter(5, cutoff/nyquist, 'low')
    filtered = signal.filtfilt(b, a, data)
    print(f"Applied filter with cutoff: {cutoff} Hz")
    
    downsample_factor = original_fs // target_fs
    downsampled = filtered[::downsample_factor]
    
    print(f"Downsampled by factor {downsample_factor}: {len(downsampled)} samples at {target_fs} Hz")
    print(f"Duration: {len(downsampled) / target_fs:.2f} seconds")
    
    return downsampled, target_fs

def create_time_vector(signal_data, fs):
    time_vec = np.arange(len(signal_data)) / fs
    print(f"Time vector: 0.00 to {time_vec[-1]:.2f} seconds")
    return time_vec

def detect_breathing_events(signal_data, fs=100):
    normalized = (signal_data - np.mean(signal_data)) / np.std(signal_data)
    
    min_distance = fs // 4
    prominence = 0.5
    height = 0.1
    
    peaks, _ = signal.find_peaks(normalized, distance=min_distance, prominence=prominence, height=height)
    
    print(f"Found {len(peaks)} breathing events")
    
    if len(peaks) < 2:
        print("Warning: Not enough events detected")
        return np.array([]), np.array([]), np.array([])
    
    peak_times = peaks / fs
    intervals = np.diff(peak_times)
    interval_times = peak_times[1:]
    
    print(f"Interval range: {intervals.min():.3f} to {intervals.max():.3f} seconds")
    print(f"Mean interval: {intervals.mean():.3f} seconds")
    
    return peaks, intervals, interval_times

def calculate_breathing_rates(intervals, times):
    rates_per_sec = 1 / intervals
    rates_per_min = rates_per_sec * 60
    
    print(f"Rate range: {rates_per_sec.min():.3f} to {rates_per_sec.max():.3f} breaths/sec")
    print(f"Rate range: {rates_per_min.min():.1f} to {rates_per_min.max():.1f} breaths/min")
    print(f"Mean rate: {rates_per_sec.mean():.3f} breaths/sec ({rates_per_min.mean():.1f} breaths/min)")
    
    return rates_per_sec, rates_per_min

def get_video_fps(filename):
    fps_dict = {
        "RI1_s1_1": 15,
        "RI1_s2_3": 15,
        "RI1_s3_6": 29,
        "RI2_s1_1": 15,
        "RI2_s2_4": 15
    }
    
    for key, fps in fps_dict.items():
        if key in filename:
            return fps
    return 30

def load_behavior_data(excel_path):
    df = pd.read_excel(excel_path)
    print(f"Loaded behavior data: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    
    fps = get_video_fps(os.path.basename(excel_path))
    print(f"Using {fps} FPS for conversion")
    
    df['time_sec'] = df['frame_number'] / fps
    df['fps'] = fps
    
    print(f"Time range: {df['time_sec'].min():.2f} to {df['time_sec'].max():.2f} seconds")
    
    return df, fps

def group_behavior_bouts(df, min_duration=500):
    df['transition'] = (df['syllable'] != df['syllable'].shift()).astype(int)
    df['group'] = df['transition'].cumsum()
    
    bouts = []
    
    for group_id, group in df.groupby('group'):
        syllable = group['syllable'].iloc[0]
        start_frame = group['frame_number'].min()
        end_frame = group['frame_number'].max()
        start_time = group['time_sec'].min()
        end_time = group['time_sec'].max()
        duration = (end_time - start_time) * 1000
        frame_count = len(group)
        fps = group['fps'].iloc[0]
        
        if duration >= min_duration:
            bouts.append({
                'syllable': syllable,
                'start_frame': start_frame,
                'end_frame': end_frame,
                'start_time': start_time,
                'end_time': end_time,
                'duration_ms': duration,
                'frame_count': frame_count,
                'fps': fps,
                'video': group['video_name'].iloc[0] if 'video_name' in group.columns else 'unknown',
                'track': group['track_name'].iloc[0] if 'track_name' in group.columns else 'track0'
            })
    
    bout_df = pd.DataFrame(bouts)
    print(f"Created {len(bout_df)} bouts ≥{min_duration}ms from {len(df)} frames")
    
    if len(bout_df) > 0:
        print(f"Duration range: {bout_df['duration_ms'].min():.0f} - {bout_df['duration_ms'].max():.0f} ms")
    
    return bout_df

def align_respiratory_behavioral_data(bouts, time_vec, signal_data, rates_per_sec, rates_per_min, intervals, interval_times):
    results = []
    
    for idx, bout in bouts.iterrows():
        start = bout['start_time']
        end = bout['end_time']
        
        signal_mask = (time_vec >= start) & (time_vec <= end)
        bout_signal = signal_data[signal_mask]
        
        if len(bout_signal) > 0:
            sig_mean = np.mean(bout_signal)
            sig_min = np.min(bout_signal)
            sig_max = np.max(bout_signal)
            sig_range = sig_max - sig_min
        else:
            sig_mean = sig_min = sig_max = sig_range = np.nan
        
        rate_mask = (interval_times >= start) & (interval_times <= end)
        bout_rates_sec = rates_per_sec[rate_mask]
        bout_rates_min = rates_per_min[rate_mask]
        bout_intervals = intervals[rate_mask]
        
        if len(bout_rates_sec) > 0:
            mean_rate_sec = np.mean(bout_rates_sec)
            mean_rate_min = np.mean(bout_rates_min)
            mean_interval = np.mean(bout_intervals)
            breath_count = len(bout_rates_sec)
        else:
            mid_time = (start + end) / 2
            if len(interval_times) > 0:
                mean_rate_sec = np.interp(mid_time, interval_times, rates_per_sec)
                mean_rate_min = mean_rate_sec * 60
                mean_interval = 1 / mean_rate_sec if mean_rate_sec > 0 else np.nan
            else:
                mean_rate_sec = mean_rate_min = mean_interval = np.nan
            
            breath_count = 0
        
        result = {
            **bout.to_dict(),
            'mean_resp_100hz': sig_mean,
            'min_resp_100hz': sig_min,
            'max_resp_100hz': sig_max,
            'resp_range': sig_range,
            'mean_rate_per_sec': mean_rate_sec,
            'mean_rate_per_min': mean_rate_min,
            'mean_interval_sec': mean_interval,
            'breath_count': breath_count
        }
        
        results.append(result)
    
    result_df = pd.DataFrame(results)
    print(f"Aligned data for {len(result_df)} behavioral bouts")
    
    return result_df

def process_session(h5_file, excel_file, min_duration=500):
    print(f"=== Processing {os.path.basename(h5_file)} with {os.path.basename(excel_file)} ===")
    
    resp_data = load_respiratory_data(h5_file)
    filtered_resp, fs = filter_respiratory_signal(resp_data)
    time_vec = create_time_vector(filtered_resp, fs)
    peaks, intervals, interval_times = detect_breathing_events(filtered_resp, fs)
    
    if len(intervals) > 0:
        rates_sec, rates_min = calculate_breathing_rates(intervals, interval_times)
    else:
        rates_sec = rates_min = np.array([])
    
    behavior_df, fps = load_behavior_data(excel_file)
    bouts = group_behavior_bouts(behavior_df, min_duration)
    
    if len(bouts) > 0 and len(intervals) > 0:
        final_df = align_respiratory_behavioral_data(bouts, time_vec, filtered_resp, rates_sec, rates_min, intervals, interval_times)
    else:
        print("No valid data for alignment")
        return None
    
    h5_name = os.path.basename(h5_file).replace('.h5', '')
    excel_name = os.path.basename(excel_file).replace('.xlsx', '').replace('.xls', '')
    output_file = f"FINAL_PROCESSED_{excel_name}_no_std.xlsx"
    
    final_df.to_excel(output_file, index=False)
    print(f"Saved data: {output_file}")
    
    if len(final_df) > 0:
        valid_rates = final_df['mean_rate_per_min'].dropna()
        if len(valid_rates) > 0:
            print(f"Mean breathing rate: {valid_rates.mean():.1f} breaths/min")
            print(f"Rate range: {valid_rates.min():.1f} - {valid_rates.max():.1f} breaths/min")
    
    return final_df

def run_analysis():
    resp_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
    behavior_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
    
    h5_files = glob.glob(os.path.join(resp_dir, "*.h5"))
    excel_files = glob.glob(os.path.join(behavior_dir, "*track0*.xlsx"))
    
    print(f"Found {len(h5_files)} h5 files and {len(excel_files)} Excel files")
    
    results = {}
    
    for h5_file in h5_files:
        h5_id = os.path.basename(h5_file).replace('.h5', '')
        
        matched_excel = None
        for excel_file in excel_files:
            parts = h5_id.split('_')
            if len(parts) >= 3:
                session_id = '_'.join(parts[:3])
                if session_id in excel_file:
                    matched_excel = excel_file
                    break
        
        if matched_excel:
            try:
                result = process_session(h5_file, matched_excel)
                if result is not None:
                    results[h5_id] = result
            except Exception as e:
                print(f"Error processing {h5_id}: {e}")
        else:
            print(f"No matching file found for {h5_id}")
    
    print(f"\nAnalysis complete")
    print(f"Processed {len(results)} sessions")
    
    return results

def create_master_files_no_std():
    processed_files = glob.glob("FINAL_PROCESSED_*_no_std.xlsx")
    
    ri1_files = [f for f in processed_files if "-RI1_" in f]
    ri2_files = [f for f in processed_files if "-RI2_" in f]
    
    print(f"Found {len(ri1_files)} RI1 files and {len(ri2_files)} RI2 files")
    
    def create_master_file(files, output_name):
        print(f"\nCreating {output_name}...")
        
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"  Added sheet: {sheet_name} ({df.shape[0]} behavioral bouts)")
        
        print(f"Saved: {output_name}")
    
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_NoStd_Respiratory_Behavioral.xlsx")
    
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_NoStd_Respiratory_Behavioral.xlsx")
    
    return len(ri1_files), len(ri2_files)

analysis_results = run_analysis()

ri1_count, ri2_count = create_master_files_no_std()

print(f"\nMaster files created without standard deviations")
print(f"RI1_MASTER_NoStd_Respiratory_Behavioral.xlsx ({ri1_count} sheets)")
print(f"RI2_MASTER_NoStd_Respiratory_Behavioral.xlsx ({ri2_count} sheets)")
# Out:
# Found 18 h5 files and 17 Excel files
# === Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5 with top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx ===
# Loaded respiratory data: 12425270 samples
# Data range: -2873.0 to 5785.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 62127 samples at 100 Hz
# Duration: 621.27 seconds
# Time vector: 0.00 to 621.26 seconds
# Found 1586 breathing events
# Interval range: 0.250 to 2.060 seconds
# Mean interval: 0.392 seconds
# Rate range: 0.485 to 4.000 breaths/sec
# Rate range: 29.1 to 240.0 breaths/min
# Mean rate: 2.793 breaths/sec (167.6 breaths/min)
# Loaded behavior data: (9300, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 15 FPS for conversion
# Time range: 0.00 to 619.93 seconds
# Created 303 bouts ≥500ms from 9300 frames
# Duration range: 533 - 5533 ms
# Aligned data for 303 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables_no_std.xlsx
# Mean breathing rate: 160.8 breaths/min
# Rate range: 39.5 - 231.1 breaths/min
# === Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5 with top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx ===
# Loaded respiratory data: 12089585 samples
# Data range: -3505.0 to 6281.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60448 samples at 100 Hz
# Duration: 604.48 seconds
# Time vector: 0.00 to 604.47 seconds
# Found 1516 breathing events
# Interval range: 0.250 to 5.620 seconds
# Mean interval: 0.399 seconds
# Rate range: 0.178 to 4.000 breaths/sec
# Rate range: 10.7 to 240.0 breaths/min
# Mean rate: 2.783 breaths/sec (167.0 breaths/min)
# Loaded behavior data: (18083, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 602.73 seconds
# Created 266 bouts ≥500ms from 18083 frames
# Duration range: 500 - 9300 ms
# Aligned data for 266 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables_no_std.xlsx
# Mean breathing rate: 156.7 breaths/min
# Rate range: 10.7 - 228.4 breaths/min
# === Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5 with top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx ===
# Loaded respiratory data: 12058916 samples
# Data range: -2545.0 to 12114.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60295 samples at 100 Hz
# Duration: 602.95 seconds
# Time vector: 0.00 to 602.94 seconds
# Found 1439 breathing events
# Interval range: 0.250 to 22.320 seconds
# Mean interval: 0.419 seconds
# Rate range: 0.045 to 4.000 breaths/sec
# Rate range: 2.7 to 240.0 breaths/min
# Mean rate: 2.764 breaths/sec (165.8 breaths/min)
# Loaded behavior data: (18060, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 15 FPS for conversion
# Time range: 0.00 to 1203.93 seconds
# Created 504 bouts ≥500ms from 18060 frames
# Duration range: 533 - 30333 ms
# Aligned data for 504 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables_no_std.xlsx
# Mean breathing rate: 139.6 breaths/min
# Rate range: 2.7 - 240.0 breaths/min
# === Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5 with top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx ===
# Loaded respiratory data: 12181909 samples
# Data range: -2385.0 to 12507.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60910 samples at 100 Hz
# Duration: 609.10 seconds
# Time vector: 0.00 to 609.09 seconds
# Found 1656 breathing events
# Interval range: 0.250 to 1.440 seconds
# Mean interval: 0.368 seconds
# Rate range: 0.694 to 4.000 breaths/sec
# Rate range: 41.7 to 240.0 breaths/min
# Mean rate: 2.885 breaths/sec (173.1 breaths/min)
# Loaded behavior data: (9116, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 303.83 seconds
# Created 132 bouts ≥500ms from 9116 frames
# Duration range: 500 - 6133 ms
# Aligned data for 132 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables_no_std.xlsx
# Mean breathing rate: 170.4 breaths/min
# Rate range: 95.2 - 226.7 breaths/min
# No matching file found for RI1_s3_5_p5_4_nRB3_20250621_105014_merged
# === Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5 with top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx ===
# Loaded respiratory data: 12065446 samples
# Data range: -2345.0 to 11978.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60328 samples at 100 Hz
# Duration: 603.28 seconds
# Time vector: 0.00 to 603.27 seconds
# Found 1509 breathing events
# Interval range: 0.250 to 5.360 seconds
# Mean interval: 0.400 seconds
# Rate range: 0.187 to 4.000 breaths/sec
# Rate range: 11.2 to 240.0 breaths/min
# Mean rate: 2.742 breaths/sec (164.5 breaths/min)
# Loaded behavior data: (18064, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 29 FPS for conversion
# Time range: 0.00 to 622.86 seconds
# Created 289 bouts ≥500ms from 18064 frames
# Duration range: 517 - 8759 ms
# Aligned data for 289 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables_no_std.xlsx
# Mean breathing rate: 160.4 breaths/min
# Rate range: 12.5 - 240.0 breaths/min
# === Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5 with top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx ===
# Loaded respiratory data: 12583112 samples
# Data range: -1521.0 to 5761.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 62916 samples at 100 Hz
# Duration: 629.16 seconds
# Time vector: 0.00 to 629.15 seconds
# Found 1624 breathing events
# Interval range: 0.250 to 2.060 seconds
# Mean interval: 0.388 seconds
# Rate range: 0.485 to 4.000 breaths/sec
# Rate range: 29.1 to 240.0 breaths/min
# Mean rate: 2.779 breaths/sec (166.7 breaths/min)
# Loaded behavior data: (18699, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 623.27 seconds
# Created 305 bouts ≥500ms from 18699 frames
# Duration range: 500 - 13633 ms
# Aligned data for 305 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables_no_std.xlsx
# Mean breathing rate: 161.9 breaths/min
# Rate range: 63.8 - 235.4 breaths/min
# === Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5 with top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx ===
# Loaded respiratory data: 12096714 samples
# Data range: -2777.0 to 6145.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60484 samples at 100 Hz
# Duration: 604.84 seconds
# Time vector: 0.00 to 604.83 seconds
# Found 1548 breathing events
# Interval range: 0.250 to 10.470 seconds
# Mean interval: 0.391 seconds
# Rate range: 0.096 to 4.000 breaths/sec
# Rate range: 5.7 to 240.0 breaths/min
# Mean rate: 2.835 breaths/sec (170.1 breaths/min)
# Loaded behavior data: (18015, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 600.47 seconds
# Created 303 bouts ≥500ms from 18015 frames
# Duration range: 500 - 3867 ms
# Aligned data for 303 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables_no_std.xlsx
# Mean breathing rate: 163.2 breaths/min
# Rate range: 8.6 - 240.0 breaths/min
# === Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5 with top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx ===
# Loaded respiratory data: 12301849 samples
# Data range: -2081.0 to 32767.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 61510 samples at 100 Hz
# Duration: 615.10 seconds
# Time vector: 0.00 to 615.09 seconds
# Found 72 breathing events
# Interval range: 0.250 to 173.820 seconds
# Mean interval: 7.974 seconds
# Rate range: 0.006 to 4.000 breaths/sec
# Rate range: 0.3 to 240.0 breaths/min
# Mean rate: 1.464 breaths/sec (87.9 breaths/min)
# Loaded behavior data: (18405, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 613.47 seconds
# Created 315 bouts ≥500ms from 18405 frames
# Duration range: 500 - 8733 ms
# Aligned data for 315 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables_no_std.xlsx
# Mean breathing rate: 52.6 breaths/min
# Rate range: 0.6 - 218.6 breaths/min
# === Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5 with top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx ===
# Loaded respiratory data: 12095837 samples
# Data range: -3705.0 to 6065.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60480 samples at 100 Hz
# Duration: 604.80 seconds
# Time vector: 0.00 to 604.79 seconds
# Found 1583 breathing events
# Interval range: 0.250 to 1.530 seconds
# Mean interval: 0.382 seconds
# Rate range: 0.654 to 4.000 breaths/sec
# Rate range: 39.2 to 240.0 breaths/min
# Mean rate: 2.812 breaths/sec (168.7 breaths/min)
# Loaded behavior data: (9053, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 15 FPS for conversion
# Time range: 0.00 to 603.47 seconds
# Created 221 bouts ≥500ms from 9053 frames
# Duration range: 533 - 24000 ms
# Aligned data for 221 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables_no_std.xlsx
# Mean breathing rate: 165.9 breaths/min
# Rate range: 70.6 - 231.1 breaths/min
# === Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5 with top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx ===
# Loaded respiratory data: 12085347 samples
# Data range: -1785.0 to 7329.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60427 samples at 100 Hz
# Duration: 604.27 seconds
# Time vector: 0.00 to 604.26 seconds
# Found 1390 breathing events
# Interval range: 0.250 to 36.810 seconds
# Mean interval: 0.430 seconds
# Rate range: 0.027 to 4.000 breaths/sec
# Rate range: 1.6 to 240.0 breaths/min
# Mean rate: 2.765 breaths/sec (165.9 breaths/min)
# Loaded behavior data: (18095, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 603.13 seconds
# Created 198 bouts ≥500ms from 18095 frames
# Duration range: 500 - 36500 ms
# Aligned data for 198 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables_no_std.xlsx
# Mean breathing rate: 145.6 breaths/min
# Rate range: 4.4 - 240.0 breaths/min
# === Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5 with top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx ===
# Loaded respiratory data: 12184065 samples
# Data range: -2689.0 to 6329.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60921 samples at 100 Hz
# Duration: 609.21 seconds
# Time vector: 0.00 to 609.20 seconds
# Found 1443 breathing events
# Interval range: 0.250 to 49.990 seconds
# Mean interval: 0.420 seconds
# Rate range: 0.020 to 4.000 breaths/sec
# Rate range: 1.2 to 240.0 breaths/min
# Mean rate: 2.784 breaths/sec (167.0 breaths/min)
# Loaded behavior data: (18153, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 605.07 seconds
# Created 188 bouts ≥500ms from 18153 frames
# Duration range: 500 - 36900 ms
# Aligned data for 188 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables_no_std.xlsx
# Mean breathing rate: 160.5 breaths/min
# Rate range: 9.1 - 231.1 breaths/min
# === Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5 with top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx ===
# Loaded respiratory data: 12108968 samples
# Data range: -9387.0 to 13427.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60545 samples at 100 Hz
# Duration: 605.45 seconds
# Time vector: 0.00 to 605.44 seconds
# Found 1306 breathing events
# Interval range: 0.250 to 37.220 seconds
# Mean interval: 0.464 seconds
# Rate range: 0.027 to 4.000 breaths/sec
# Rate range: 1.6 to 240.0 breaths/min
# Mean rate: 2.725 breaths/sec (163.5 breaths/min)
# Loaded behavior data: (9065, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 15 FPS for conversion
# Time range: 0.00 to 604.27 seconds
# Created 201 bouts ≥500ms from 9065 frames
# Duration range: 533 - 28133 ms
# Aligned data for 201 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables_no_std.xlsx
# Mean breathing rate: 153.5 breaths/min
# Rate range: 1.8 - 231.1 breaths/min
# === Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5 with top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx ===
# Loaded respiratory data: 4266732 samples
# Data range: -5826.0 to 6193.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 21334 samples at 100 Hz
# Duration: 213.34 seconds
# Time vector: 0.00 to 213.33 seconds
# Found 556 breathing events
# Interval range: 0.250 to 0.870 seconds
# Mean interval: 0.382 seconds
# Rate range: 1.149 to 4.000 breaths/sec
# Rate range: 69.0 to 240.0 breaths/min
# Mean rate: 2.810 breaths/sec (168.6 breaths/min)
# Loaded behavior data: (18062, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 602.03 seconds
# Created 115 bouts ≥500ms from 18062 frames
# Duration range: 500 - 55767 ms
# Aligned data for 115 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables_no_std.xlsx
# Mean breathing rate: 213.6 breaths/min
# Rate range: 101.7 - 240.0 breaths/min
# === Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5 with top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx ===
# Loaded respiratory data: 12200094 samples
# Data range: -3001.0 to 14467.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 61001 samples at 100 Hz
# Duration: 610.01 seconds
# Time vector: 0.00 to 610.00 seconds
# Found 1502 breathing events
# Interval range: 0.250 to 2.040 seconds
# Mean interval: 0.406 seconds
# Rate range: 0.490 to 4.000 breaths/sec
# Rate range: 29.4 to 240.0 breaths/min
# Mean rate: 2.687 breaths/sec (161.2 breaths/min)
# Loaded behavior data: (18263, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 608.73 seconds
# Created 180 bouts ≥500ms from 18263 frames
# Duration range: 500 - 26667 ms
# Aligned data for 180 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables_no_std.xlsx
# Mean breathing rate: 160.4 breaths/min
# Rate range: 53.6 - 240.0 breaths/min
# === Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5 with top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx ===
# Loaded respiratory data: 12129332 samples
# Data range: -5386.0 to 8602.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60647 samples at 100 Hz
# Duration: 606.47 seconds
# Time vector: 0.00 to 606.46 seconds
# Found 1559 breathing events
# Interval range: 0.250 to 1.380 seconds
# Mean interval: 0.389 seconds
# Rate range: 0.725 to 4.000 breaths/sec
# Rate range: 43.5 to 240.0 breaths/min
# Mean rate: 2.776 breaths/sec (166.5 breaths/min)
# Loaded behavior data: (18158, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 605.23 seconds
# Created 238 bouts ≥500ms from 18158 frames
# Duration range: 500 - 11567 ms
# Aligned data for 238 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables_no_std.xlsx
# Mean breathing rate: 165.8 breaths/min
# Rate range: 76.9 - 240.0 breaths/min
# === Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5 with top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx ===
# Loaded respiratory data: 12064729 samples
# Data range: -4834.0 to 5785.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 60324 samples at 100 Hz
# Duration: 603.24 seconds
# Time vector: 0.00 to 603.23 seconds
# Found 1494 breathing events
# Interval range: 0.250 to 1.300 seconds
# Mean interval: 0.404 seconds
# Rate range: 0.769 to 4.000 breaths/sec
# Rate range: 46.2 to 240.0 breaths/min
# Mean rate: 2.667 breaths/sec (160.0 breaths/min)
# Loaded behavior data: (18065, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 602.13 seconds
# Created 197 bouts ≥500ms from 18065 frames
# Duration range: 500 - 22000 ms
# Aligned data for 197 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables_no_std.xlsx
# Mean breathing rate: 160.2 breaths/min
# Rate range: 88.2 - 227.1 breaths/min
# === Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5 with top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx ===
# Loaded respiratory data: 9780589 samples
# Data range: 904.0 to 984.0
# Original sampling rate: 20000 Hz
# Target sampling rate: 100 Hz
# Applied filter with cutoff: 50.0 Hz
# Downsampled by factor 200: 48903 samples at 100 Hz
# Duration: 489.03 seconds
# Time vector: 0.00 to 489.02 seconds
# Found 808 breathing events
# Interval range: 0.250 to 14.400 seconds
# Mean interval: 0.601 seconds
# Rate range: 0.069 to 4.000 breaths/sec
# Rate range: 4.2 to 240.0 breaths/min
# Mean rate: 2.425 breaths/sec (145.5 breaths/min)
# Loaded behavior data: (14654, 5)
# Columns: ['frame_number', 'syllable', 'video_name', 'track_name', 'track_number']
# Using 30 FPS for conversion
# Time range: 0.00 to 488.43 seconds
# Created 188 bouts ≥500ms from 14654 frames
# Duration range: 500 - 25600 ms
# Aligned data for 188 behavioral bouts
# Saved data: FINAL_PROCESSED_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables_no_std.xlsx
# Mean breathing rate: 129.2 breaths/min
# Rate range: 4.8 - 218.8 breaths/min
#
# Analysis complete
# Processed 17 sessions
# Found 8 RI1 files and 9 RI2 files
#
# Creating RI1_MASTER_NoStd_Respiratory_Behavioral.xlsx...
#   Added sheet: RI1_s1_1_p5_track0 (303 behavioral bouts)
#   Added sheet: RI1_s1_2_p5_track0 (266 behavioral bouts)
#   Added sheet: RI1_s2_3_p5_track0 (504 behavioral bouts)
#   Added sheet: RI1_s2_4_p5_track0 (132 behavioral bouts)
#   Added sheet: RI1_s3_6_p5_track0 (289 behavioral bouts)
#   Added sheet: RI1_s4_7_p5_track0 (305 behavioral bouts)
#   Added sheet: RI1_s4_8_p5_track0 (303 behavioral bouts)
#   Added sheet: RI1_s5_13_p5_track0 (315 behavioral bouts)
# Saved: RI1_MASTER_NoStd_Respiratory_Behavioral.xlsx
#
# Creating RI2_MASTER_NoStd_Respiratory_Behavioral.xlsx...
#   Added sheet: RI2_s1_1_p5_track0 (221 behavioral bouts)
#   Added sheet: RI2_s1_2_p5_track0 (198 behavioral bouts)
#   Added sheet: RI2_s2_3_p5_track0 (188 behavioral bouts)
#   Added sheet: RI2_s2_4_p5_track0 (201 behavioral bouts)
#   Added sheet: RI2_s3_5_p5_track0 (115 behavioral bouts)
#   Added sheet: RI2_s3_6_p_track0 (180 behavioral bouts)
#   Added sheet: RI2_s4_7_p5_track0 (238 behavioral bouts)
#   Added sheet: RI2_s4_8_p5_track0 (197 behavioral bouts)
#   Added sheet: RI2_s5_13_p5_track0 (188 behavioral bouts)
# Saved: RI2_MASTER_NoStd_Respiratory_Behavioral.xlsx
#
# Master files created without standard deviations
# RI1_MASTER_NoStd_Respiratory_Behavioral.xlsx (8 sheets)
# RI2_MASTER_NoStd_Respiratory_Behavioral.xlsx (9 sheets)

# %%
import numpy as np
from scipy.signal import find_peaks

def align_respiratory_behavioral_data(bouts, time_vec, signal_data, rates_per_sec, rates_per_min, intervals, interval_times, sampling_rate=100):
    results = []
    
    for idx, bout in bouts.iterrows():
        start = bout['start_time']
        end = bout['end_time']
        
        # Extract respiratory signal for this bout
        signal_mask = (time_vec >= start) & (time_vec <= end)
        bout_signal = signal_data[signal_mask]
        bout_time = time_vec[signal_mask]
        
        # Default values
        sig_mean = sig_min = sig_max = sig_range = np.nan
        mean_rate_sec = mean_rate_min = mean_interval = np.nan
        breath_count = 0
        ibi = []
        inst_rates = []
        
        if len(bout_signal) > 0:
            # Basic respiratory signal stats
            sig_mean = np.mean(bout_signal)
            sig_min = np.min(bout_signal)
            sig_max = np.max(bout_signal)
            sig_range = sig_max - sig_min

            # --- NEW: Instantaneous breathing rate calculation ---
            peaks, _ = find_peaks(bout_signal, distance=sampling_rate * 0.0833)  # at least 0.0833s apart (12 Hz max)
            peak_times = peaks / sampling_rate  # convert to seconds
            if len(peak_times) > 1:
                ibi = np.diff(peak_times)                 # inter-breath intervals
                inst_rates = 1.0 / ibi                    # instantaneous rate (Hz)
        
        # Breathing rate from peak intervals (your existing code)
        rate_mask = (interval_times >= start) & (interval_times <= end)
        bout_rates_sec = rates_per_sec[rate_mask]
        bout_rates_min = rates_per_min[rate_mask]
        bout_intervals = intervals[rate_mask]
        
        if len(bout_rates_sec) > 0:
            mean_rate_sec = np.mean(bout_rates_sec)
            mean_rate_min = np.mean(bout_rates_min)
            mean_interval = np.mean(bout_intervals)
            breath_count = len(bout_rates_sec)
        elif len(inst_rates) > 0:
            # Fallback to instantaneous rate if global alignment is missing
            mean_rate_sec = np.mean(inst_rates)
            mean_rate_min = mean_rate_sec * 60
            mean_interval = np.mean(ibi)
            breath_count = len(inst_rates)
        
        result = {
            **bout.to_dict(),
            'mean_resp_100hz': sig_mean,
            'min_resp_100hz': sig_min,
            'max_resp_100hz': sig_max,
            'resp_range': sig_range,
            'mean_rate_per_sec': mean_rate_sec,
            'mean_rate_per_min': mean_rate_min,
            'mean_interval_sec': mean_interval,
            'breath_count': breath_count,
            'ibi_list': ibi,                 # NEW: inter-breath intervals
            'inst_rate_list_hz': inst_rates  # NEW: instantaneous rates
        }
        
        results.append(result)
    
    result_df = pd.DataFrame(results)
    print(f"Aligned data for {len(result_df)} behavioral bouts (with IBI/instantaneous rates)")
    
    return result_df

# %%
import h5py
import numpy as np
from scipy.signal import butter, filtfilt, resample
import neurokit2 as nk
import os

def load_clean_resp_signal(h5_file, target_rate=100):

    try:
        with h5py.File(h5_file, 'r') as f:
            resp = f['resp'][:].flatten()
            ekg_meta = dict(f['ekg_metadata'].attrs)
        duration_sec = float(ekg_meta['duration_sec'])
        fs = len(resp) / duration_sec
        print(f"Loaded {os.path.basename(h5_file)}: {len(resp)} samples, {fs:.2f} Hz, {duration_sec:.2f} sec")
    except Exception as e:
        print(f"Error loading {h5_file}: {e}")
        return None, None, None, None
    
    # Process signal
    filtered = apply_lowpass_filter(resp, fs, target_rate)
    resampled = resample_signal(filtered, duration_sec, target_rate)
    cleaned = apply_bandpass_filter(resampled, target_rate)
    time_vector = np.arange(len(cleaned)) / float(target_rate)
    
    return cleaned, time_vector, float(target_rate), os.path.basename(h5_file)

# %%
#Low pass filter func.
def apply_lowpass_filter(signal, fs, target_rate):
    
    cutoff_hz = min(0.45 * fs, 20.0) if target_rate >= fs else target_rate / 2.0
    Wn = cutoff_hz / (fs / 2.0)
    Wn = min(max(Wn, 0.0001), 0.9999) 
    
    b, a = butter(N=4, Wn=Wn, btype='low')
    filtered = filtfilt(b, a, signal)
    
    print(f"Applied low-pass filter: {cutoff_hz:.2f} Hz cutoff")
    return filtered

# %%
#Resampling Func.
def resample_signal(signal, duration_sec, target_rate):
 
    N_out = int(round(duration_sec * target_rate))
    resampled = resample(signal, N_out)
    
    print(f"Resampled: {len(signal)} -> {len(resampled)} samples at {target_rate} Hz")
    return resampled

# %%
#Band-pass filter
def apply_bandpass_filter(signal, sampling_rate, lowcut=0.5, highcut=15.0):
   
    cleaned = nk.signal_filter(
        signal, lowcut=lowcut, highcut=highcut,
        method="butterworth", sampling_rate=sampling_rate, order=2
    )
    
    print(f"Applied band-pass filter: {lowcut}-{highcut} Hz")
    return cleaned

# %%
import zipfile
import tempfile

def extract_h5_files_from_zip(zip_path):
    
    temp_dir = tempfile.mkdtemp()
    
    print(f"Extracting {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(temp_dir)
    
    # Find all H5 files
    h5_files = []
    for root, dirs, files in os.walk(temp_dir):
        for file in files:
            if file.endswith('.h5'):
                h5_files.append(os.path.join(root, file))
    
    print(f"Found {len(h5_files)} H5 files")
    return h5_files, temp_dir

# %%
#Batch processing
def process_multiple_h5_files(h5_files, target_rate=100):
    
    processed_data = {}
    
    for h5_file in h5_files:
        filename = os.path.basename(h5_file)
        print(f"\nProcessing: {filename}")
        
        resp_cleaned, time_vec, fs_out, file_id = load_clean_resp_signal(h5_file, target_rate)
        
        if resp_cleaned is not None:
            processed_data[file_id] = {
                'respiration': resp_cleaned,
                'time': time_vec,
                'sampling_rate': fs_out,
                'duration_sec': len(resp_cleaned) / fs_out,
                'filename': filename
            }
            print(f"Success: {len(resp_cleaned)} samples")
        else:
            print(f"Failed: {filename}")
    
    return processed_data

# %%
#Save data
import pandas as pd

def save_processed_data(processed_data, output_dir):
  
    output_file = os.path.join(output_dir, "processed_respiration_data.pkl")
    pd.to_pickle(processed_data, output_file)
    print(f"Saved processed data to: {output_file}")
  
    summary_data = []
    for file_id, data in processed_data.items():
        summary_data.append({
            'filename': file_id,
            'duration_sec': data['duration_sec'],
            'sampling_rate': data['sampling_rate'],
            'num_samples': len(data['respiration']),
            'mean_resp': np.mean(data['respiration']),
            'std_resp': np.std(data['respiration'])
        })
    
    summary_df = pd.DataFrame(summary_data)
    summary_file = os.path.join(output_dir, "respiration_summary.xlsx")
    summary_df.to_excel(summary_file, index=False)
    print(f"Saved summary to: {summary_file}")
    
    return summary_df

# %%
zip_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5.zip"
output_directory = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"

h5_files, temp_dir = extract_h5_files_from_zip(zip_path)

processed_data = process_multiple_h5_files(h5_files, target_rate=100)

summary = save_processed_data(processed_data, output_directory)

print(f"\nProcessed {len(processed_data)} files:")
print(summary)

import shutil
shutil.rmtree(temp_dir)
print("Cleaned up temporary files")
# Out:
# Extracting C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5.zip...
# Found 18 H5 files
#
# Processing: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Loaded RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5: 12425270 samples, 20000.00 Hz, 621.26 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12425270 -> 62126 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 62126 samples
#
# Processing: RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
# Loaded RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5: 12089585 samples, 20000.00 Hz, 604.48 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12089585 -> 60448 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60448 samples
#
# Processing: RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
# Loaded RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5: 12058916 samples, 20000.00 Hz, 602.95 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12058916 -> 60295 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60295 samples
#
# Processing: RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
# Loaded RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5: 12181909 samples, 20000.00 Hz, 609.10 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12181909 -> 60910 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60910 samples
#
# Processing: RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
# Loaded RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5: 12474615 samples, 20000.00 Hz, 623.73 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12474615 -> 62373 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 62373 samples
#
# Processing: RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
# Loaded RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5: 12065446 samples, 20000.00 Hz, 603.27 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12065446 -> 60327 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60327 samples
#
# Processing: RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
# Loaded RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5: 12583112 samples, 20000.00 Hz, 629.16 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12583112 -> 62916 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 62916 samples
#
# Processing: RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
# Loaded RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5: 12096714 samples, 20000.00 Hz, 604.84 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12096714 -> 60484 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60484 samples
#
# Processing: RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
# Loaded RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5: 12301849 samples, 20000.00 Hz, 615.09 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12301849 -> 61509 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 61509 samples
#
# Processing: RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
# Loaded RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5: 12095837 samples, 20000.00 Hz, 604.79 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12095837 -> 60479 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60479 samples
#
# Processing: RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
# Loaded RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5: 12085347 samples, 20000.00 Hz, 604.27 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12085347 -> 60427 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60427 samples
#
# Processing: RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
# Loaded RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5: 12184065 samples, 20000.00 Hz, 609.20 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12184065 -> 60920 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60920 samples
#
# Processing: RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
# Loaded RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5: 12108968 samples, 20000.00 Hz, 605.45 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12108968 -> 60545 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60545 samples
#
# Processing: RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
# Loaded RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5: 4266732 samples, 20000.00 Hz, 213.34 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 4266732 -> 21334 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 21334 samples
#
# Processing: RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
# Loaded RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5: 12200094 samples, 20000.00 Hz, 610.00 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12200094 -> 61000 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 61000 samples
#
# Processing: RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
# Loaded RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5: 12129332 samples, 20000.00 Hz, 606.47 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12129332 -> 60647 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60647 samples
#
# Processing: RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
# Loaded RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5: 12064729 samples, 20000.00 Hz, 603.24 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 12064729 -> 60324 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 60324 samples
#
# Processing: RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
# Loaded RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5: 9780589 samples, 20000.00 Hz, 489.03 sec
# Applied low-pass filter: 50.00 Hz cutoff
# Resampled: 9780589 -> 48903 samples at 100 Hz
# Applied band-pass filter: 0.5-15.0 Hz
# Success: 48903 samples
# Saved processed data to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data.pkl
# Saved summary to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\respiration_summary.xlsx
#
# Processed 18 files:
#                                          filename  duration_sec  \
# 0    RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5        621.26
# 1    RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5        604.48
# 2    RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5        602.95
# 3    RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5        609.10
# 4    RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5        623.73
# 5    RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5        603.27
# 6    RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5        629.16
# 7    RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5        604.84
# 8   RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5        615.09
# 9    RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5        604.79
# 10   RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5        604.27
# 11   RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5        609.20
# 12   RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5        605.45
# 13   RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5        213.34
# 14   RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5        610.00
# 15   RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5        606.47
# 16   RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5        603.24
# 17  RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5        489.03
#
#     sampling_rate  num_samples  mean_resp     std_resp
# 0           100.0        62126  -0.202867   783.602136
# 1           100.0        60448  -1.516067   769.120054
# 2           100.0        60295   0.127220   686.979926
# 3           100.0        60910  -0.552319   843.216271
# 4           100.0        62373  -0.035485   897.939610
# 5           100.0        60327   0.358948   794.832793
# 6           100.0        62916  -0.172896   805.205650
# 7           100.0        60484  -0.303714   894.423316
# 8           100.0        61509  -0.072806   843.332455
# 9           100.0        60479  -0.210412   744.934351
# 10          100.0        60427  -0.354585   659.761705
# 11          100.0        60920   0.034316   726.414387
# 12          100.0        60545  -0.454796   719.546675
# 13          100.0        21334  -0.244147  1014.771430
# 14          100.0        61000  -0.073053   633.308274
# 15          100.0        60647  -0.053351   791.718383
# 16          100.0        60324  -0.147177   972.861702
# 17          100.0        48903   0.005471     2.647889
# Cleaned up temporary files

# %%
import os

# Check what files are in your Excel_Results directory
output_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"

print("Files in Excel_Results folder:")
for file in os.listdir(output_dir):
    if file.endswith('.xlsx'):
        print(f"  {file}")
# Out:
# Files in Excel_Results folder:
#   2025_08_04-15_38_34_individual_track_syllable_durations.xlsx
#   2025_08_04-15_38_34_overall_top_20_syllable_half_second_bout_percentages.xlsx
#   2025_08_04-15_38_34_overall_top_20_syllable_long_bout_percentages.xlsx
#   2025_08_04-15_38_34_overall_top_syllable_long_bout_percentages.xlsx
#   2025_08_04-15_38_34_per_video_top_20_syllable_half_second_bout_percentages.xlsx
#   2025_08_04-15_38_34_per_video_top_20_syllable_long_bout_percentages.xlsx
#   2025_08_04-15_38_34_per_video_top_syllable_long_bout_percentages.xlsx
#   respiration_summary.xlsx
#   top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
#   top-RI1_s1_1_p5_2_nRB6_20250622_143958_track1_syllables.xlsx
#   top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
#   top-RI1_s1_2_p5_1_nRB6_20250622_170742_track1_syllables.xlsx
#   top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
#   top-RI1_s2_3_p5_3_nRB3_20250622_104059_track1_syllables.xlsx
#   top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
#   top-RI1_s2_4_p5_4_nRB3_20250622_123424_track1_syllables.xlsx
#   top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
#   top-RI1_s3_6_p5_3_nRB3_20250621_125312_track1_syllables.xlsx
#   top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
#   top-RI1_s4_7_p5_2_nRB3_20250621_150707_track1_syllables.xlsx
#   top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
#   top-RI1_s4_8_p5_1_nRB3_20250621_165214_track1_syllables.xlsx
#   top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
#   top-RI1_s5_13_p5_4_nRB3_20250622_181801_track1_syllables.xlsx
#   top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
#   top-RI2_s1_1_p5_2_nRB6_20250622_150457_track1_syllables.xlsx
#   top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
#   top-RI2_s1_2_p5_1_nRB6_20250622_173049_track1_syllables.xlsx
#   top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
#   top-RI2_s2_3_p5_3_nRB3_20250622_110216_track1_syllables.xlsx
#   top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
#   top-RI2_s2_4_p5_4_nRB3_20250622_125648_track1_syllables.xlsx
#   top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
#   top-RI2_s3_5_p5_4_nRB3_20250621_112618_track1_syllables.xlsx
#   top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
#   top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track1_syllables.xlsx
#   top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
#   top-RI2_s4_7_p5_2_nRB3_20250621_152519_track1_syllables.xlsx
#   top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
#   top-RI2_s4_8_p5_1_nRB3_20250621_171318_track1_syllables.xlsx
#   top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
#   top-RI2_s5_13_p5_4_nRB3_20250622_184136_track1_syllables.xlsx

# %%
import pandas as pd

# Load the bout details file
bout_details_file = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\detailed_bout_frame_locations_correct_fps.xlsx"
bout_df = pd.read_excel(bout_details_file)

# Corrected FPS mapping based on actual video name patterns
def get_corrected_fps(video_name):
    if "RI1_s1_1" in video_name:
        return 15
    elif "RI1_s2_3" in video_name:
        return 15  
    elif "RI1_s3_6" in video_name:
        return 29
    elif "RI2_s1_1" in video_name:
        return 15
    elif "RI2_s2_4" in video_name:
        return 15
    else:
        return 30  # Default

# Update the FPS values
bout_df['video_fps'] = bout_df['video_name'].apply(get_corrected_fps)

# Recalculate bout durations with correct FPS
bout_df['bout_duration_seconds'] = bout_df['bout_duration_frames'] / bout_df['video_fps']
bout_df['longer_than_0.5sec'] = bout_df['bout_duration_seconds'] > 0.5
bout_df['longer_than_1sec'] = bout_df['bout_duration_seconds'] > 1.0

# Save corrected file
corrected_file = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\detailed_bout_frame_locations_correct_fps_FIXED.xlsx"
bout_df.to_excel(corrected_file, index=False)

# Check the corrected FPS distribution
print("Corrected FPS distribution:")
fps_counts = bout_df.groupby(['video_name', 'video_fps']).size().reset_index(name='bout_count')
print(fps_counts)

print(f"\nSaved corrected file to: {corrected_file}")
# Out:
# Corrected FPS distribution:
#                              video_name  video_fps  bout_count
# 0    RI1_s1_1_p5_2_nRB6_20250622_143958         15        3496
# 1    RI1_s1_2_p5_1_nRB6_20250622_170742         30        5242
# 2    RI1_s2_3_p5_3_nRB3_20250622_104059         15        3569
# 3    RI1_s2_4_p5_4_nRB3_20250622_123424         30        3133
# 4    RI1_s3_6_p5_3_nRB3_20250621_125312         29        3397
# 5    RI1_s4_7_p5_2_nRB3_20250621_150707         30        4739
# 6    RI1_s4_8_p5_1_nRB3_20250621_165214         30        5447
# 7   RI1_s5_13_p5_4_nRB3_20250622_181801         30        4407
# 8    RI2_s1_1_p5_2_nRB6_20250622_150457         15        2634
# 9    RI2_s1_2_p5_1_nRB6_20250622_173049         30        2997
# 10   RI2_s2_3_p5_3_nRB3_20250622_110216         30        3747
# 11   RI2_s2_4_p5_4_nRB3_20250622_125648         15        2376
# 12   RI2_s3_5_p5_4_nRB3_20250621_112618         30        4042
# 13  RI2_s3_6_p_5_3_nRB3_20250621_131158         30        4355
# 14   RI2_s4_7_p5_2_nRB3_20250621_152519         30        5112
# 15   RI2_s4_8_p5_1_nRB3_20250621_171318         30        4580
# 16  RI2_s5_13_p5_4_nRB3_20250622_184136         30        3643
#
# Saved corrected file to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\detailed_bout_frame_locations_correct_fps_FIXED.xlsx

# %%
# Filter out bouts shorter than 0.5 seconds
min_bout_duration = 0.5
filtered_bouts = bout_df[bout_df['bout_duration_seconds'] >= min_bout_duration]

print(f"Original bouts: {len(bout_df)}")
print(f"Filtered bouts (≥0.5 seconds): {len(filtered_bouts)}")
print(f"Removed {len(bout_df) - len(filtered_bouts)} short bouts")
# Out:
# Original bouts: 66916
# Filtered bouts (≥0.5 seconds): 8333
# Removed 58583 short bouts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import os

# Load your processed respiration data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data.pkl")

def calculate_respiratory_metrics(resp_signal, resp_time, sampling_rate=100):
    """
    Calculate detailed respiratory metrics from respiration signal
    """
    if len(resp_signal) < 10:  # Too short to analyze
        return {}
    
    # Find peaks (inspirations) - look for positive peaks
    peak_height = np.std(resp_signal) * 0.3  # Adaptive threshold
    min_distance = int(sampling_rate * 0.5)  # Minimum 0.5 seconds between breaths
    
    peaks, peak_properties = find_peaks(resp_signal, 
                                       height=peak_height, 
                                       distance=min_distance)
    
    # Find troughs (expirations) - look for negative peaks
    troughs, trough_properties = find_peaks(-resp_signal, 
                                          height=peak_height, 
                                          distance=min_distance)
    
    if len(peaks) < 2:  # Need at least 2 breaths
        return {
            'respiratory_rate_per_sec': 0,
            'respiratory_rate_per_min': 0,
            'interbreath_interval_mean': 0,
            'interbreath_interval_std': 0,
            'breath_count': 0,
            'breathing_amplitude_mean': 0,
            'breathing_amplitude_std': 0,
            'inspiration_duration_mean': 0,
            'expiration_duration_mean': 0,
            'respiratory_variability': 0
        }
    
    # Calculate interbreath intervals (peak to peak)
    peak_times = resp_time[peaks]
    interbreath_intervals = np.diff(peak_times)
    
    # Respiratory rate calculations
    total_duration = resp_time[-1] - resp_time[0]
    breath_count = len(peaks)
    respiratory_rate_per_sec = breath_count / total_duration if total_duration > 0 else 0
    respiratory_rate_per_min = respiratory_rate_per_sec * 60
    
    # Breathing amplitudes (peak to trough differences)
    amplitudes = []
    inspiration_durations = []
    expiration_durations = []
    
    for peak_idx in peaks:
        peak_value = resp_signal[peak_idx]
        
        # Find nearest trough before and after peak
        troughs_before = troughs[troughs < peak_idx]
        troughs_after = troughs[troughs > peak_idx]
        
        if len(troughs_before) > 0:
            trough_before_idx = troughs_before[-1]
            trough_before_value = resp_signal[trough_before_idx]
            amplitudes.append(peak_value - trough_before_value)
            
            # Inspiration duration (trough to peak)
            inspiration_duration = (peak_idx - trough_before_idx) / sampling_rate
            inspiration_durations.append(inspiration_duration)
        
        if len(troughs_after) > 0:
            trough_after_idx = troughs_after[0]
            
            # Expiration duration (peak to trough)
            expiration_duration = (trough_after_idx - peak_idx) / sampling_rate
            expiration_durations.append(expiration_duration)
    
    # Calculate metrics
    metrics = {
        'respiratory_rate_per_sec': respiratory_rate_per_sec,
        'respiratory_rate_per_min': respiratory_rate_per_min,
        'interbreath_interval_mean': np.mean(interbreath_intervals) if len(interbreath_intervals) > 0 else 0,
        'interbreath_interval_std': np.std(interbreath_intervals) if len(interbreath_intervals) > 0 else 0,
        'breath_count': breath_count,
        'breathing_amplitude_mean': np.mean(amplitudes) if len(amplitudes) > 0 else 0,
        'breathing_amplitude_std': np.std(amplitudes) if len(amplitudes) > 0 else 0,
        'inspiration_duration_mean': np.mean(inspiration_durations) if len(inspiration_durations) > 0 else 0,
        'expiration_duration_mean': np.mean(expiration_durations) if len(expiration_durations) > 0 else 0,
        'respiratory_variability': np.std(interbreath_intervals) / np.mean(interbreath_intervals) if len(interbreath_intervals) > 0 and np.mean(interbreath_intervals) > 0 else 0
    }
    
    return metrics

def extract_resp_during_bout(resp_data, bout_start_frame, bout_end_frame, video_fps, resp_fps=100):
    """
    Extract respiration data during a specific syllable bout
    """
    # Convert frame numbers to time
    start_time = bout_start_frame / video_fps
    end_time = bout_end_frame / video_fps
    
    # Convert time to respiration indices
    start_idx = int(start_time * resp_fps)
    end_idx = int(end_time * resp_fps)
    
    # Extract respiration during bout
    if start_idx < len(resp_data['respiration']) and end_idx < len(resp_data['respiration']):
        bout_resp = resp_data['respiration'][start_idx:end_idx]
        bout_time = resp_data['time'][start_idx:end_idx] - resp_data['time'][start_idx]  # Start from 0
        return bout_resp, bout_time
    else:
        return None, None

def analyze_resp_during_syllables(bout_details_file, processed_resp_data, min_bout_duration=0.5):
    """
    Analyze respiration patterns during syllable bouts with detailed metrics
    """
    # Load bout data
    bout_df = pd.read_excel(bout_details_file)
    
    # Filter out bouts shorter than 0.5 seconds
    print(f"Original bouts: {len(bout_df)}")
    filtered_bouts = bout_df[bout_df['bout_duration_seconds'] >= min_bout_duration]
    print(f"Filtered bouts (≥{min_bout_duration} seconds): {len(filtered_bouts)}")
    print(f"Removed {len(bout_df) - len(filtered_bouts)} short bouts")
    
    resp_bout_data = []
    
    for _, bout in filtered_bouts.iterrows():
        video_name = bout['video_name']
        
        # Find matching respiration file
        resp_key = f"{video_name}_merged.h5"
        
        if resp_key in processed_resp_data:
            resp_data = processed_resp_data[resp_key]
            video_fps = bout['video_fps']
            
            # Extract respiration during this bout
            bout_resp, bout_time = extract_resp_during_bout(
                resp_data, 
                bout['bout_start_frame'], 
                bout['bout_end_frame'], 
                video_fps
            )
            
            if bout_resp is not None:
                # Calculate detailed respiratory metrics
                resp_metrics = calculate_respiratory_metrics(bout_resp, bout_time)
                
                # Combine bout info with respiratory metrics
                bout_data = {
                    'syllable_id': bout['syllable_id'],
                    'video_name': bout['video_name'],
                    'track_number': bout['track_number'],
                    'bout_start_frame': bout['bout_start_frame'],
                    'bout_end_frame': bout['bout_end_frame'],
                    'bout_duration_sec': bout['bout_duration_seconds'],
                    'video_fps': bout['video_fps'],
                    'resp_mean': np.mean(bout_resp),
                    'resp_std': np.std(bout_resp),
                    'resp_range': np.max(bout_resp) - np.min(bout_resp),
                }
                
                # Add all respiratory metrics
                bout_data.update(resp_metrics)
                
                resp_bout_data.append(bout_data)
    
    return resp_bout_data

def create_detailed_resp_dataframe(resp_bout_data):
    """
    Create detailed DataFrame with all respiratory metrics
    """
    df = pd.DataFrame(resp_bout_data)
    
    # Reorder columns for better readability
    column_order = [
        'syllable_id', 'video_name', 'track_number', 
        'bout_start_frame', 'bout_end_frame', 'bout_duration_sec', 'video_fps',
        'respiratory_rate_per_sec', 'respiratory_rate_per_min', 
        'interbreath_interval_mean', 'interbreath_interval_std',
        'breath_count', 'breathing_amplitude_mean', 'breathing_amplitude_std',
        'inspiration_duration_mean', 'expiration_duration_mean', 
        'respiratory_variability', 'resp_mean', 'resp_std', 'resp_range'
    ]
    
    # Only include columns that exist
    available_columns = [col for col in column_order if col in df.columns]
    df = df[available_columns]
    
    return df

# Execute the analysis
bout_details_file = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\detailed_bout_frame_locations_correct_fps_FIXED.xlsx"

print("Analyzing respiration during syllable bouts (≥0.5 seconds)...")
resp_bout_data = analyze_resp_during_syllables(bout_details_file, processed_resp_data, min_bout_duration=0.5)

print(f"Found respiration data for {len(resp_bout_data)} syllable bouts")

# Create detailed DataFrame
detailed_resp_df = create_detailed_resp_dataframe(resp_bout_data)
print("\nFirst few rows of detailed respiration data:")
print(detailed_resp_df.head())

# Save results
output_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"

# Save detailed data (like your screenshot)
detailed_file = os.path.join(output_dir, "detailed_respiration_syllable_analysis_filtered.xlsx")
detailed_resp_df.to_excel(detailed_file, index=False)

print(f"\nSaved detailed analysis to: {detailed_file}")
print("Analysis complete!")
# Out:
# Analyzing respiration during syllable bouts (≥0.5 seconds)...
# Original bouts: 66916
# Filtered bouts (≥0.5 seconds): 9981
# Removed 56935 short bouts
# Found respiration data for 8687 syllable bouts
#
# First few rows of detailed respiration data:
#    syllable_id                          video_name  track_number  \
# 0           21  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 1           28  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 2            2  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 3            7  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 4           16  RI1_s1_1_p5_2_nRB6_20250622_143958             0
#
#    bout_start_frame  bout_end_frame  bout_duration_sec  video_fps  \
# 0                 0              25           1.733333         15
# 1                26              34           0.600000         15
# 2                39              46           0.533333         15
# 3                47              66           1.333333         15
# 4                69             110           2.800000         15
#
#    respiratory_rate_per_sec  respiratory_rate_per_min  \
# 0                  1.818182                109.090909
# 1                  0.000000                  0.000000
# 2                  0.000000                  0.000000
# 3                  2.380952                142.857143
# 4                  1.465201                 87.912088
#
#    interbreath_interval_mean  interbreath_interval_std  breath_count  \
# 0                      0.665                  0.165000             3
# 1                      0.000                  0.000000             0
# 2                      0.000                  0.000000             0
# 3                      0.560                  0.040000             3
# 4                      0.710                  0.163299             4
#
#    breathing_amplitude_mean  breathing_amplitude_std  \
# 0               3455.417172               204.926682
# 1                  0.000000                 0.000000
# 2                  0.000000                 0.000000
# 3               3204.328141               376.032608
# 4               2465.936300               584.029716
#
#    inspiration_duration_mean  expiration_duration_mean  \
# 0                     0.5500                  0.096667
# 1                     0.0000                  0.000000
# 2                     0.0000                  0.000000
# 3                     0.4250                  0.135000
# 4                     0.1775                  0.436667
#
#    respiratory_variability   resp_mean     resp_std   resp_range
# 0                 0.248120 -269.598495  1017.382576  3991.481229
# 1                 0.000000  -36.115451   787.560790  2923.464092
# 2                 0.000000   81.351523   916.467265  3282.044282
# 3                 0.071429   62.680979   970.338013  3580.360749
# 4                 0.229999  -83.088686   720.033234  3455.768822
#
# Saved detailed analysis to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\detailed_respiration_syllable_analysis_filtered.xlsx
# Analysis complete!

# %%
# Check what percentage of bouts have valid respiratory data
detailed_resp_df = pd.read_excel(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\detailed_respiration_syllable_analysis_filtered.xlsx")

print("Respiratory data quality check:")
print(f"Total bouts: {len(detailed_resp_df)}")
print(f"Bouts with respiratory rate > 0: {(detailed_resp_df['respiratory_rate_per_sec'] > 0).sum()}")
print(f"Bouts with breath count > 0: {(detailed_resp_df['breath_count'] > 0).sum()}")

print("\nBout duration vs respiratory detection:")
print(detailed_resp_df.groupby(pd.cut(detailed_resp_df['bout_duration_sec'], bins=[0, 1, 2, 5, float('inf')]))['respiratory_rate_per_sec'].apply(lambda x: (x > 0).sum()))
# Out:
# Respiratory data quality check:
# Total bouts: 8687
# Bouts with respiratory rate > 0: 3783
# Bouts with breath count > 0: 3783
#
# Bout duration vs respiratory detection:
# bout_duration_sec
# (0.0, 1.0]    1216
# (1.0, 2.0]    1738
# (2.0, 5.0]     654
# (5.0, inf]     175
# Name: respiratory_rate_per_sec, dtype: int64
# C:\Users\Padilla-Coreano\AppData\Local\Temp\ipykernel_20320\2241731519.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(detailed_resp_df.groupby(pd.cut(detailed_resp_df['bout_duration_sec'], bins=[0, 1, 2, 5, float('inf')]))['respiratory_rate_per_sec'].apply(lambda x: (x > 0).sum()))

# %%
# Rerun analysis with 1-second minimum
print("Rerunning analysis with 1-second minimum bout duration...")
resp_bout_data_1sec = analyze_resp_during_syllables(bout_details_file, processed_resp_data, min_bout_duration=1.0)

print(f"Found respiration data for {len(resp_bout_data_1sec)} syllable bouts (≥1 second)")

# Create detailed DataFrame
detailed_resp_df_1sec = create_detailed_resp_dataframe(resp_bout_data_1sec)

# Save with new threshold
output_dir = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
detailed_file_1sec = os.path.join(output_dir, "detailed_respiration_syllable_analysis_1sec_min.xlsx")
detailed_resp_df_1sec.to_excel(detailed_file_1sec, index=False)

print(f"Saved 1-second minimum analysis to: {detailed_file_1sec}")

# Check the improved quality
print("\nImproved respiratory data quality:")
print(f"Total bouts (≥1 sec): {len(detailed_resp_df_1sec)}")
print(f"Bouts with respiratory rate > 0: {(detailed_resp_df_1sec['respiratory_rate_per_sec'] > 0).sum()}")
success_rate = (detailed_resp_df_1sec['respiratory_rate_per_sec'] > 0).sum() / len(detailed_resp_df_1sec) * 100
print(f"Success rate: {success_rate:.1f}%")

print("\nFirst few rows of improved data:")
print(detailed_resp_df_1sec.head())

print("Analysis with 1-second minimum complete!")
# Out:
# Rerunning analysis with 1-second minimum bout duration...
# Original bouts: 66916
# Filtered bouts (≥1.0 seconds): 3685
# Removed 63231 short bouts
# Found respiration data for 3101 syllable bouts (≥1 second)
# Saved 1-second minimum analysis to: C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\detailed_respiration_syllable_analysis_1sec_min.xlsx
#
# Improved respiratory data quality:
# Total bouts (≥1 sec): 3101
# Bouts with respiratory rate > 0: 2716
# Success rate: 87.6%
#
# First few rows of improved data:
#    syllable_id                          video_name  track_number  \
# 0           21  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 1            7  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 2           16  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 3           25  RI1_s1_1_p5_2_nRB6_20250622_143958             0
# 4           13  RI1_s1_1_p5_2_nRB6_20250622_143958             0
#
#    bout_start_frame  bout_end_frame  bout_duration_sec  video_fps  \
# 0                 0              25           1.733333         15
# 1                47              66           1.333333         15
# 2                69             110           2.800000         15
# 3               169             199           2.066667         15
# 4               239             253           1.000000         15
#
#    respiratory_rate_per_sec  respiratory_rate_per_min  \
# 0                  1.818182                109.090909
# 1                  2.380952                142.857143
# 2                  1.465201                 87.912088
# 3                  1.507538                 90.452261
# 4                  2.173913                130.434783
#
#    interbreath_interval_mean  interbreath_interval_std  breath_count  \
# 0                      0.665                  0.165000             3
# 1                      0.560                  0.040000             3
# 2                      0.710                  0.163299             4
# 3                      0.785                  0.155000             3
# 4                      0.770                  0.000000             2
#
#    breathing_amplitude_mean  breathing_amplitude_std  \
# 0               3455.417172               204.926682
# 1               3204.328141               376.032608
# 2               2465.936300               584.029716
# 3               3326.674239               192.312050
# 4               3340.100342                 0.000000
#
#    inspiration_duration_mean  expiration_duration_mean  \
# 0                     0.5500                  0.096667
# 1                     0.4250                  0.135000
# 2                     0.1775                  0.436667
# 3                     0.6100                  0.163333
# 4                     0.5500                  0.220000
#
#    respiratory_variability   resp_mean     resp_std   resp_range
# 0                 0.248120 -269.598495  1017.382576  3991.481229
# 1                 0.071429   62.680979   970.338013  3580.360749
# 2                 0.229999  -83.088686   720.033234  3455.768822
# 3                 0.197452   11.552842   838.066277  3518.986288
# 4                 0.000000  113.267438   743.047198  3340.100342
# Analysis with 1-second minimum complete!

# %%
import pandas as pd
import glob
import os

def create_master_corrected_files():
    # Find all CORRECTED files
    corrected_files = glob.glob("CORRECTED_*_with_1_over_IBI.xlsx")
    
    # Separate RI1 and RI2 files
    ri1_files = [f for f in corrected_files if "-RI1_" in f]
    ri2_files = [f for f in corrected_files if "-RI2_" in f]
    
    print(f"Found {len(ri1_files)} RI1 files and {len(ri2_files)} RI2 files")
    
    def create_master_file(files, output_name):
        print(f"Creating {output_name}...")
        
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                
                # Extract session info from filename
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                # Get session identifier
                session_info = session_part.split("_")[0:3]  # s1, 1, p5
                
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                # Excel sheet names can't be longer than 31 characters
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                # Add source filename info to the dataframe
                df['source_file'] = filename
                df['session_id'] = sheet_name
                
                # Write to sheet
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"  Added sheet: {sheet_name} ({df.shape[0]} rows)")
        
        print(f"Saved: {output_name}")
    
    # Create master files
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_Corrected_1_over_IBI.xlsx")
    
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_Corrected_1_over_IBI.xlsx")
    
    return len(ri1_files), len(ri2_files)

# Create the master files
ri1_count, ri2_count = create_master_corrected_files()

print(f"Master files created:")
print(f"RI1_MASTER_Corrected_1_over_IBI.xlsx ({ri1_count} sheets)")
print(f"RI2_MASTER_Corrected_1_over_IBI.xlsx ({ri2_count} sheets)")

# Verify the files
print("Verifying master files...")
for master_file in ["RI1_MASTER_Corrected_1_over_IBI.xlsx", "RI2_MASTER_Corrected_1_over_IBI.xlsx"]:
    if os.path.exists(master_file):
        xl_file = pd.ExcelFile(master_file)
        print(f"{master_file}:")
        print(f"  Total sheets: {len(xl_file.sheet_names)}")
        for sheet in xl_file.sheet_names:
            print(f"    - {sheet}")
# Out:
# Found 8 RI1 files and 9 RI2 files
# Creating RI1_MASTER_Corrected_1_over_IBI.xlsx...
#   Added sheet: RI1_s1_1_p5_track0 (9300 rows)
#   Added sheet: RI1_s1_2_p5_track0 (18083 rows)
#   Added sheet: RI1_s2_3_p5_track0 (18060 rows)
#   Added sheet: RI1_s2_4_p5_track0 (9116 rows)
#   Added sheet: RI1_s3_6_p5_track0 (18064 rows)
#   Added sheet: RI1_s4_7_p5_track0 (18699 rows)
#   Added sheet: RI1_s4_8_p5_track0 (18015 rows)
#   Added sheet: RI1_s5_13_p5_track0 (18405 rows)
# Saved: RI1_MASTER_Corrected_1_over_IBI.xlsx
# Creating RI2_MASTER_Corrected_1_over_IBI.xlsx...
#   Added sheet: RI2_s1_1_p5_track0 (9053 rows)
#   Added sheet: RI2_s1_2_p5_track0 (18095 rows)
#   Added sheet: RI2_s2_3_p5_track0 (18153 rows)
#   Added sheet: RI2_s2_4_p5_track0 (9065 rows)
#   Added sheet: RI2_s3_5_p5_track0 (18062 rows)
#   Added sheet: RI2_s3_6_p_track0 (18263 rows)
#   Added sheet: RI2_s4_7_p5_track0 (18158 rows)
#   Added sheet: RI2_s4_8_p5_track0 (18065 rows)
#   Added sheet: RI2_s5_13_p5_track0 (14654 rows)
# Saved: RI2_MASTER_Corrected_1_over_IBI.xlsx
# Master files created:
# RI1_MASTER_Corrected_1_over_IBI.xlsx (8 sheets)
# RI2_MASTER_Corrected_1_over_IBI.xlsx (9 sheets)
# Verifying master files...
# RI1_MASTER_Corrected_1_over_IBI.xlsx:
#   Total sheets: 8
#     - RI1_s1_1_p5_track0
#     - RI1_s1_2_p5_track0
#     - RI1_s2_3_p5_track0
#     - RI1_s2_4_p5_track0
#     - RI1_s3_6_p5_track0
#     - RI1_s4_7_p5_track0
#     - RI1_s4_8_p5_track0
#     - RI1_s5_13_p5_track0
# RI2_MASTER_Corrected_1_over_IBI.xlsx:
#   Total sheets: 9
#     - RI2_s1_1_p5_track0
#     - RI2_s1_2_p5_track0
#     - RI2_s2_3_p5_track0
#     - RI2_s2_4_p5_track0
#     - RI2_s3_5_p5_track0
#     - RI2_s3_6_p_track0
#     - RI2_s4_7_p5_track0
#     - RI2_s4_8_p5_track0
#     - RI2_s5_13_p5_track0

# %%
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
import glob
import os

def process_respiratory_bouts_with_bandpass_corrected():
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    
    excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
    excel_files = glob.glob(os.path.join(excel_path, "*track0*.xlsx"))
    
    results = {}
    
    for file_id, resp_data in processed_resp_data.items():
        print(f"Processing {file_id}")
        
        filtered_signal = resp_data['respiration']
        fs = 100
        time_vector = np.arange(len(filtered_signal)) / fs
        
        normalized_signal = (filtered_signal - np.mean(filtered_signal)) / np.std(filtered_signal)
        peaks, _ = find_peaks(normalized_signal, distance=fs//4, prominence=0.5, height=0.1)
        
        print(f"Found {len(peaks)} breathing peaks")
        
        if len(peaks) < 2:
            continue
            
        peak_times = peaks / fs
        ibi_seconds = np.diff(peak_times)
        breathing_rate_1_over_ibi = 1 / ibi_seconds
        breathing_rate_bpm = breathing_rate_1_over_ibi * 60
        breath_times = peak_times[1:]
        
        print(f"IBI range: {ibi_seconds.min():.3f} - {ibi_seconds.max():.3f} seconds")
        print(f"Mean IBI: {ibi_seconds.mean():.3f} seconds")
        
        matching_excel = None
        for excel_file in excel_files:
            if any(session in file_id and session in excel_file for session in 
                   ['RI1_s1_1', 'RI1_s1_2', 'RI1_s2_3', 'RI1_s2_4', 'RI1_s3_5', 'RI1_s3_6', 
                    'RI1_s4_7', 'RI1_s4_8', 'RI1_s5_13', 'RI2_s1_1', 'RI2_s1_2', 'RI2_s2_3', 
                    'RI2_s2_4', 'RI2_s3_5', 'RI2_s3_6', 'RI2_s4_7', 'RI2_s4_8', 'RI2_s5_13']):
                matching_excel = excel_file
                break
        
        if matching_excel:
            print(f"Matched with: {os.path.basename(matching_excel)}")
            behavior_df = pd.read_excel(matching_excel)
            
            fps_map = {"RI1_s1_1": 15, "RI1_s2_3": 15, "RI1_s3_6": 29, "RI2_s1_1": 15, "RI2_s2_4": 15}
            video_fps = 30
            for pattern, fps in fps_map.items():
                if pattern in os.path.basename(matching_excel):
                    video_fps = fps
                    break
            
            print(f"Using {video_fps} FPS")
            
            behavior_df['time_seconds'] = behavior_df['frame_number'] / video_fps
            behavior_df['behavior_transition'] = (behavior_df['syllable'] != behavior_df['syllable'].shift()).astype(int)
            behavior_df['episode_group'] = behavior_df['behavior_transition'].cumsum()
            
            syllable_bouts = []
            
            for group_id, episode_group in behavior_df.groupby('episode_group'):
                syllable_id = episode_group['syllable'].iloc[0]
                
                bout_start_frame = episode_group['frame_number'].min()
                bout_end_frame = episode_group['frame_number'].max()
                bout_start_time_sec = episode_group['time_seconds'].min()
                bout_end_time_sec = episode_group['time_seconds'].max()
                bout_duration_ms = (bout_end_time_sec - bout_start_time_sec) * 1000
                bout_frame_count = len(episode_group)
                
                if bout_duration_ms >= 500:
                    
                    time_mask = (time_vector >= bout_start_time_sec) & (time_vector <= bout_end_time_sec)
                    bout_resp_signal = filtered_signal[time_mask]
                    
                    if len(bout_resp_signal) > 0:
                        mean_resp = np.mean(bout_resp_signal)
                        min_resp = np.min(bout_resp_signal)
                        max_resp = np.max(bout_resp_signal)
                        resp_range = max_resp - min_resp
                    else:
                        mean_resp = min_resp = max_resp = resp_range = np.nan
                    
                    breath_mask = (breath_times >= bout_start_time_sec) & (breath_times <= bout_end_time_sec)
                    bout_1_over_ibi = breathing_rate_1_over_ibi[breath_mask]
                    bout_bpm = breathing_rate_bpm[breath_mask]
                    bout_ibi = ibi_seconds[breath_mask]
                    
                    if len(bout_1_over_ibi) > 0:
                        mean_1_over_ibi = np.mean(bout_1_over_ibi)
                        mean_bpm = np.mean(bout_bpm)
                        mean_ibi = np.mean(bout_ibi)
                        breath_count = len(bout_1_over_ibi)
                    else:
                        mid_time = (bout_start_time_sec + bout_end_time_sec) / 2
                        if len(breath_times) > 0:
                            mean_1_over_ibi = np.interp(mid_time, breath_times, breathing_rate_1_over_ibi)
                            mean_bpm = mean_1_over_ibi * 60
                            mean_ibi = 1 / mean_1_over_ibi if mean_1_over_ibi > 0 else np.nan
                        else:
                            mean_1_over_ibi = mean_bpm = mean_ibi = np.nan
                        breath_count = 0
                    
                    syllable_bouts.append({
                        'syllable_id': syllable_id,
                        'bout_start_frame': bout_start_frame,
                        'bout_end_frame': bout_end_frame,
                        'bout_start_time_sec': bout_start_time_sec,
                        'bout_end_time_sec': bout_end_time_sec,
                        'bout_duration_ms': bout_duration_ms,
                        'bout_frame_count': bout_frame_count,
                        'fps_used': video_fps,
                        'mean_resp_signal_bandpass': mean_resp,
                        'min_resp_signal_bandpass': min_resp,
                        'max_resp_signal_bandpass': max_resp,
                        'resp_signal_range': resp_range,
                        'mean_1_over_IBI': mean_1_over_ibi,
                        'mean_breathing_rate_BPM': mean_bpm,
                        'mean_IBI_seconds': mean_ibi,
                        'breath_count': breath_count,
                        'video_name': episode_group['video_name'].iloc[0] if 'video_name' in episode_group.columns else 'unknown',
                        'track_name': episode_group['track_name'].iloc[0] if 'track_name' in episode_group.columns else 'track0'
                    })
            
            bouts_df = pd.DataFrame(syllable_bouts)
            bouts_df = bouts_df.sort_values('bout_start_time_sec').reset_index(drop=True)
            
            if len(bouts_df) > 0:
                excel_basename = os.path.basename(matching_excel).replace('.xlsx', '')
                output_file = f"FINAL_BOUTS_{excel_basename}.xlsx"
                bouts_df.to_excel(output_file, index=False)
                print(f"Saved: {output_file} with {len(bouts_df)} bouts")
                
                results[file_id] = bouts_df
        else:
            print(f"No matching file found")
    
    return results

def create_master_bout_files():
    bout_files = glob.glob("FINAL_BOUTS_*.xlsx")
    
    ri1_files = [f for f in bout_files if "-RI1_" in f]
    ri2_files = [f for f in bout_files if "-RI2_" in f]
    
    def create_master_file(files, output_name):
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"Added {sheet_name}: {len(df)} bouts")
    
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_Bouts.xlsx")
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_Bouts.xlsx")

print("Processing respiratory bout data")
corrected_bout_results = process_respiratory_bouts_with_bandpass_corrected()
create_master_bout_files()
print(f"Done - processed {len(corrected_bout_results)} files")

if corrected_bout_results:
    sample_key = list(corrected_bout_results.keys())[0]
    sample_data = corrected_bout_results[sample_key]
    
    valid_ibi = sample_data['mean_IBI_seconds'].dropna()
    if len(valid_ibi) > 0:
        print(f"IBI range: {valid_ibi.min():.3f} - {valid_ibi.max():.3f} seconds")
        print(f"BPM range: {valid_ibi.min()*60:.1f} - {valid_ibi.max()*60:.1f}")
# Out:
# Processing respiratory bout data
# Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Found 1602 breathing peaks
# IBI range: 0.250 - 1.650 seconds
# Mean IBI: 0.388 seconds
# Matched with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
# Using 15 FPS
# Saved: FINAL_BOUTS_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx with 303 bouts
# Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
# Found 1543 breathing peaks
# IBI range: 0.250 - 5.620 seconds
# Mean IBI: 0.391 seconds
# Matched with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx with 266 bouts
# Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
# Found 1454 breathing peaks
# IBI range: 0.250 - 15.500 seconds
# Mean IBI: 0.415 seconds
# Matched with: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
# Using 15 FPS
# Saved: FINAL_BOUTS_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx with 504 bouts
# Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
# Found 1656 breathing peaks
# IBI range: 0.250 - 0.820 seconds
# Mean IBI: 0.367 seconds
# Matched with: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx with 132 bouts
# Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
# Found 1546 breathing peaks
# IBI range: 0.250 - 1.310 seconds
# Mean IBI: 0.403 seconds
# No matching file found
# Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
# Found 1526 breathing peaks
# IBI range: 0.250 - 5.360 seconds
# Mean IBI: 0.395 seconds
# Matched with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
# Using 29 FPS
# Saved: FINAL_BOUTS_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx with 289 bouts
# Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
# Found 1617 breathing peaks
# IBI range: 0.250 - 1.290 seconds
# Mean IBI: 0.389 seconds
# Matched with: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx with 305 bouts
# Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
# Found 1540 breathing peaks
# IBI range: 0.250 - 10.900 seconds
# Mean IBI: 0.393 seconds
# Matched with: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx with 303 bouts
# Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
# Found 113 breathing peaks
# IBI range: 0.250 - 172.490 seconds
# Mean IBI: 5.073 seconds
# Matched with: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx with 315 bouts
# Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
# Found 1587 breathing peaks
# IBI range: 0.250 - 1.320 seconds
# Mean IBI: 0.381 seconds
# Matched with: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
# Using 15 FPS
# Saved: FINAL_BOUTS_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx with 221 bouts
# Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
# Found 1413 breathing peaks
# IBI range: 0.250 - 34.410 seconds
# Mean IBI: 0.423 seconds
# Matched with: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx with 198 bouts
# Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
# Found 1452 breathing peaks
# IBI range: 0.250 - 40.930 seconds
# Mean IBI: 0.418 seconds
# Matched with: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx with 188 bouts
# Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
# Found 1312 breathing peaks
# IBI range: 0.250 - 37.220 seconds
# Mean IBI: 0.462 seconds
# Matched with: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
# Using 15 FPS
# Saved: FINAL_BOUTS_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx with 201 bouts
# Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
# Found 556 breathing peaks
# IBI range: 0.250 - 0.800 seconds
# Mean IBI: 0.384 seconds
# Matched with: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx with 115 bouts
# Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
# Found 1529 breathing peaks
# IBI range: 0.250 - 1.240 seconds
# Mean IBI: 0.399 seconds
# Matched with: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx with 180 bouts
# Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
# Found 1572 breathing peaks
# IBI range: 0.250 - 1.190 seconds
# Mean IBI: 0.386 seconds
# Matched with: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx with 238 bouts
# Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
# Found 1502 breathing peaks
# IBI range: 0.250 - 1.090 seconds
# Mean IBI: 0.402 seconds
# Matched with: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx with 197 bouts
# Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
# Found 1210 breathing peaks
# IBI range: 0.250 - 0.980 seconds
# Mean IBI: 0.404 seconds
# Matched with: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
# Using 30 FPS
# Saved: FINAL_BOUTS_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx with 188 bouts
# Added RI1_s1_1_p5_track0: 303 bouts
# Added RI1_s1_2_p5_track0: 266 bouts
# Added RI1_s2_3_p5_track0: 504 bouts
# Added RI1_s2_4_p5_track0: 132 bouts
# Added RI1_s3_6_p5_track0: 289 bouts
# Added RI1_s4_7_p5_track0: 305 bouts
# Added RI1_s4_8_p5_track0: 303 bouts
# Added RI1_s5_13_p5_track0: 315 bouts
# Added RI2_s1_1_p5_track0: 221 bouts
# Added RI2_s1_2_p5_track0: 198 bouts
# Added RI2_s2_3_p5_track0: 188 bouts
# Added RI2_s2_4_p5_track0: 201 bouts
# Added RI2_s3_5_p5_track0: 115 bouts
# Added RI2_s3_6_p_track0: 180 bouts
# Added RI2_s4_7_p5_track0: 238 bouts
# Added RI2_s4_8_p5_track0: 197 bouts
# Added RI2_s5_13_p5_track0: 188 bouts
# Done - processed 17 files
# IBI range: 0.260 - 1.340 seconds
# BPM range: 15.6 - 80.4

# %%
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
import glob
import os

def process_respiratory_bouts_with_improved_peak_detection():
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    
    excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
    excel_files = glob.glob(os.path.join(excel_path, "*track0*.xlsx"))
    
    results = {}
    
    for file_id, resp_data in processed_resp_data.items():
        print(f"Processing {file_id}")
        
        filtered_signal = resp_data['respiration']
        fs = 100
        time_vector = np.arange(len(filtered_signal)) / fs
        
        # Improved peak detection - enforce ≥12 Hz refractory → 0.083 s min distance
        peaks, _ = find_peaks(filtered_signal, distance=fs * 0.0833)
        
        print(f"Found {len(peaks)} breathing peaks")
        
        if len(peaks) < 2:
            continue
            
        peak_times = peaks / fs
        ibi_seconds = np.diff(peak_times)
        breathing_rate_1_over_ibi = 1 / ibi_seconds
        breathing_rate_bpm = breathing_rate_1_over_ibi * 60
        breath_times = peak_times[1:]
        
        print(f"IBI range: {ibi_seconds.min():.3f} - {ibi_seconds.max():.3f} seconds")
        print(f"Mean IBI: {ibi_seconds.mean():.3f} seconds")
        
        matching_excel = None
        for excel_file in excel_files:
            if any(session in file_id and session in excel_file for session in 
                   ['RI1_s1_1', 'RI1_s1_2', 'RI1_s2_3', 'RI1_s2_4', 'RI1_s3_5', 'RI1_s3_6', 
                    'RI1_s4_7', 'RI1_s4_8', 'RI1_s5_13', 'RI2_s1_1', 'RI2_s1_2', 'RI2_s2_3', 
                    'RI2_s2_4', 'RI2_s3_5', 'RI2_s3_6', 'RI2_s4_7', 'RI2_s4_8', 'RI2_s5_13']):
                matching_excel = excel_file
                break
        
        if matching_excel:
            print(f"Matched with: {os.path.basename(matching_excel)}")
            behavior_df = pd.read_excel(matching_excel)
            
            fps_map = {"RI1_s1_1": 15, "RI1_s2_3": 15, "RI1_s3_6": 29, "RI2_s1_1": 15, "RI2_s2_4": 15}
            video_fps = 30
            for pattern, fps in fps_map.items():
                if pattern in os.path.basename(matching_excel):
                    video_fps = fps
                    break
            
            print(f"Using {video_fps} FPS")
            
            behavior_df['time_seconds'] = behavior_df['frame_number'] / video_fps
            behavior_df['behavior_transition'] = (behavior_df['syllable'] != behavior_df['syllable'].shift()).astype(int)
            behavior_df['episode_group'] = behavior_df['behavior_transition'].cumsum()
            
            syllable_bouts = []
            
            for group_id, episode_group in behavior_df.groupby('episode_group'):
                syllable_id = episode_group['syllable'].iloc[0]
                
                bout_start_frame = episode_group['frame_number'].min()
                bout_end_frame = episode_group['frame_number'].max()
                bout_start_time_sec = episode_group['time_seconds'].min()
                bout_end_time_sec = episode_group['time_seconds'].max()
                bout_duration_ms = (bout_end_time_sec - bout_start_time_sec) * 1000
                bout_frame_count = len(episode_group)
                
                if bout_duration_ms >= 500:
                    
                    time_mask = (time_vector >= bout_start_time_sec) & (time_vector <= bout_end_time_sec)
                    bout_resp_signal = filtered_signal[time_mask]
                    
                    if len(bout_resp_signal) > 0:
                        mean_resp = np.mean(bout_resp_signal)
                        min_resp = np.min(bout_resp_signal)
                        max_resp = np.max(bout_resp_signal)
                        resp_range = max_resp - min_resp
                    else:
                        mean_resp = min_resp = max_resp = resp_range = np.nan
                    
                    breath_mask = (breath_times >= bout_start_time_sec) & (breath_times <= bout_end_time_sec)
                    bout_1_over_ibi = breathing_rate_1_over_ibi[breath_mask]
                    bout_bpm = breathing_rate_bpm[breath_mask]
                    bout_ibi = ibi_seconds[breath_mask]
                    
                    if len(bout_1_over_ibi) > 0:
                        mean_1_over_ibi = np.mean(bout_1_over_ibi)
                        mean_bpm = np.mean(bout_bpm)
                        mean_ibi = np.mean(bout_ibi)
                        breath_count = len(bout_1_over_ibi)
                    else:
                        mid_time = (bout_start_time_sec + bout_end_time_sec) / 2
                        if len(breath_times) > 0:
                            mean_1_over_ibi = np.interp(mid_time, breath_times, breathing_rate_1_over_ibi)
                            mean_bpm = mean_1_over_ibi * 60
                            mean_ibi = 1 / mean_1_over_ibi if mean_1_over_ibi > 0 else np.nan
                        else:
                            mean_1_over_ibi = mean_bpm = mean_ibi = np.nan
                        breath_count = 0
                    
                    syllable_bouts.append({
                        'syllable_id': syllable_id,
                        'bout_start_frame': bout_start_frame,
                        'bout_end_frame': bout_end_frame,
                        'bout_start_time_sec': bout_start_time_sec,
                        'bout_end_time_sec': bout_end_time_sec,
                        'bout_duration_ms': bout_duration_ms,
                        'bout_frame_count': bout_frame_count,
                        'fps_used': video_fps,
                        'mean_resp_signal_bandpass': mean_resp,
                        'min_resp_signal_bandpass': min_resp,
                        'max_resp_signal_bandpass': max_resp,
                        'resp_signal_range': resp_range,
                        'mean_1_over_IBI': mean_1_over_ibi,
                        'mean_breathing_rate_BPM': mean_bpm,
                        'mean_IBI_seconds': mean_ibi,
                        'breath_count': breath_count,
                        'video_name': episode_group['video_name'].iloc[0] if 'video_name' in episode_group.columns else 'unknown',
                        'track_name': episode_group['track_name'].iloc[0] if 'track_name' in episode_group.columns else 'track0'
                    })
            
            bouts_df = pd.DataFrame(syllable_bouts)
            bouts_df = bouts_df.sort_values('bout_start_time_sec').reset_index(drop=True)
            
            if len(bouts_df) > 0:
                excel_basename = os.path.basename(matching_excel).replace('.xlsx', '')
                output_file = f"IMPROVED_BOUTS_{excel_basename}.xlsx"
                bouts_df.to_excel(output_file, index=False)
                print(f"Saved: {output_file} with {len(bouts_df)} bouts")
                
                results[file_id] = bouts_df
        else:
            print(f"No matching file found")
    
    return results

def create_master_improved_files():
    bout_files = glob.glob("IMPROVED_BOUTS_*.xlsx")
    
    ri1_files = [f for f in bout_files if "-RI1_" in f]
    ri2_files = [f for f in bout_files if "-RI2_" in f]
    
    def create_master_file(files, output_name):
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"Added {sheet_name}: {len(df)} bouts")
    
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_Improved_Peak_Detection.xlsx")
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_Improved_Peak_Detection.xlsx")

print("Processing with improved peak detection (0.083s minimum distance)")
improved_results = process_respiratory_bouts_with_improved_peak_detection()
create_master_improved_files()
print(f"Done - processed {len(improved_results)} files")

if improved_results:
    sample_key = list(improved_results.keys())[0]
    sample_data = improved_results[sample_key]
    
    valid_ibi = sample_data['mean_IBI_seconds'].dropna()
    if len(valid_ibi) > 0:
        print(f"IBI range: {valid_ibi.min():.3f} - {valid_ibi.max():.3f} seconds")
        print(f"BPM range: {(1/valid_ibi.max())*60:.1f} - {(1/valid_ibi.min())*60:.1f}")
# Out:
# Processing with improved peak detection (0.083s minimum distance)
# Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Found 4740 breathing peaks
# IBI range: 0.090 - 0.650 seconds
# Mean IBI: 0.131 seconds
# Matched with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
# Using 15 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx with 303 bouts
# Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
# Found 4679 breathing peaks
# IBI range: 0.090 - 0.530 seconds
# Mean IBI: 0.129 seconds
# Matched with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx with 266 bouts
# Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
# Found 4467 breathing peaks
# IBI range: 0.090 - 1.100 seconds
# Mean IBI: 0.135 seconds
# Matched with: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
# Using 15 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx with 504 bouts
# Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
# Found 5081 breathing peaks
# IBI range: 0.090 - 0.520 seconds
# Mean IBI: 0.120 seconds
# Matched with: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx with 132 bouts
# Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
# Found 4493 breathing peaks
# IBI range: 0.090 - 0.820 seconds
# Mean IBI: 0.139 seconds
# No matching file found
# Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
# Found 4553 breathing peaks
# IBI range: 0.090 - 0.630 seconds
# Mean IBI: 0.132 seconds
# Matched with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
# Using 29 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx with 289 bouts
# Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
# Found 4975 breathing peaks
# IBI range: 0.090 - 0.600 seconds
# Mean IBI: 0.126 seconds
# Matched with: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx with 305 bouts
# Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
# Found 4672 breathing peaks
# IBI range: 0.090 - 0.700 seconds
# Mean IBI: 0.129 seconds
# Matched with: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx with 303 bouts
# Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
# Found 3274 breathing peaks
# IBI range: 0.090 - 2.020 seconds
# Mean IBI: 0.188 seconds
# Matched with: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx with 315 bouts
# Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
# Found 3649 breathing peaks
# IBI range: 0.090 - 0.440 seconds
# Mean IBI: 0.166 seconds
# Matched with: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
# Using 15 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx with 221 bouts
# Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
# Found 3953 breathing peaks
# IBI range: 0.090 - 0.400 seconds
# Mean IBI: 0.153 seconds
# Matched with: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx with 198 bouts
# Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
# Found 4103 breathing peaks
# IBI range: 0.090 - 0.630 seconds
# Mean IBI: 0.148 seconds
# Matched with: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx with 188 bouts
# Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
# Found 3773 breathing peaks
# IBI range: 0.090 - 1.100 seconds
# Mean IBI: 0.160 seconds
# Matched with: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
# Using 15 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx with 201 bouts
# Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
# Found 1265 breathing peaks
# IBI range: 0.090 - 0.400 seconds
# Mean IBI: 0.169 seconds
# Matched with: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx with 115 bouts
# Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
# Found 3635 breathing peaks
# IBI range: 0.090 - 0.520 seconds
# Mean IBI: 0.168 seconds
# Matched with: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx with 180 bouts
# Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
# Found 3997 breathing peaks
# IBI range: 0.090 - 0.420 seconds
# Mean IBI: 0.152 seconds
# Matched with: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx with 238 bouts
# Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
# Found 3490 breathing peaks
# IBI range: 0.090 - 0.500 seconds
# Mean IBI: 0.173 seconds
# Matched with: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx with 197 bouts
# Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
# Found 3248 breathing peaks
# IBI range: 0.090 - 0.390 seconds
# Mean IBI: 0.151 seconds
# Matched with: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
# Using 30 FPS
# Saved: IMPROVED_BOUTS_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx with 188 bouts
# Added RI1_s1_1_p5_track0: 303 bouts
# Added RI1_s1_2_p5_track0: 266 bouts
# Added RI1_s2_3_p5_track0: 504 bouts
# Added RI1_s2_4_p5_track0: 132 bouts
# Added RI1_s3_6_p5_track0: 289 bouts
# Added RI1_s4_7_p5_track0: 305 bouts
# Added RI1_s4_8_p5_track0: 303 bouts
# Added RI1_s5_13_p5_track0: 315 bouts
# Added RI2_s1_1_p5_track0: 221 bouts
# Added RI2_s1_2_p5_track0: 198 bouts
# Added RI2_s2_3_p5_track0: 188 bouts
# Added RI2_s2_4_p5_track0: 201 bouts
# Added RI2_s3_5_p5_track0: 115 bouts
# Added RI2_s3_6_p_track0: 180 bouts
# Added RI2_s4_7_p5_track0: 238 bouts
# Added RI2_s4_8_p5_track0: 197 bouts
# Added RI2_s5_13_p5_track0: 188 bouts
# Done - processed 17 files
# IBI range: 0.093 - 0.520 seconds
# BPM range: 115.4 - 642.9

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load your processed data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")

# Get the RI1_s1_1 data
ri1_s1_1_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
sig = processed_resp_data[ri1_s1_1_key]['respiration']
Fs = 100

# Apply improved peak detection
peaks, _ = find_peaks(sig, distance=Fs * 0.0833)

# Plot the same segment as before
seg_start_s = 110.0
seg_dur_s = 5.0
i0 = int(seg_start_s * Fs)
i1 = min(int((seg_start_s + seg_dur_s) * Fs), len(sig))

t_local = np.arange(i1 - i0) / Fs

plt.figure(figsize=(12,4))
plt.plot(t_local, sig[i0:i1], lw=1.0, label="resp (0.5-15Hz filtered)")

# Plot improved peaks
mask = (peaks >= i0) & (peaks < i1)
plt.plot((peaks[mask] - i0) / Fs, sig[peaks[mask]], 'ro', ms=5, label=f"improved peaks ({np.sum(mask)} detected)")

# Highlight row 26 behavior (frames 1662-1676 at 15fps = 110.8-111.7s)
behavior_start = 110.8 - seg_start_s
behavior_end = 111.7 - seg_start_s
plt.axvspan(behavior_start, behavior_end, alpha=0.3, color='yellow', label='Row 26: Syllable 19')

plt.xlabel("Time (s)")
plt.ylabel("Resp (a.u.)")
plt.title("Improved Peak Detection (0.083s min distance)")
plt.legend()
plt.tight_layout()
plt.show()

print(f"Peak detection comparison:")
print(f"Before: ~1600 peaks")
print(f"After: {len(peaks)} peaks")
print(f"In this 5s window: {np.sum(mask)} peaks detected")
print(f"Peak rate in window: {np.sum(mask)/5:.1f} peaks per second")
# Out:
# Peak detection comparison:
# Before: ~1600 peaks
# After: 4740 peaks
# In this 5s window: 41 peaks detected
# Peak rate in window: 8.2 peaks per second

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load your processed data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")

# Session 1: RI1_s1_1 - Row 26 area
session_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
sig = processed_resp_data[session_key]['respiration']
Fs = 100
peaks, _ = find_peaks(sig, distance=Fs * 0.0833)

start_time = 110.0
seg_dur_s = 8.0
i0 = int(start_time * Fs)
i1 = min(int((start_time + seg_dur_s) * Fs), len(sig))
t_local = np.arange(i1 - i0) / Fs + start_time

plt.figure(figsize=(12,4))
plt.plot(t_local, sig[i0:i1], 'b-', lw=1.0, label="resp (0.5-15Hz)")
mask = (peaks >= i0) & (peaks < i1)
peak_times = peaks[mask] / Fs
plt.plot(peak_times, sig[peaks[mask]], 'ro', ms=4, label=f"peaks ({np.sum(mask)})")

if np.sum(mask) > 1:
    peak_intervals = np.diff(peak_times)
    mean_rate = (1/np.mean(peak_intervals)) * 60
    plt.text(0.02, 0.95, f'Mean: {mean_rate:.0f} BPM', transform=plt.gca().transAxes, 
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8))

plt.xlabel("Time (s)")
plt.ylabel("Resp (a.u.)")
plt.title("RI1 Session 1_1 - Row 26 area (110-118s)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Session 2: RI1_s2_3 - Mid recording
session_key = [key for key in processed_resp_data.keys() if 'RI1_s2_3' in key][0]
sig = processed_resp_data[session_key]['respiration']
peaks, _ = find_peaks(sig, distance=Fs * 0.0833)

start_time = 200.0
i0 = int(start_time * Fs)
i1 = min(int((start_time + seg_dur_s) * Fs), len(sig))
t_local = np.arange(i1 - i0) / Fs + start_time

plt.figure(figsize=(12,4))
plt.plot(t_local, sig[i0:i1], 'b-', lw=1.0, label="resp (0.5-15Hz)")
mask = (peaks >= i0) & (peaks < i1)
peak_times = peaks[mask] / Fs
plt.plot(peak_times, sig[peaks[mask]], 'ro', ms=4, label=f"peaks ({np.sum(mask)})")

if np.sum(mask) > 1:
    peak_intervals = np.diff(peak_times)
    mean_rate = (1/np.mean(peak_intervals)) * 60
    plt.text(0.02, 0.95, f'Mean: {mean_rate:.0f} BPM', transform=plt.gca().transAxes, 
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8))

plt.xlabel("Time (s)")
plt.ylabel("Resp (a.u.)")
plt.title("RI1 Session 2_3 - Mid recording (200-208s)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Load the respiratory data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
session_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
sig = processed_resp_data[session_key]['respiration']
Fs = 100

# Detect peaks using your current method
peaks, _ = find_peaks(sig, distance=Fs * 0.0833)

# Plot a window to see the peaks
start_time = 110.0
window_duration = 10.0  # 10 seconds
i0 = int(start_time * Fs)
i1 = int((start_time + window_duration) * Fs)

t_plot = np.arange(i0, i1) / Fs
sig_window = sig[i0:i1]

# Find peaks in this window
peak_mask = (peaks >= i0) & (peaks < i1)
window_peaks = peaks[peak_mask]
peak_times = window_peaks / Fs
peak_values = sig[window_peaks]

plt.figure(figsize=(15, 6))
plt.plot(t_plot, sig_window, 'b-', lw=1.0, label="Respiratory signal")
plt.plot(peak_times, peak_values, 'ro', ms=4, label=f"Detected peaks ({len(window_peaks)})")

plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")
plt.title(f"Peak Detection Verification - {len(window_peaks)} peaks in {window_duration} seconds")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(f"Peak detection summary:")
print(f"Total peaks in {window_duration}s window: {len(window_peaks)}")
print(f"Peak rate: {len(window_peaks)/window_duration:.1f} peaks/second")
print(f"Equivalent BPM: {len(window_peaks)/window_duration * 60:.1f}")

# Show first few peak times for reference
print(f"\nFirst 10 peak times:")
for i, peak_time in enumerate(peak_times[:10]):
    print(f"  Peak {i+1}: {peak_time:.3f}s")
# Out:
# Peak detection summary:
# Total peaks in 10.0s window: 80
# Peak rate: 8.0 peaks/second
# Equivalent BPM: 480.0
#
# First 10 peak times:
#   Peak 1: 110.060s
#   Peak 2: 110.190s
#   Peak 3: 110.320s
#   Peak 4: 110.450s
#   Peak 5: 110.590s
#   Peak 6: 110.720s
#   Peak 7: 110.830s
#   Peak 8: 110.930s
#   Peak 9: 111.020s
#   Peak 10: 111.130s

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import pandas as pd

# Load the respiratory data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
session_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
sig = processed_resp_data[session_key]['respiration']
Fs = 100

# Detect peaks using your current method
peaks, _ = find_peaks(sig, distance=Fs * 0.0833)

# Plot a window to see the peaks
start_time = 110.0
window_duration = 10.0
i0 = int(start_time * Fs)
i1 = int((start_time + window_duration) * Fs)

t_plot = np.arange(i0, i1) / Fs
sig_window = sig[i0:i1]

# Find peaks in this window
peak_mask = (peaks >= i0) & (peaks < i1)
window_peaks = peaks[peak_mask]
peak_times = window_peaks / Fs
peak_values = sig[window_peaks]

plt.figure(figsize=(15, 6))
plt.plot(t_plot, sig_window, 'b-', lw=1.0, label="Respiratory signal")
plt.plot(peak_times, peak_values, 'ro', ms=4, label=f"Detected peaks ({len(window_peaks)})")

plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")
plt.title(f"Peak Detection - {len(window_peaks)} peaks in {window_duration} seconds")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(f"Peak summary: {len(window_peaks)} peaks in {window_duration}s = {len(window_peaks)/window_duration * 60:.1f} BPM")
# Out:
# Peak summary: 80 peaks in 10.0s = 480.0 BPM

# %%
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
import glob
import os

def improved_peak_detection(signal, fs=100):
    """Improved peak detection for respiratory signals"""
    
    # Calculate signal characteristics
    signal_std = np.std(signal)
    signal_mean = np.mean(signal)
    
    # Use adaptive thresholds
    height_threshold = signal_mean + 0.3 * signal_std
    prominence_threshold = signal_std * 0.4
    
    # Detect peaks with better parameters
    peaks, properties = find_peaks(signal, 
                                  distance=fs * 0.15,  # 0.15s minimum (400 BPM max)
                                  height=height_threshold,
                                  prominence=prominence_threshold,
                                  width=3)  # Minimum width requirement
    
    return peaks

def create_improved_syllable_bout_files():
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    
    excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
    excel_files = glob.glob(os.path.join(excel_path, "*track0*.xlsx"))
    
    results = {}
    
    for file_id, resp_data in processed_resp_data.items():
        print(f"Processing {file_id}")
        
        filtered_signal = resp_data['respiration']
        fs = 100
        time_vector = np.arange(len(filtered_signal)) / fs
        
        # Use improved peak detection
        peaks = improved_peak_detection(filtered_signal, fs)
        
        print(f"Found {len(peaks)} breathing peaks (improved method)")
        
        if len(peaks) < 2:
            continue
            
        peak_times = peaks / fs
        ibi_seconds = np.diff(peak_times)
        breathing_rate_1_over_ibi = 1 / ibi_seconds
        breathing_rate_bpm = breathing_rate_1_over_ibi * 60
        breath_times = peak_times[1:]
        
        print(f"Breathing rate: {breathing_rate_bpm.mean():.1f} BPM (range: {breathing_rate_bpm.min():.1f}-{breathing_rate_bpm.max():.1f})")
        
        matching_excel = None
        for excel_file in excel_files:
            if any(session in file_id and session in excel_file for session in 
                   ['RI1_s1_1', 'RI1_s1_2', 'RI1_s2_3', 'RI1_s2_4', 'RI1_s3_5', 'RI1_s3_6', 
                    'RI1_s4_7', 'RI1_s4_8', 'RI1_s5_13', 'RI2_s1_1', 'RI2_s1_2', 'RI2_s2_3', 
                    'RI2_s2_4', 'RI2_s3_5', 'RI2_s3_6', 'RI2_s4_7', 'RI2_s4_8', 'RI2_s5_13']):
                matching_excel = excel_file
                break
        
        if matching_excel:
            print(f"Matched with: {os.path.basename(matching_excel)}")
            behavior_df = pd.read_excel(matching_excel)
            
            fps_map = {"RI1_s1_1": 15, "RI1_s2_3": 15, "RI1_s3_6": 29, "RI2_s1_1": 15, "RI2_s2_4": 15}
            video_fps = 30
            for pattern, fps in fps_map.items():
                if pattern in os.path.basename(matching_excel):
                    video_fps = fps
                    break
            
            behavior_df['time_seconds'] = behavior_df['frame_number'] / video_fps
            behavior_df['behavior_transition'] = (behavior_df['syllable'] != behavior_df['syllable'].shift()).astype(int)
            behavior_df['episode_group'] = behavior_df['behavior_transition'].cumsum()
            
            syllable_bouts = []
            
            for group_id, episode_group in behavior_df.groupby('episode_group'):
                syllable_id = episode_group['syllable'].iloc[0]
                
                bout_start_frame = episode_group['frame_number'].min()
                bout_end_frame = episode_group['frame_number'].max()
                bout_start_time_sec = episode_group['time_seconds'].min()
                bout_end_time_sec = episode_group['time_seconds'].max()
                bout_duration_ms = (bout_end_time_sec - bout_start_time_sec) * 1000
                bout_frame_count = len(episode_group)
                
                if bout_duration_ms >= 500:
                    
                    time_mask = (time_vector >= bout_start_time_sec) & (time_vector <= bout_end_time_sec)
                    bout_resp_signal = filtered_signal[time_mask]
                    
                    if len(bout_resp_signal) > 0:
                        mean_resp = np.mean(bout_resp_signal)
                        min_resp = np.min(bout_resp_signal)
                        max_resp = np.max(bout_resp_signal)
                        resp_range = max_resp - min_resp
                    else:
                        mean_resp = min_resp = max_resp = resp_range = np.nan
                    
                    breath_mask = (breath_times >= bout_start_time_sec) & (breath_times <= bout_end_time_sec)
                    bout_1_over_ibi = breathing_rate_1_over_ibi[breath_mask]
                    bout_bpm = breathing_rate_bpm[breath_mask]
                    bout_ibi = ibi_seconds[breath_mask]
                    
                    if len(bout_1_over_ibi) > 0:
                        mean_1_over_ibi = np.mean(bout_1_over_ibi)
                        mean_bpm = np.mean(bout_bpm)
                        mean_ibi = np.mean(bout_ibi)
                        breath_count = len(bout_1_over_ibi)
                    else:
                        mid_time = (bout_start_time_sec + bout_end_time_sec) / 2
                        if len(breath_times) > 0:
                            mean_1_over_ibi = np.interp(mid_time, breath_times, breathing_rate_1_over_ibi)
                            mean_bpm = mean_1_over_ibi * 60
                            mean_ibi = 1 / mean_1_over_ibi if mean_1_over_ibi > 0 else np.nan
                        else:
                            mean_1_over_ibi = mean_bpm = mean_ibi = np.nan
                        breath_count = 0
                    
                    syllable_bouts.append({
                        'syllable_id': syllable_id,
                        'bout_start_frame': bout_start_frame,
                        'bout_end_frame': bout_end_frame,
                        'bout_start_time_sec': bout_start_time_sec,
                        'bout_end_time_sec': bout_end_time_sec,
                        'bout_duration_ms': bout_duration_ms,
                        'bout_frame_count': bout_frame_count,
                        'fps_used': video_fps,
                        'mean_resp_signal_bandpass': mean_resp,
                        'min_resp_signal_bandpass': min_resp,
                        'max_resp_signal_bandpass': max_resp,
                        'resp_signal_range': resp_range,
                        'mean_1_over_IBI': mean_1_over_ibi,
                        'mean_breathing_rate_BPM': mean_bpm,
                        'mean_IBI_seconds': mean_ibi,
                        'breath_count': breath_count,
                        'video_name': episode_group['video_name'].iloc[0] if 'video_name' in episode_group.columns else 'unknown',
                        'track_name': episode_group['track_name'].iloc[0] if 'track_name' in episode_group.columns else 'track0'
                    })
            
            bouts_df = pd.DataFrame(syllable_bouts)
            bouts_df = bouts_df.sort_values('bout_start_time_sec').reset_index(drop=True)
            
            if len(bouts_df) > 0:
                excel_basename = os.path.basename(matching_excel).replace('.xlsx', '')
                output_file = f"FINAL_IMPROVED_{excel_basename}.xlsx"
                bouts_df.to_excel(output_file, index=False)
                print(f"Saved: {output_file} with {len(bouts_df)} bouts")
                
                results[file_id] = bouts_df
    
    return results

def create_final_master_files():
    bout_files = glob.glob("FINAL_IMPROVED_*.xlsx")
    
    ri1_files = [f for f in bout_files if "-RI1_" in f]
    ri2_files = [f for f in bout_files if "-RI2_" in f]
    
    print(f"Found {len(ri1_files)} RI1 files and {len(ri2_files)} RI2 files for master files")
    
    def create_master_file(files, output_name):
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"Added {sheet_name}: {len(df)} bouts")
    
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_Final_Improved_Peaks.xlsx")
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_Final_Improved_Peaks.xlsx")

print("Reprocessing with improved peak detection")
improved_results = create_improved_syllable_bout_files()
create_final_master_files()

print(f"Completed - processed {len(improved_results)} files with improved peak detection")
print("Created final master files:")
print("- RI1_MASTER_Final_Improved_Peaks.xlsx") 
print("- RI2_MASTER_Final_Improved_Peaks.xlsx")

# Verify the improvement
if improved_results:
    sample_key = list(improved_results.keys())[0]
    sample_data = improved_results[sample_key]
    
    valid_bpm = sample_data['mean_breathing_rate_BPM'].dropna()
    if len(valid_bpm) > 0:
        print(f"\nImproved results verification:")
        print(f"BPM range: {valid_bpm.min():.1f} - {valid_bpm.max():.1f}")
        print(f"Mean BPM: {valid_bpm.mean():.1f}")
        print(f"This should be more realistic than 480+ BPM!")
# Out:
# Reprocessing with improved peak detection
# Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Found 2312 breathing peaks (improved method)
# Breathing rate: 252.2 BPM (range: 27.5-400.0)
# Matched with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx with 303 bouts
# Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
# Found 2248 breathing peaks (improved method)
# Breathing rate: 253.0 BPM (range: 16.4-400.0)
# Matched with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx with 266 bouts
# Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
# Found 2100 breathing peaks (improved method)
# Breathing rate: 250.8 BPM (range: 3.9-400.0)
# Matched with: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx with 504 bouts
# Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
# Found 2478 breathing peaks (improved method)
# Breathing rate: 263.9 BPM (range: 48.4-400.0)
# Matched with: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx with 132 bouts
# Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
# Found 2282 breathing peaks (improved method)
# Breathing rate: 250.2 BPM (range: 42.0-400.0)
# Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
# Found 2285 breathing peaks (improved method)
# Breathing rate: 254.6 BPM (range: 11.6-400.0)
# Matched with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx with 289 bouts
# Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
# Found 2399 breathing peaks (improved method)
# Breathing rate: 254.1 BPM (range: 32.6-400.0)
# Matched with: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx with 305 bouts
# Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
# Found 2314 breathing peaks (improved method)
# Breathing rate: 260.5 BPM (range: 5.2-400.0)
# Matched with: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx with 303 bouts
# Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
# Found 115 breathing peaks (improved method)
# Breathing rate: 146.9 BPM (range: 0.3-375.0)
# Matched with: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx with 315 bouts
# Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
# Found 2613 breathing peaks (improved method)
# Breathing rate: 282.1 BPM (range: 45.8-400.0)
# Matched with: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx with 221 bouts
# Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
# Found 2324 breathing peaks (improved method)
# Breathing rate: 280.6 BPM (range: 1.7-400.0)
# Matched with: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx with 198 bouts
# Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
# Found 2360 breathing peaks (improved method)
# Breathing rate: 279.4 BPM (range: 1.2-400.0)
# Matched with: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx with 188 bouts
# Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
# Found 2232 breathing peaks (improved method)
# Breathing rate: 289.8 BPM (range: 1.6-400.0)
# Matched with: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx with 201 bouts
# Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
# Found 909 breathing peaks (improved method)
# Breathing rate: 278.1 BPM (range: 74.1-400.0)
# Matched with: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx with 115 bouts
# Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
# Found 2579 breathing peaks (improved method)
# Breathing rate: 285.4 BPM (range: 30.2-400.0)
# Matched with: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx with 180 bouts
# Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
# Found 2611 breathing peaks (improved method)
# Breathing rate: 292.2 BPM (range: 40.0-400.0)
# Matched with: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx with 238 bouts
# Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
# Found 2721 breathing peaks (improved method)
# Breathing rate: 297.3 BPM (range: 52.2-400.0)
# Matched with: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx with 197 bouts
# Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
# Found 1557 breathing peaks (improved method)
# Breathing rate: 224.7 BPM (range: 63.2-400.0)
# Matched with: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
# Saved: FINAL_IMPROVED_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx with 188 bouts
# Found 8 RI1 files and 9 RI2 files for master files
# Added RI1_s1_1_p5_track0: 303 bouts
# Added RI1_s1_2_p5_track0: 266 bouts
# Added RI1_s2_3_p5_track0: 504 bouts
# Added RI1_s2_4_p5_track0: 132 bouts
# Added RI1_s3_6_p5_track0: 289 bouts
# Added RI1_s4_7_p5_track0: 305 bouts
# Added RI1_s4_8_p5_track0: 303 bouts
# Added RI1_s5_13_p5_track0: 315 bouts
# Added RI2_s1_1_p5_track0: 221 bouts
# Added RI2_s1_2_p5_track0: 198 bouts
# Added RI2_s2_3_p5_track0: 188 bouts
# Added RI2_s2_4_p5_track0: 201 bouts
# Added RI2_s3_5_p5_track0: 115 bouts
# Added RI2_s3_6_p_track0: 180 bouts
# Added RI2_s4_7_p5_track0: 238 bouts
# Added RI2_s4_8_p5_track0: 197 bouts
# Added RI2_s5_13_p5_track0: 188 bouts
# Completed - processed 17 files with improved peak detection
# Created final master files:
# - RI1_MASTER_Final_Improved_Peaks.xlsx
# - RI2_MASTER_Final_Improved_Peaks.xlsx
#
# Improved results verification:
# BPM range: 44.8 - 360.3
# Mean BPM: 238.8
# This should be more realistic than 480+ BPM!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Load the improved Excel file
improved_excel = "FINAL_IMPROVED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx"
bouts_df = pd.read_excel(improved_excel)

print("Available syllable bouts:")
print(bouts_df[['syllable_id', 'bout_start_time_sec', 'bout_end_time_sec', 'bout_duration_ms', 'mean_breathing_rate_BPM']].head(10))

# Pick a specific syllable bout to verify
syllable_row = 5  # Change this to pick different rows
selected_bout = bouts_df.iloc[syllable_row]

print(f"\nSelected syllable bout (row {syllable_row}):")
print(f"Syllable ID: {selected_bout['syllable_id']}")
print(f"Time: {selected_bout['bout_start_time_sec']:.2f} - {selected_bout['bout_end_time_sec']:.2f} seconds")
print(f"Duration: {selected_bout['bout_duration_ms']:.0f} ms")
print(f"Excel says BPM: {selected_bout['mean_breathing_rate_BPM']:.1f}")
print(f"Excel says 1/IBI: {selected_bout['mean_1_over_IBI']:.3f}")
print(f"Excel says breath count: {selected_bout['breath_count']}")

# Load the corresponding respiratory data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
session_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
sig = processed_resp_data[session_key]['respiration']
Fs = 100

# Apply the improved peak detection (same as in processing)
def improved_peak_detection(signal, fs=100):
    signal_std = np.std(signal)
    signal_mean = np.mean(signal)
    height_threshold = signal_mean + 0.3 * signal_std
    prominence_threshold = signal_std * 0.4
    
    peaks, _ = find_peaks(signal, 
                         distance=fs * 0.15,
                         height=height_threshold,
                         prominence=prominence_threshold,
                         width=3)
    return peaks

peaks = improved_peak_detection(sig, Fs)

# Set up plotting window with context around the syllable
context_before = 2.0  # 2 seconds before
context_after = 2.0   # 2 seconds after

plot_start_time = max(0, selected_bout['bout_start_time_sec'] - context_before)
plot_end_time = min(len(sig)/Fs, selected_bout['bout_end_time_sec'] + context_after)

i0 = int(plot_start_time * Fs)
i1 = int(plot_end_time * Fs)
t_plot = np.arange(i0, i1) / Fs

# Find peaks in plotting window
peak_mask = (peaks >= i0) & (peaks < i1)
window_peaks = peaks[peak_mask]
peak_times = window_peaks / Fs

# Find peaks specifically within the syllable bout
syllable_peak_mask = (peak_times >= selected_bout['bout_start_time_sec']) & (peak_times <= selected_bout['bout_end_time_sec'])
syllable_peaks = peak_times[syllable_peak_mask]

# Plot the verification
plt.figure(figsize=(15, 8))

# Main plot
plt.subplot(2, 1, 1)
plt.plot(t_plot, sig[i0:i1], 'b-', lw=1.0, label="Respiratory signal")
plt.plot(peak_times, sig[window_peaks], 'ro', ms=4, label=f"All detected peaks ({len(window_peaks)})")
plt.plot(syllable_peaks, sig[(syllable_peaks * Fs).astype(int)], 'go', ms=6, 
         label=f"Peaks in syllable ({len(syllable_peaks)})")

# Highlight the syllable bout
plt.axvspan(selected_bout['bout_start_time_sec'], selected_bout['bout_end_time_sec'], 
           alpha=0.3, color='yellow', label=f"Syllable {selected_bout['syllable_id']} bout")
plt.axvline(selected_bout['bout_start_time_sec'], color='orange', linestyle='--', alpha=0.7)
plt.axvline(selected_bout['bout_end_time_sec'], color='red', linestyle='--', alpha=0.7)

plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")
plt.title(f"Syllable {selected_bout['syllable_id']} Verification - Row {syllable_row}")
plt.legend()
plt.grid(True, alpha=0.3)

# Zoomed view of just the syllable
plt.subplot(2, 1, 2)
syllable_i0 = int(selected_bout['bout_start_time_sec'] * Fs)
syllable_i1 = int(selected_bout['bout_end_time_sec'] * Fs)
syllable_t = np.arange(syllable_i0, syllable_i1) / Fs

plt.plot(syllable_t, sig[syllable_i0:syllable_i1], 'b-', lw=2, label="Syllable respiratory signal")
if len(syllable_peaks) > 0:
    plt.plot(syllable_peaks, sig[(syllable_peaks * Fs).astype(int)], 'ro', ms=8, 
             label=f"Peaks in syllable ({len(syllable_peaks)})")

plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")
plt.title(f"Zoomed: Syllable {selected_bout['syllable_id']} Only")
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Manual verification
if len(syllable_peaks) > 1:
    manual_ibis = np.diff(syllable_peaks)
    manual_mean_ibi = np.mean(manual_ibis)
    manual_1_over_ibi = 1 / manual_mean_ibi
    manual_bpm = manual_1_over_ibi * 60
    
    print(f"\nManual calculation from graph:")
    print(f"  Peaks in syllable: {len(syllable_peaks)}")
    print(f"  Manual mean IBI: {manual_mean_ibi:.3f}s")
    print(f"  Manual 1/IBI: {manual_1_over_ibi:.3f} breaths/sec")
    print(f"  Manual BPM: {manual_bpm:.1f}")
    
    print(f"\nExcel file values:")
    print(f"  Excel breath count: {selected_bout['breath_count']}")
    print(f"  Excel mean IBI: {selected_bout['mean_IBI_seconds']:.3f}s")
    print(f"  Excel 1/IBI: {selected_bout['mean_1_over_IBI']:.3f} breaths/sec")
    print(f"  Excel BPM: {selected_bout['mean_breathing_rate_BPM']:.1f}")
    
    print(f"\nMatch check:")
    bpm_match = abs(manual_bpm - selected_bout['mean_breathing_rate_BPM']) < 5
    peak_count_match = len(syllable_peaks) == selected_bout['breath_count']
    print(f"  BPM match (±5): {bpm_match}")
    print(f"  Peak count match: {peak_count_match}")
    
else:
    print(f"\nNot enough peaks in syllable for verification")
    print(f"Graph shows: {len(syllable_peaks)} peaks")
    print(f"Excel shows: {selected_bout['breath_count']} breath count")

print(f"\nTo try a different syllable, change 'syllable_row' to another number (0-{len(bouts_df)-1})")
# Out:
# Available syllable bouts:
#    syllable_id  bout_start_time_sec  bout_end_time_sec  bout_duration_ms  \
# 0           21             0.000000           1.666667       1666.666667
# 1           28             1.733333           2.266667        533.333333
# 2            7             3.133333           4.400000       1266.666667
# 3           16             4.600000           7.333333       2733.333333
# 4            5             7.533333           8.066667        533.333333
# 5           21             9.933333          10.800000        866.666667
# 6           25            11.266667          13.266667       2000.000000
# 7           13            15.933333          16.866667        933.333333
# 8           13            18.400000          19.266667        866.666667
# 9           20            21.533333          22.200000        666.666667
#
#    mean_breathing_rate_BPM
# 0               286.931615
# 1               360.294118
# 2               308.758170
# 3               313.062892
# 4               282.051282
# 5               337.254902
# 6               294.113886
# 7               259.663866
# 8               263.795853
# 9               269.164760
#
# Selected syllable bout (row 5):
# Syllable ID: 21
# Time: 9.93 - 10.80 seconds
# Duration: 867 ms
# Excel says BPM: 337.3
# Excel says 1/IBI: 5.621
# Excel says breath count: 5
# Manual calculation from graph:
#   Peaks in syllable: 5
#   Manual mean IBI: 0.178s
#   Manual 1/IBI: 5.634 breaths/sec
#   Manual BPM: 338.0
#
# Excel file values:
#   Excel breath count: 5
#   Excel mean IBI: 0.178s
#   Excel 1/IBI: 5.621 breaths/sec
#   Excel BPM: 337.3
#
# Match check:
#   BPM match (±5): True
#   Peak count match: True
#
# To try a different syllable, change 'syllable_row' to another number (0-302)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def better_peak_detection(signal, fs=100):
    """Much better peak detection for respiratory signals"""
    
    # Method 1: Detect all positive peaks with minimal restrictions
    peaks_all, _ = find_peaks(signal, distance=fs * 0.08)  # 0.08s = 750 BPM max
    
    # Method 2: Filter by prominence to keep real breathing peaks
    signal_std = np.std(signal)
    peaks_filtered, properties = find_peaks(signal, 
                                           distance=fs * 0.08,  # Allow closer peaks
                                           prominence=signal_std * 0.2,  # Lower prominence
                                           height=np.mean(signal))  # Above mean only
    
    return peaks_filtered

# Load the same data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
session_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
sig = processed_resp_data[session_key]['respiration']
Fs = 100

# Apply the better peak detection
peaks_better = better_peak_detection(sig, Fs)

# Test on the same syllable bout from your screenshot
syllable_start = 10.0  # From your screenshot
syllable_end = 10.8    # From your screenshot

# Plot comparison
plot_start = 8.0
plot_end = 13.0
i0 = int(plot_start * Fs)
i1 = int(plot_end * Fs)
t_plot = np.arange(i0, i1) / Fs

# Find peaks in window
peak_mask_better = (peaks_better >= i0) & (peaks_better < i1)
window_peaks_better = peaks_better[peak_mask_better]
peak_times_better = window_peaks_better / Fs

# Find peaks in syllable
syllable_peak_mask = (peak_times_better >= syllable_start) & (peak_times_better <= syllable_end)
syllable_peaks_better = peak_times_better[syllable_peak_mask]

plt.figure(figsize=(15, 10))

# Top plot: Full window
plt.subplot(3, 1, 1)
plt.plot(t_plot, sig[i0:i1], 'b-', lw=1.0, label="Respiratory signal")
plt.plot(peak_times_better, sig[window_peaks_better], 'ro', ms=4, 
         label=f"Better detection ({len(window_peaks_better)} peaks)")
plt.axvspan(syllable_start, syllable_end, alpha=0.3, color='yellow', label="Syllable 21 bout")
plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")
plt.title("Better Peak Detection")
plt.legend()
plt.grid(True, alpha=0.3)

# Middle plot: Zoomed syllable
plt.subplot(3, 1, 2)
syl_i0 = int(syllable_start * Fs)
syl_i1 = int(syllable_end * Fs)
syl_t = np.arange(syl_i0, syl_i1) / Fs

plt.plot(syl_t, sig[syl_i0:syl_i1], 'b-', lw=2, label="Syllable signal")
if len(syllable_peaks_better) > 0:
    plt.plot(syllable_peaks_better, sig[(syllable_peaks_better * Fs).astype(int)], 'ro', ms=8, 
             label=f"Peaks in syllable ({len(syllable_peaks_better)})")

plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")
plt.title(f"Zoomed: Better Detection - {len(syllable_peaks_better)} peaks detected")
plt.legend()
plt.grid(True, alpha=0.3)

# Bottom plot: Manual count verification
plt.subplot(3, 1, 3)
plt.plot(syl_t, sig[syl_i0:syl_i1], 'b-', lw=3)

# Let's manually mark where we think peaks should be by visual inspection
manual_peak_times = []
for i, t in enumerate(syl_t[:-10]):
    current_val = sig[syl_i0 + i]
    # Look for local maxima in a small window
    window_start = max(0, i-5)
    window_end = min(len(syl_t), i+5)
    window_vals = sig[syl_i0 + window_start:syl_i0 + window_end]
    
    if current_val == np.max(window_vals) and current_val > np.mean(sig[syl_i0:syl_i1]):
        if len(manual_peak_times) == 0 or (t - manual_peak_times[-1]) > 0.06:  # At least 60ms apart
            manual_peak_times.append(t)

manual_peak_times = np.array(manual_peak_times)
if len(manual_peak_times) > 0:
    plt.plot(manual_peak_times, sig[(manual_peak_times * Fs).astype(int)], 'go', ms=8, 
             label=f"Manual detection ({len(manual_peak_times)} peaks)")

plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")
plt.title("Manual Peak Detection for Comparison")
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Detection comparison for syllable bout:")
print(f"Original method: 5 peaks")
print(f"Better method: {len(syllable_peaks_better)} peaks")
print(f"Manual method: {len(manual_peak_times)} peaks")

if len(syllable_peaks_better) > 1:
    better_ibis = np.diff(syllable_peaks_better)
    better_bpm = (1/np.mean(better_ibis)) * 60
    print(f"Better method BPM: {better_bpm:.1f}")

if len(manual_peak_times) > 1:
    manual_ibis = np.diff(manual_peak_times)
    manual_bpm = (1/np.mean(manual_ibis)) * 60
    print(f"Manual method BPM: {manual_bpm:.1f}")
# Out:
# Detection comparison for syllable bout:
# Original method: 5 peaks
# Better method: 9 peaks
# Manual method: 8 peaks
# Better method BPM: 676.1
# Manual method BPM: 677.4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Load the improved Excel file to get exact syllable timing
improved_excel = "FINAL_IMPROVED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx"
bouts_df = pd.read_excel(improved_excel)

# Pick a specific syllable bout
syllable_row = 5
selected_bout = bouts_df.iloc[syllable_row]

# Get EXACT timing from Excel
exact_start = selected_bout['bout_start_time_sec']
exact_end = selected_bout['bout_end_time_sec']
syllable_id = selected_bout['syllable_id']

# Load respiratory data
processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
session_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
sig = processed_resp_data[session_key]['respiration']
Fs = 100

# Apply peak detection
def better_peak_detection(signal, fs=100):
    signal_std = np.std(signal)
    peaks_filtered, _ = find_peaks(signal,
                                  distance=fs * 0.08,
                                  prominence=signal_std * 0.2,
                                  height=np.mean(signal))
    return peaks_filtered

peaks = better_peak_detection(sig, Fs)
peak_times = peaks / Fs

# Find peaks within EXACT syllable boundaries
syllable_peak_mask = (peak_times >= exact_start) & (peak_times <= exact_end)
syllable_peaks = peak_times[syllable_peak_mask]

# Plot with exact boundaries
context = 1.0  # 1 second before/after for context
plot_start = max(0, exact_start - context)
plot_end = min(len(sig)/Fs, exact_end + context)

i0 = int(plot_start * Fs)
i1 = int(plot_end * Fs)
t_plot = np.arange(i0, i1) / Fs

plt.figure(figsize=(15, 6))
plt.plot(t_plot, sig[i0:i1], 'b-', lw=2, label="Respiratory signal")

# Show all peaks in window
window_peaks = peak_times[(peak_times >= plot_start) & (peak_times <= plot_end)]
plt.plot(window_peaks, sig[(window_peaks * Fs).astype(int)], 'ro', ms=4, alpha=0.5, label="All peaks")

# Highlight peaks within exact syllable  
plt.plot(syllable_peaks, sig[(syllable_peaks * Fs).astype(int)], 'go', ms=8,
         label=f"Peaks in syllable ({len(syllable_peaks)})")

# Mark EXACT syllable boundaries with vertical lines
plt.axvline(exact_start, color='red', linestyle='-', linewidth=3, alpha=0.8, label=f'Syllable START: {exact_start:.3f}s')
plt.axvline(exact_end, color='red', linestyle='-', linewidth=3, alpha=0.8, label=f'Syllable END: {exact_end:.3f}s')

# Shade the exact syllable area
plt.axvspan(exact_start, exact_end, alpha=0.3, color='yellow', label=f'Syllable {syllable_id} EXACT bounds')

plt.xlabel("Time (seconds)")
plt.ylabel("Respiratory Signal")  
plt.title(f"EXACT Syllable Boundaries - Syllable {syllable_id}")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print("=== EXACT SYLLABLE INFORMATION ===")
print(f"Video file: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5")
print(f"Excel file: FINAL_IMPROVED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx")
print(f"Excel row: {syllable_row + 1} (with headers) or row {syllable_row} (0-indexed)")
print(f"")
print(f"Syllable ID: {syllable_id}")
print(f"EXACT start time: {exact_start:.6f} seconds")
print(f"EXACT end time: {exact_end:.6f} seconds")
print(f"EXACT duration: {(exact_end - exact_start)*1000:.1f} milliseconds")
print(f"")
print(f"Frame information:")
print(f"Start frame: {selected_bout['bout_start_frame']}")
print(f"End frame: {selected_bout['bout_end_frame']}")
print(f"Frame rate: {selected_bout['fps_used']} FPS")
print(f"")
print(f"Peaks detected in EXACT syllable bounds: {len(syllable_peaks)}")
print(f"Excel file says breath_count: {selected_bout['breath_count']}")
print(f"Excel file says BPM: {selected_bout['mean_breathing_rate_BPM']:.1f}")

if len(syllable_peaks) > 1:
    manual_bpm = (1/np.mean(np.diff(syllable_peaks))) * 60
    print(f"Manual calculation BPM: {manual_bpm:.1f}")
    print(f"Match: {abs(manual_bpm - selected_bout['mean_breathing_rate_BPM']) < 5}")  # Fixed typo here
# Out:
# === EXACT SYLLABLE INFORMATION ===
# Video file: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Excel file: FINAL_IMPROVED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
# Excel row: 6 (with headers) or row 5 (0-indexed)
#
# Syllable ID: 21
# EXACT start time: 9.933333 seconds
# EXACT end time: 10.800000 seconds
# EXACT duration: 866.7 milliseconds
#
# Frame information:
# Start frame: 149
# End frame: 162
# Frame rate: 15 FPS
#
# Peaks detected in EXACT syllable bounds: 9
# Excel file says breath_count: 5
# Excel file says BPM: 337.3
# Manual calculation BPM: 676.1
# Match: False

# %%
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
import glob
import os

def create_excel_matching_graph_peaks():
    """Create Excel files where breath_count matches exactly what graphs show"""
    
    # Load respiratory data
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    
    excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
    excel_files = glob.glob(os.path.join(excel_path, "*track0*.xlsx"))
    
    def graph_peak_detection(signal, fs=100):
        """EXACT same peak detection as shown in verification graphs"""
        signal_std = np.std(signal)
        peaks, _ = find_peaks(signal,
                             distance=fs * 0.08,
                             prominence=signal_std * 0.2,
                             height=np.mean(signal))
        return peaks
    
    results = {}
    
    for file_id, resp_data in processed_resp_data.items():
        print(f"Processing {file_id}")
        
        filtered_signal = resp_data['respiration']
        fs = 100
        time_vector = np.arange(len(filtered_signal)) / fs
        
        # Use EXACT same peak detection as graphs
        peaks = graph_peak_detection(filtered_signal, fs)
        peak_times = peaks / fs
        
        print(f"Total peaks detected: {len(peaks)}")
        
        if len(peaks) < 2:
            continue
            
        # Calculate breathing rates from peaks
        ibi_seconds = np.diff(peak_times)
        breathing_rate_1_over_ibi = 1 / ibi_seconds
        breathing_rate_bpm = breathing_rate_1_over_ibi * 60
        breath_times = peak_times[1:]
        
        # Find matching Excel file
        matching_excel = None
        for excel_file in excel_files:
            if any(session in file_id and session in excel_file for session in 
                   ['RI1_s1_1', 'RI1_s1_2', 'RI1_s2_3', 'RI1_s2_4', 'RI1_s3_5', 'RI1_s3_6', 
                    'RI1_s4_7', 'RI1_s4_8', 'RI1_s5_13', 'RI2_s1_1', 'RI2_s1_2', 'RI2_s2_3', 
                    'RI2_s2_4', 'RI2_s3_5', 'RI2_s3_6', 'RI2_s4_7', 'RI2_s4_8', 'RI2_s5_13']):
                matching_excel = excel_file
                break
        
        if matching_excel:
            print(f"Matched with: {os.path.basename(matching_excel)}")
            behavior_df = pd.read_excel(matching_excel)
            
            fps_map = {"RI1_s1_1": 15, "RI1_s2_3": 15, "RI1_s3_6": 29, "RI2_s1_1": 15, "RI2_s2_4": 15}
            video_fps = 30
            for pattern, fps in fps_map.items():
                if pattern in os.path.basename(matching_excel):
                    video_fps = fps
                    break
            
            behavior_df['time_seconds'] = behavior_df['frame_number'] / video_fps
            behavior_df['behavior_transition'] = (behavior_df['syllable'] != behavior_df['syllable'].shift()).astype(int)
            behavior_df['episode_group'] = behavior_df['behavior_transition'].cumsum()
            
            syllable_bouts = []
            
            for group_id, episode_group in behavior_df.groupby('episode_group'):
                syllable_id = episode_group['syllable'].iloc[0]
                
                bout_start_frame = episode_group['frame_number'].min()
                bout_end_frame = episode_group['frame_number'].max()
                bout_start_time_sec = episode_group['time_seconds'].min()
                bout_end_time_sec = episode_group['time_seconds'].max()
                bout_duration_ms = (bout_end_time_sec - bout_start_time_sec) * 1000
                bout_frame_count = len(episode_group)
                
                if bout_duration_ms >= 500:
                    
                    # Respiratory signal stats
                    time_mask = (time_vector >= bout_start_time_sec) & (time_vector <= bout_end_time_sec)
                    bout_resp_signal = filtered_signal[time_mask]
                    
                    if len(bout_resp_signal) > 0:
                        mean_resp = np.mean(bout_resp_signal)
                        min_resp = np.min(bout_resp_signal)
                        max_resp = np.max(bout_resp_signal)
                        resp_range = max_resp - min_resp
                    else:
                        mean_resp = min_resp = max_resp = resp_range = np.nan
                    
                    # COUNT PEAKS WITHIN EXACT SYLLABLE BOUNDARIES
                    syllable_peak_mask = (peak_times >= bout_start_time_sec) & (peak_times <= bout_end_time_sec)
                    syllable_peak_times = peak_times[syllable_peak_mask]
                    actual_breath_count = len(syllable_peak_times)
                    
                    # Calculate breathing rates ONLY from peaks within this syllable
                    if len(syllable_peak_times) > 1:
                        syllable_ibis = np.diff(syllable_peak_times)
                        mean_ibi = np.mean(syllable_ibis)
                        mean_1_over_ibi = 1 / mean_ibi
                        mean_bpm = mean_1_over_ibi * 60
                    else:
                        # If less than 2 peaks, interpolate from nearest
                        mid_time = (bout_start_time_sec + bout_end_time_sec) / 2
                        if len(breath_times) > 0:
                            mean_1_over_ibi = np.interp(mid_time, breath_times, breathing_rate_1_over_ibi)
                            mean_bpm = mean_1_over_ibi * 60
                            mean_ibi = 1 / mean_1_over_ibi if mean_1_over_ibi > 0 else np.nan
                        else:
                            mean_1_over_ibi = mean_bpm = mean_ibi = np.nan
                    
                    syllable_bouts.append({
                        'syllable_id': syllable_id,
                        'bout_start_frame': bout_start_frame,
                        'bout_end_frame': bout_end_frame,
                        'bout_start_time_sec': bout_start_time_sec,
                        'bout_end_time_sec': bout_end_time_sec,
                        'bout_duration_ms': bout_duration_ms,
                        'bout_frame_count': bout_frame_count,
                        'fps_used': video_fps,
                        'mean_resp_signal_bandpass': mean_resp,
                        'min_resp_signal_bandpass': min_resp,
                        'max_resp_signal_bandpass': max_resp,
                        'resp_signal_range': resp_range,
                        'mean_1_over_IBI': mean_1_over_ibi,
                        'mean_breathing_rate_BPM': mean_bpm,
                        'mean_IBI_seconds': mean_ibi,
                        'breath_count': actual_breath_count,  # THIS NOW MATCHES GRAPH
                        'video_name': episode_group['video_name'].iloc[0] if 'video_name' in episode_group.columns else 'unknown',
                        'track_name': episode_group['track_name'].iloc[0] if 'track_name' in episode_group.columns else 'track0'
                    })
            
            bouts_df = pd.DataFrame(syllable_bouts)
            bouts_df = bouts_df.sort_values('bout_start_time_sec').reset_index(drop=True)
            
            if len(bouts_df) > 0:
                excel_basename = os.path.basename(matching_excel).replace('.xlsx', '')
                output_file = f"CORRECTED_PEAK_COUNT_{excel_basename}.xlsx"
                bouts_df.to_excel(output_file, index=False)
                print(f"Saved: {output_file} with {len(bouts_df)} bouts")
                
                results[file_id] = bouts_df
    
    return results

def create_corrected_master_files():
    """Create master files with corrected peak counts"""
    bout_files = glob.glob("CORRECTED_PEAK_COUNT_*.xlsx")
    
    ri1_files = [f for f in bout_files if "-RI1_" in f]
    ri2_files = [f for f in bout_files if "-RI2_" in f]
    
    print(f"Creating master files from {len(ri1_files)} RI1 and {len(ri2_files)} RI2 files")
    
    def create_master_file(files, output_name):
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"Added {sheet_name}: {len(df)} bouts")
    
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_Corrected_Peak_Counts.xlsx")
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_Corrected_Peak_Counts.xlsx")

print("Creating Excel files with corrected peak counts that match graphs...")
corrected_results = create_excel_matching_graph_peaks()
create_corrected_master_files()

print(f"Done! Created {len(corrected_results)} files where breath_count matches graph peaks")
print("Files: CORRECTED_PEAK_COUNT_*.xlsx")
print("Masters: RI1_MASTER_Corrected_Peak_Counts.xlsx, RI2_MASTER_Corrected_Peak_Counts.xlsx")

# Verify the correction worked
test_file = "CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx"
if os.path.exists(test_file):
    df = pd.read_excel(test_file)
    row5 = df.iloc[5]
    print(f"\nVerification - Row 5 (Syllable {row5['syllable_id']}):")
    print(f"New breath_count: {row5['breath_count']} (should match graph peaks)")
    print(f"New BPM: {row5['mean_breathing_rate_BPM']:.1f}")
# Out:
# Creating Excel files with corrected peak counts that match graphs...
# Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Total peaks detected: 4566
# Matched with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx with 303 bouts
# Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
# Total peaks detected: 4495
# Matched with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx with 266 bouts
# Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
# Total peaks detected: 4091
# Matched with: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx with 504 bouts
# Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
# Total peaks detected: 5100
# Matched with: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx with 132 bouts
# Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
# Total peaks detected: 4163
# Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
# Total peaks detected: 4233
# Matched with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx with 289 bouts
# Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
# Total peaks detected: 4682
# Matched with: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx with 305 bouts
# Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
# Total peaks detected: 4363
# Matched with: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx with 303 bouts
# Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
# Total peaks detected: 163
# Matched with: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx with 315 bouts
# Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
# Total peaks detected: 3606
# Matched with: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx with 221 bouts
# Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
# Total peaks detected: 3529
# Matched with: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx with 198 bouts
# Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
# Total peaks detected: 3673
# Matched with: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx with 188 bouts
# Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
# Total peaks detected: 3187
# Matched with: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx with 201 bouts
# Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
# Total peaks detected: 1231
# Matched with: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx with 115 bouts
# Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
# Total peaks detected: 3412
# Matched with: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx with 180 bouts
# Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
# Total peaks detected: 3822
# Matched with: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx with 238 bouts
# Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
# Total peaks detected: 3360
# Matched with: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx with 197 bouts
# Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
# Total peaks detected: 2686
# Matched with: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx with 188 bouts
# Creating master files from 8 RI1 and 9 RI2 files
# Added RI1_s1_1_p5_track0: 303 bouts
# Added RI1_s1_2_p5_track0: 266 bouts
# Added RI1_s2_3_p5_track0: 504 bouts
# Added RI1_s2_4_p5_track0: 132 bouts
# Added RI1_s3_6_p5_track0: 289 bouts
# Added RI1_s4_7_p5_track0: 305 bouts
# Added RI1_s4_8_p5_track0: 303 bouts
# Added RI1_s5_13_p5_track0: 315 bouts
# Added RI2_s1_1_p5_track0: 221 bouts
# Added RI2_s1_2_p5_track0: 198 bouts
# Added RI2_s2_3_p5_track0: 188 bouts
# Added RI2_s2_4_p5_track0: 201 bouts
# Added RI2_s3_5_p5_track0: 115 bouts
# Added RI2_s3_6_p_track0: 180 bouts
# Added RI2_s4_7_p5_track0: 238 bouts
# Added RI2_s4_8_p5_track0: 197 bouts
# Added RI2_s5_13_p5_track0: 188 bouts
# Done! Created 17 files where breath_count matches graph peaks
# Files: CORRECTED_PEAK_COUNT_*.xlsx
# Masters: RI1_MASTER_Corrected_Peak_Counts.xlsx, RI2_MASTER_Corrected_Peak_Counts.xlsx
#
# Verification - Row 5 (Syllable 21):
# New breath_count: 9 (should match graph peaks)
# New BPM: 676.1

# %%
import numpy as np
import pandas as pd
from scipy.signal import find_peaks
import glob
import os

def create_excel_matching_graph_peaks():
    """Create Excel files where breath_count matches exactly what graphs show"""
    
    # Load respiratory data
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    
    excel_path = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
    excel_files = glob.glob(os.path.join(excel_path, "*track0*.xlsx"))
    
    def graph_peak_detection(signal, fs=100):
        """EXACT same peak detection as shown in verification graphs"""
        signal_std = np.std(signal)
        peaks, _ = find_peaks(signal,
                             distance=fs * 0.08,
                             prominence=signal_std * 0.2,
                             height=np.mean(signal))
        return peaks
    
    results = {}
    
    for file_id, resp_data in processed_resp_data.items():
        print(f"Processing {file_id}")
        
        filtered_signal = resp_data['respiration']
        fs = 100
        time_vector = np.arange(len(filtered_signal)) / fs
        
        # Use EXACT same peak detection as graphs
        peaks = graph_peak_detection(filtered_signal, fs)
        peak_times = peaks / fs
        
        print(f"Total peaks detected: {len(peaks)}")
        
        if len(peaks) < 2:
            continue
            
        # Calculate breathing rates from peaks
        ibi_seconds = np.diff(peak_times)
        breathing_rate_1_over_ibi = 1 / ibi_seconds
        breathing_rate_bpm = breathing_rate_1_over_ibi * 60
        breath_times = peak_times[1:]
        
        # Find matching Excel file
        matching_excel = None
        for excel_file in excel_files:
            if any(session in file_id and session in excel_file for session in 
                   ['RI1_s1_1', 'RI1_s1_2', 'RI1_s2_3', 'RI1_s2_4', 'RI1_s3_5', 'RI1_s3_6', 
                    'RI1_s4_7', 'RI1_s4_8', 'RI1_s5_13', 'RI2_s1_1', 'RI2_s1_2', 'RI2_s2_3', 
                    'RI2_s2_4', 'RI2_s3_5', 'RI2_s3_6', 'RI2_s4_7', 'RI2_s4_8', 'RI2_s5_13']):
                matching_excel = excel_file
                break
        
        if matching_excel:
            print(f"Matched with: {os.path.basename(matching_excel)}")
            behavior_df = pd.read_excel(matching_excel)
            
            fps_map = {"RI1_s1_1": 15, "RI1_s2_3": 15, "RI1_s3_6": 29, "RI2_s1_1": 15, "RI2_s2_4": 15}
            video_fps = 30
            for pattern, fps in fps_map.items():
                if pattern in os.path.basename(matching_excel):
                    video_fps = fps
                    break
            
            behavior_df['time_seconds'] = behavior_df['frame_number'] / video_fps
            behavior_df['behavior_transition'] = (behavior_df['syllable'] != behavior_df['syllable'].shift()).astype(int)
            behavior_df['episode_group'] = behavior_df['behavior_transition'].cumsum()
            
            syllable_bouts = []
            
            for group_id, episode_group in behavior_df.groupby('episode_group'):
                syllable_id = episode_group['syllable'].iloc[0]
                
                bout_start_frame = episode_group['frame_number'].min()
                bout_end_frame = episode_group['frame_number'].max()
                bout_start_time_sec = episode_group['time_seconds'].min()
                bout_end_time_sec = episode_group['time_seconds'].max()
                bout_duration_ms = (bout_end_time_sec - bout_start_time_sec) * 1000
                bout_frame_count = len(episode_group)
                
                if bout_duration_ms >= 500:
                    
                    # Respiratory signal stats
                    time_mask = (time_vector >= bout_start_time_sec) & (time_vector <= bout_end_time_sec)
                    bout_resp_signal = filtered_signal[time_mask]
                    
                    if len(bout_resp_signal) > 0:
                        mean_resp = np.mean(bout_resp_signal)
                        min_resp = np.min(bout_resp_signal)
                        max_resp = np.max(bout_resp_signal)
                        resp_range = max_resp - min_resp
                    else:
                        mean_resp = min_resp = max_resp = resp_range = np.nan
                    
                    # COUNT PEAKS WITHIN EXACT SYLLABLE BOUNDARIES
                    syllable_peak_mask = (peak_times >= bout_start_time_sec) & (peak_times <= bout_end_time_sec)
                    syllable_peak_times = peak_times[syllable_peak_mask]
                    actual_breath_count = len(syllable_peak_times)
                    
                    # Calculate breathing rates ONLY from peaks within this syllable
                    if len(syllable_peak_times) > 1:
                        syllable_ibis = np.diff(syllable_peak_times)
                        mean_ibi = np.mean(syllable_ibis)
                        mean_1_over_ibi = 1 / mean_ibi
                        mean_bpm = mean_1_over_ibi * 60
                    else:
                        # If less than 2 peaks, interpolate from nearest
                        mid_time = (bout_start_time_sec + bout_end_time_sec) / 2
                        if len(breath_times) > 0:
                            mean_1_over_ibi = np.interp(mid_time, breath_times, breathing_rate_1_over_ibi)
                            mean_bpm = mean_1_over_ibi * 60
                            mean_ibi = 1 / mean_1_over_ibi if mean_1_over_ibi > 0 else np.nan
                        else:
                            mean_1_over_ibi = mean_bpm = mean_ibi = np.nan
                    
                    syllable_bouts.append({
                        'syllable_id': syllable_id,
                        'bout_start_frame': bout_start_frame,
                        'bout_end_frame': bout_end_frame,
                        'bout_start_time_sec': bout_start_time_sec,
                        'bout_end_time_sec': bout_end_time_sec,
                        'bout_duration_ms': bout_duration_ms,
                        'bout_frame_count': bout_frame_count,
                        'fps_used': video_fps,
                        'mean_resp_signal_bandpass': mean_resp,
                        'min_resp_signal_bandpass': min_resp,
                        'max_resp_signal_bandpass': max_resp,
                        'resp_signal_range': resp_range,
                        'mean_1_over_IBI': mean_1_over_ibi,
                        'mean_breathing_rate_BPM': mean_bpm,
                        'mean_IBI_seconds': mean_ibi,
                        'breath_count': actual_breath_count,  # THIS NOW MATCHES GRAPH
                        'video_name': episode_group['video_name'].iloc[0] if 'video_name' in episode_group.columns else 'unknown',
                        'track_name': episode_group['track_name'].iloc[0] if 'track_name' in episode_group.columns else 'track0'
                    })
            
            bouts_df = pd.DataFrame(syllable_bouts)
            bouts_df = bouts_df.sort_values('bout_start_time_sec').reset_index(drop=True)
            
            if len(bouts_df) > 0:
                excel_basename = os.path.basename(matching_excel).replace('.xlsx', '')
                output_file = f"CORRECTED_PEAK_COUNT_{excel_basename}.xlsx"
                bouts_df.to_excel(output_file, index=False)
                print(f"Saved: {output_file} with {len(bouts_df)} bouts")
                
                results[file_id] = bouts_df
    
    return results

def create_corrected_master_files():
    """Create master files with corrected peak counts"""
    bout_files = glob.glob("CORRECTED_PEAK_COUNT_*.xlsx")
    
    ri1_files = [f for f in bout_files if "-RI1_" in f]
    ri2_files = [f for f in bout_files if "-RI2_" in f]
    
    print(f"Creating master files from {len(ri1_files)} RI1 and {len(ri2_files)} RI2 files")
    
    def create_master_file(files, output_name):
        with pd.ExcelWriter(output_name, engine='openpyxl') as writer:
            for file in files:
                df = pd.read_excel(file)
                
                filename = os.path.basename(file)
                if "-RI1_" in filename:
                    session_part = filename.split("-RI1_")[1]
                    sheet_prefix = "RI1_"
                elif "-RI2_" in filename:
                    session_part = filename.split("-RI2_")[1]
                    sheet_prefix = "RI2_"
                
                session_info = session_part.split("_")[0:3]
                sheet_name = f"{sheet_prefix}{'_'.join(session_info)}_track0"
                
                if len(sheet_name) > 31:
                    sheet_name = sheet_name[:31]
                
                df.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"Added {sheet_name}: {len(df)} bouts")
    
    if ri1_files:
        create_master_file(ri1_files, "RI1_MASTER_Corrected_Peak_Counts.xlsx")
    if ri2_files:
        create_master_file(ri2_files, "RI2_MASTER_Corrected_Peak_Counts.xlsx")

print("Creating Excel files with corrected peak counts that match graphs...")
corrected_results = create_excel_matching_graph_peaks()
create_corrected_master_files()

print(f"Done! Created {len(corrected_results)} files where breath_count matches graph peaks")
print("Files: CORRECTED_PEAK_COUNT_*.xlsx")
print("Masters: RI1_MASTER_Corrected_Peak_Counts.xlsx, RI2_MASTER_Corrected_Peak_Counts.xlsx")

# Verify the correction worked
test_file = "CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx"
if os.path.exists(test_file):
    df = pd.read_excel(test_file)
    row5 = df.iloc[5]
    print(f"\nVerification - Row 5 (Syllable {row5['syllable_id']}):")
    print(f"New breath_count: {row5['breath_count']} (should match graph peaks)")
    print(f"New BPM: {row5['mean_breathing_rate_BPM']:.1f}")
# Out:
# Creating Excel files with corrected peak counts that match graphs...
# Processing RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Total peaks detected: 4566
# Matched with: top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx with 303 bouts
# Processing RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5
# Total peaks detected: 4495
# Matched with: top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s1_2_p5_1_nRB6_20250622_170742_track0_syllables.xlsx with 266 bouts
# Processing RI1_s2_3_p5_3_nRB3_20250622_104059_merged.h5
# Total peaks detected: 4091
# Matched with: top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx with 504 bouts
# Processing RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5
# Total peaks detected: 5100
# Matched with: top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s2_4_p5_4_nRB3_20250622_123424_track0_syllables.xlsx with 132 bouts
# Processing RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5
# Total peaks detected: 4163
# Processing RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5
# Total peaks detected: 4233
# Matched with: top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx with 289 bouts
# Processing RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5
# Total peaks detected: 4682
# Matched with: top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s4_7_p5_2_nRB3_20250621_150707_track0_syllables.xlsx with 305 bouts
# Processing RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5
# Total peaks detected: 4363
# Matched with: top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s4_8_p5_1_nRB3_20250621_165214_track0_syllables.xlsx with 303 bouts
# Processing RI1_s5_13_p5_4_nRB3_20250622_181801_merged.h5
# Total peaks detected: 163
# Matched with: top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI1_s5_13_p5_4_nRB3_20250622_181801_track0_syllables.xlsx with 315 bouts
# Processing RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5
# Total peaks detected: 3606
# Matched with: top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s1_1_p5_2_nRB6_20250622_150457_track0_syllables.xlsx with 221 bouts
# Processing RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5
# Total peaks detected: 3529
# Matched with: top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s1_2_p5_1_nRB6_20250622_173049_track0_syllables.xlsx with 198 bouts
# Processing RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5
# Total peaks detected: 3673
# Matched with: top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s2_3_p5_3_nRB3_20250622_110216_track0_syllables.xlsx with 188 bouts
# Processing RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5
# Total peaks detected: 3187
# Matched with: top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s2_4_p5_4_nRB3_20250622_125648_track0_syllables.xlsx with 201 bouts
# Processing RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5
# Total peaks detected: 1231
# Matched with: top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s3_5_p5_4_nRB3_20250621_112618_track0_syllables.xlsx with 115 bouts
# Processing RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5
# Total peaks detected: 3412
# Matched with: top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s3_6_p_5_3_nRB3_20250621_131158_track0_syllables.xlsx with 180 bouts
# Processing RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5
# Total peaks detected: 3822
# Matched with: top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s4_7_p5_2_nRB3_20250621_152519_track0_syllables.xlsx with 238 bouts
# Processing RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5
# Total peaks detected: 3360
# Matched with: top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s4_8_p5_1_nRB3_20250621_171318_track0_syllables.xlsx with 197 bouts
# Processing RI2_s5_13_p5_4_nRB3_20250622_184136_merged.h5
# Total peaks detected: 2686
# Matched with: top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx
# Saved: CORRECTED_PEAK_COUNT_top-RI2_s5_13_p5_4_nRB3_20250622_184136_track0_syllables.xlsx with 188 bouts
# Creating master files from 8 RI1 and 9 RI2 files
# Added RI1_s1_1_p5_track0: 303 bouts
# Added RI1_s1_2_p5_track0: 266 bouts
# Added RI1_s2_3_p5_track0: 504 bouts
# Added RI1_s2_4_p5_track0: 132 bouts
# Added RI1_s3_6_p5_track0: 289 bouts
# Added RI1_s4_7_p5_track0: 305 bouts
# Added RI1_s4_8_p5_track0: 303 bouts
# Added RI1_s5_13_p5_track0: 315 bouts
# Added RI2_s1_1_p5_track0: 221 bouts
# Added RI2_s1_2_p5_track0: 198 bouts
# Added RI2_s2_3_p5_track0: 188 bouts
# Added RI2_s2_4_p5_track0: 201 bouts
# Added RI2_s3_5_p5_track0: 115 bouts
# Added RI2_s3_6_p_track0: 180 bouts
# Added RI2_s4_7_p5_track0: 238 bouts
# Added RI2_s4_8_p5_track0: 197 bouts
# Added RI2_s5_13_p5_track0: 188 bouts
# Done! Created 17 files where breath_count matches graph peaks
# Files: CORRECTED_PEAK_COUNT_*.xlsx
# Masters: RI1_MASTER_Corrected_Peak_Counts.xlsx, RI2_MASTER_Corrected_Peak_Counts.xlsx
#
# Verification - Row 5 (Syllable 21):
# New breath_count: 9 (should match graph peaks)
# New BPM: 676.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def verify_and_plot():
    """Verify Excel matches graph and show visual proof"""
    
    # Load the corrected Excel file
    test_file = "CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx"
    df = pd.read_excel(test_file)
    
    # Load respiratory data
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    session_key = [key for key in processed_resp_data.keys() if 'RI1_s1_1' in key][0]
    sig = processed_resp_data[session_key]['respiration']
    fs = 100
    
    # Same peak detection as used in Excel creation
    def graph_peak_detection(signal, fs=100):
        signal_std = np.std(signal)
        peaks, _ = find_peaks(signal,
                             distance=fs * 0.08,
                             prominence=signal_std * 0.2,
                             height=np.mean(signal))
        return peaks
    
    peaks = graph_peak_detection(sig, fs)
    peak_times = peaks / fs
    
    # Test row 5 (Syllable 21)
    selected_bout = df.iloc[5]
    exact_start = selected_bout['bout_start_time_sec']
    exact_end = selected_bout['bout_end_time_sec']
    
    # Count peaks in syllable
    syllable_peak_mask = (peak_times >= exact_start) & (peak_times <= exact_end)
    syllable_peaks = peak_times[syllable_peak_mask]
    graph_peak_count = len(syllable_peaks)
    excel_breath_count = selected_bout['breath_count']
    
    # Plot verification
    context = 1.5
    plot_start = max(0, exact_start - context)
    plot_end = min(len(sig)/fs, exact_end + context)
    
    i0 = int(plot_start * fs)
    i1 = int(plot_end * fs)
    t_plot = np.arange(i0, i1) / fs
    
    window_peaks = peak_times[(peak_times >= plot_start) & (peak_times <= plot_end)]
    
    plt.figure(figsize=(15, 8))
    
    # Top plot: Full context
    plt.subplot(2, 1, 1)
    plt.plot(t_plot, sig[i0:i1], 'b-', lw=2, label="Respiratory signal")
    plt.plot(window_peaks, sig[(window_peaks * fs).astype(int)], 'ro', ms=4, alpha=0.5, label="All peaks")
    plt.plot(syllable_peaks, sig[(syllable_peaks * fs).astype(int)], 'go', ms=8, 
             label=f"Syllable peaks ({len(syllable_peaks)})")
    
    plt.axvline(exact_start, color='red', linestyle='-', linewidth=3, alpha=0.8, label='Syllable bounds')
    plt.axvline(exact_end, color='red', linestyle='-', linewidth=3, alpha=0.8)
    plt.axvspan(exact_start, exact_end, alpha=0.3, color='yellow', label=f'Syllable {selected_bout["syllable_id"]}')
    
    plt.xlabel("Time (seconds)")
    plt.ylabel("Respiratory Signal")
    plt.title(f"VERIFICATION: Row 5 - Syllable {selected_bout['syllable_id']}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Bottom plot: Zoomed syllable only
    plt.subplot(2, 1, 2)
    syl_i0 = int(exact_start * fs)
    syl_i1 = int(exact_end * fs)
    syl_t = np.arange(syl_i0, syl_i1) / fs
    
    plt.plot(syl_t, sig[syl_i0:syl_i1], 'b-', lw=3, label="Syllable signal")
    if len(syllable_peaks) > 0:
        plt.plot(syllable_peaks, sig[(syllable_peaks * fs).astype(int)], 'ro', ms=10, 
                 label=f"Peaks ({len(syllable_peaks)})")
    
    plt.xlabel("Time (seconds)")
    plt.ylabel("Respiratory Signal")
    plt.title(f"ZOOMED: Syllable {selected_bout['syllable_id']} Only")
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Print verification results
    print("=== VERIFICATION RESULTS ===")
    print(f"Video: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5")
    print(f"Excel file: CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx")
    print(f"Row: 5 (Syllable {selected_bout['syllable_id']})")
    print(f"Time: {exact_start:.6f} - {exact_end:.6f} seconds")
    print(f"Duration: {selected_bout['bout_duration_ms']:.1f} ms")
    print()
    print(f"Graph peak count: {graph_peak_count}")
    print(f"Excel breath_count: {excel_breath_count}")
    print(f"MATCH: {'✅ YES' if graph_peak_count == excel_breath_count else '❌ NO'}")
    print()
    print(f"Excel BPM: {selected_bout['mean_breathing_rate_BPM']:.1f}")
    
    if len(syllable_peaks) > 1:
        manual_bpm = (1/np.mean(np.diff(syllable_peaks))) * 60
        print(f"Manual BPM from graph: {manual_bpm:.1f}")
        print(f"BPM MATCH: {'✅ YES' if abs(manual_bpm - selected_bout['mean_breathing_rate_BPM']) < 5 else '❌ NO'}")
    
    return graph_peak_count == excel_breath_count

# Run the verification
success = verify_and_plot()

if success:
    print("\n🎉 SUCCESS: Excel file now matches graph peak detection!")
else:
    print("\n❌ Still doesn't match - need further debugging")
# Out:
# === VERIFICATION RESULTS ===
# Video: RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5
# Excel file: CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx
# Row: 5 (Syllable 21)
# Time: 9.933333 - 10.800000 seconds
# Duration: 866.7 ms
#
# Graph peak count: 9
# Excel breath_count: 9
# MATCH: ✅ YES
#
# Excel BPM: 676.1
# Manual BPM from graph: 676.1
# BPM MATCH: ✅ YES
#
# 🎉 SUCCESS: Excel file now matches graph peak detection!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def verify_multiple_syllables():
    """Verify multiple syllables across different sessions"""
    
    # Test different files and rows
    test_cases = [
        ("CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx", "RI1_s1_1", [2, 5, 10, 15]),
        ("CORRECTED_PEAK_COUNT_top-RI1_s2_3_p5_3_nRB3_20250622_104059_track0_syllables.xlsx", "RI1_s2_3", [1, 8, 12, 20]),
        ("CORRECTED_PEAK_COUNT_top-RI1_s3_6_p5_3_nRB3_20250621_125312_track0_syllables.xlsx", "RI1_s3_6", [3, 7, 14, 18])
    ]
    
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    
    def graph_peak_detection(signal, fs=100):
        signal_std = np.std(signal)
        peaks, _ = find_peaks(signal,
                             distance=fs * 0.08,
                             prominence=signal_std * 0.2,
                             height=np.mean(signal))
        return peaks
    
    for excel_file, session_pattern, test_rows in test_cases:
        if not os.path.exists(excel_file):
            print(f"File not found: {excel_file}")
            continue
            
        print(f"\n=== TESTING {session_pattern} ===")
        
        # Load data
        df = pd.read_excel(excel_file)
        session_key = [key for key in processed_resp_data.keys() if session_pattern in key][0]
        sig = processed_resp_data[session_key]['respiration']
        fs = 100
        
        # Detect peaks
        peaks = graph_peak_detection(sig, fs)
        peak_times = peaks / fs
        
        fig, axes = plt.subplots(2, 2, figsize=(16, 10))
        axes = axes.flatten()
        
        matches = 0
        total = 0
        
        for i, row_idx in enumerate(test_rows[:4]):  # Max 4 plots
            if row_idx >= len(df):
                continue
                
            bout = df.iloc[row_idx]
            exact_start = bout['bout_start_time_sec']
            exact_end = bout['bout_end_time_sec']
            
            # Count peaks in syllable
            syllable_peak_mask = (peak_times >= exact_start) & (peak_times <= exact_end)
            syllable_peaks = peak_times[syllable_peak_mask]
            graph_count = len(syllable_peaks)
            excel_count = bout['breath_count']
            
            match = (graph_count == excel_count)
            matches += match
            total += 1
            
            # Plot
            context = 1.0
            plot_start = max(0, exact_start - context)
            plot_end = min(len(sig)/fs, exact_end + context)
            
            i0 = int(plot_start * fs)
            i1 = int(plot_end * fs)
            t_plot = np.arange(i0, i1) / fs
            
            window_peaks = peak_times[(peak_times >= plot_start) & (peak_times <= plot_end)]
            
            ax = axes[i]
            ax.plot(t_plot, sig[i0:i1], 'b-', lw=1.5, label="Signal")
            ax.plot(window_peaks, sig[(window_peaks * fs).astype(int)], 'ro', ms=3, alpha=0.6, label="All peaks")
            ax.plot(syllable_peaks, sig[(syllable_peaks * fs).astype(int)], 'go', ms=6, 
                   label=f"Syllable peaks ({len(syllable_peaks)})")
            
            ax.axvline(exact_start, color='red', linestyle='-', linewidth=2, alpha=0.8)
            ax.axvline(exact_end, color='red', linestyle='-', linewidth=2, alpha=0.8)
            ax.axvspan(exact_start, exact_end, alpha=0.3, color='yellow')
            
            ax.set_xlabel("Time (s)")
            ax.set_ylabel("Signal")
            ax.set_title(f"Row {row_idx}: Syl {bout['syllable_id']} - Graph:{graph_count} Excel:{excel_count} {'✓' if match else '✗'}")
            ax.legend(fontsize=8)
            ax.grid(True, alpha=0.3)
            
            print(f"  Row {row_idx}: Syllable {bout['syllable_id']} - Graph:{graph_count} Excel:{excel_count} {'✓' if match else '✗'}")
        
        plt.suptitle(f"{session_pattern} Verification - {matches}/{total} matches", fontsize=14)
        plt.tight_layout()
        plt.show()
        
        print(f"  Summary: {matches}/{total} syllables match")

# Run verification on multiple files
verify_multiple_syllables()
# Out:
# === TESTING RI1_s1_1 ===
#   Row 2: Syllable 7 - Graph:15 Excel:15 ✓
#   Row 5: Syllable 21 - Graph:9 Excel:9 ✓
#   Row 10: Syllable 20 - Graph:10 Excel:10 ✓
#   Row 15: Syllable 18 - Graph:6 Excel:6 ✓
#   Summary: 4/4 syllables match
#
# === TESTING RI1_s2_3 ===
#   Row 1: Syllable 10 - Graph:21 Excel:21 ✓
#   Row 8: Syllable 24 - Graph:52 Excel:52 ✓
#   Row 12: Syllable 3 - Graph:4 Excel:4 ✓
#   Row 20: Syllable 24 - Graph:9 Excel:9 ✓
#   Summary: 4/4 syllables match
#
# === TESTING RI1_s3_6 ===
#   Row 3: Syllable 24 - Graph:19 Excel:19 ✓
#   Row 7: Syllable 11 - Graph:15 Excel:15 ✓
#   Row 14: Syllable 0 - Graph:6 Excel:6 ✓
#   Row 18: Syllable 0 - Graph:7 Excel:7 ✓
#   Summary: 4/4 syllables match

# %%
def test_specific_time_windows():
    """Test specific time windows across different sessions"""
    
    time_tests = [
        ("RI1_s1_1", 50.0, 55.0, "Early recording"),
        ("RI1_s1_1", 150.0, 155.0, "Mid recording"),  
        ("RI1_s2_3", 100.0, 105.0, "Different session"),
        ("RI1_s3_6", 200.0, 205.0, "29 FPS session"),
        ("RI2_s1_1", 80.0, 85.0, "RI2 example")
    ]
    
    processed_resp_data = pd.read_pickle(r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl")
    
    def graph_peak_detection(signal, fs=100):
        signal_std = np.std(signal)
        peaks, _ = find_peaks(signal,
                             distance=fs * 0.08,
                             prominence=signal_std * 0.2,
                             height=np.mean(signal))
        return peaks
    
    fig, axes = plt.subplots(3, 2, figsize=(15, 12))
    axes = axes.flatten()
    
    for i, (session, start_time, end_time, description) in enumerate(time_tests):
        if i >= 6:  # Max 6 plots
            break
            
        # Find session key
        session_key = None
        for key in processed_resp_data.keys():
            if session in key:
                session_key = key
                break
        
        if session_key is None:
            continue
            
        sig = processed_resp_data[session_key]['respiration']
        fs = 100
        
        # Detect peaks
        peaks = graph_peak_detection(sig, fs)
        peak_times = peaks / fs
        
        # Plot time window
        i0 = int(start_time * fs)
        i1 = int(end_time * fs)
        t_plot = np.arange(i0, i1) / fs
        
        window_peaks = peak_times[(peak_times >= start_time) & (peak_times <= end_time)]
        
        ax = axes[i]
        ax.plot(t_plot, sig[i0:i1], 'b-', lw=1.5, label="Signal")
        ax.plot(window_peaks, sig[(window_peaks * fs).astype(int)], 'ro', ms=5, 
               label=f"Peaks ({len(window_peaks)})")
        
        ax.set_xlabel("Time (s)")
        ax.set_ylabel("Signal")
        ax.set_title(f"{session} ({start_time}-{end_time}s) - {description}")
        ax.legend()
        ax.grid(True, alpha=0.3)
        
        # Calculate BPM for this window
        if len(window_peaks) > 1:
            window_ibis = np.diff(window_peaks)
            window_bpm = (1/np.mean(window_ibis)) * 60
            ax.text(0.02, 0.95, f'{window_bpm:.0f} BPM', transform=ax.transAxes,
                   bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8))
    
    plt.suptitle("Peak Detection Across Different Sessions and Time Windows", fontsize=14)
    plt.tight_layout()
    plt.show()

# Run time window tests
test_specific_time_windows()

# %%
def compare_before_after_correction():
    """Compare old vs new Excel files to show the correction worked"""
    
    # Compare if you have both old and new files
    old_file = "FINAL_IMPROVED_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx"
    new_file = "CORRECTED_PEAK_COUNT_top-RI1_s1_1_p5_2_nRB6_20250622_143958_track0_syllables.xlsx"
    
    if os.path.exists(old_file) and os.path.exists(new_file):
        old_df = pd.read_excel(old_file)
        new_df = pd.read_excel(new_file)
        
        print("=== BEFORE vs AFTER CORRECTION ===")
        print("Comparing first 10 syllable bouts:")
        print()
        
        for i in range(min(10, len(old_df), len(new_df))):
            old_bout = old_df.iloc[i]
            new_bout = new_df.iloc[i]
            
            print(f"Row {i}: Syllable {old_bout['syllable_id']}")
            print(f"  Old breath_count: {old_bout['breath_count']}")
            print(f"  New breath_count: {new_bout['breath_count']}")
            print(f"  Change: {new_bout['breath_count'] - old_bout['breath_count']:+d}")
            print(f"  Old BPM: {old_bout['mean_breathing_rate_BPM']:.1f}")
            print(f"  New BPM: {new_bout['mean_breathing_rate_BPM']:.1f}")
            print()
    
    else:
        print("Old file not found - cannot compare before/after")

# Run comparison
compare_before_after_correction()
# Out:
# === BEFORE vs AFTER CORRECTION ===
# Comparing first 10 syllable bouts:
#
# Row 0: Syllable 21
#   Old breath_count: 7
#   New breath_count: 16
#   Change: +9
#   Old BPM: 286.9
#   New BPM: 580.6
#
# Row 1: Syllable 28
#   Old breath_count: 3
#   New breath_count: 7
#   Change: +4
#   Old BPM: 360.3
#   New BPM: 720.0
#
# Row 2: Syllable 7
#   Old breath_count: 6
#   New breath_count: 15
#   Change: +9
#   Old BPM: 308.8
#   New BPM: 700.0
#
# Row 3: Syllable 16
#   Old breath_count: 14
#   New breath_count: 28
#   Change: +14
#   Old BPM: 313.1
#   New BPM: 613.6
#
# Row 4: Syllable 5
#   Old breath_count: 2
#   New breath_count: 6
#   Change: +4
#   Old BPM: 282.1
#   New BPM: 638.3
#
# Row 5: Syllable 21
#   Old breath_count: 5
#   New breath_count: 9
#   Change: +4
#   Old BPM: 337.3
#   New BPM: 676.1
#
# Row 6: Syllable 25
#   Old breath_count: 8
#   New breath_count: 20
#   Change: +12
#   Old BPM: 294.1
#   New BPM: 584.6
#
# Row 7: Syllable 13
#   Old breath_count: 4
#   New breath_count: 7
#   Change: +3
#   Old BPM: 259.7
#   New BPM: 413.8
#
# Row 8: Syllable 13
#   Old breath_count: 4
#   New breath_count: 7
#   Change: +3
#   Old BPM: 263.8
#   New BPM: 423.5
#
# Row 9: Syllable 20
#   Old breath_count: 4
#   New breath_count: 6
#   Change: +2
#   Old BPM: 269.2
#   New BPM: 483.9
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import h5py
import numpy as np
import pandas as pd
from scipy.signal import find_peaks, butter, filtfilt
import glob
import os
import matplotlib.pyplot as plt
from datetime import datetime

def H(title):
    line = "=" * max(12, len(title))
    print("\n" + line)
    print(title)
    print(line)

H("Imports and runtime state")
print("Libraries loaded")
print(f"Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

H("Global parameters and core assumptions")
RESP_H5_PATH = r"C:\Users\Padilla-Coreano\Documents\tanish\Resp_h5"
EXCEL_PATH = r"C:\Users\Padilla-Coreano\Documents\tanish\Keypoint RI1+RI2\Excel_Results"
PROCESSED_DATA_PATH = r"C:\Users\Padilla-Coreano\Documents\tanis...oint RI1+RI2\Excel_Results\processed_respiration_data_0.5Hz.pkl"

ORIGINAL_SAMPLING_RATE = 20000
TARGET_SAMPLING_RATE = 100
MIN_SYLLABLE_DURATION = 500

PEAK_MIN_DISTANCE = 0.08
PEAK_PROMINENCE_FACTOR = 0.2

FPS_MAPPING = {
    "RI1_s1_1": 15,
    "RI1_s2_3": 15,
    "RI1_s3_6": 29,
    "RI2_s1_1": 15,
    "RI2_s2_4": 15
}
DEFAULT_FPS = 30

print({
    "ORIGINAL_SAMPLING_RATE": ORIGINAL_SAMPLING_RATE,
    "TARGET_SAMPLING_RATE": TARGET_SAMPLING_RATE,
    "MIN_SYLLABLE_DURATION_MS": MIN_SYLLABLE_DURATION,
    "PEAK_MIN_DISTANCE_SEC": PEAK_MIN_DISTANCE,
    "PEAK_PROMINENCE_FACTOR": PEAK_PROMINENCE_FACTOR,
    "DEFAULT_FPS": DEFAULT_FPS,
    "FPS_MAPPING_KEYS": sorted(list(FPS_MAPPING.keys()))
})

H("H5 ingestion primitives")
def list_h5_datasets(h5_path):
    keys = []
    with h5py.File(h5_path, "r") as f:
        def visitor(name, obj):
            if isinstance(obj, h5py.Dataset):
                keys.append(name)
        f.visititems(visitor)
    return sorted(keys)

def read_h5_signal(h5_path, dataset_key):
    with h5py.File(h5_path, "r") as f:
        x = np.array(f[dataset_key])
    return x

print("H5 dataset listing and reading ready")

H("Filtering and resampling primitives")
def butter_lowpass(cutoff_hz, fs_hz, order=4):
    nyq = 0.5 * fs_hz
    normal = cutoff_hz / nyq
    b, a = butter(order, normal, btype="low", analog=False)
    return b, a

def apply_lowpass(x, cutoff_hz, fs_hz, order=4):
    b, a = butter_lowpass(cutoff_hz, fs_hz, order=order)
    return filtfilt(b, a, x)

def resample_by_decimation(x, original_fs, target_fs):
    factor = int(round(original_fs / target_fs))
    if factor <= 0:
        raise ValueError("Invalid decimation factor")
    if original_fs % target_fs != 0:
        raise ValueError("original_fs must be an integer multiple of target_fs for this resampling method")
    return x[::factor]

print("Filter + decimation resampling ready")

H("Normalization primitives (if used before peak detection)")
def zscore(x):
    s = np.std(x)
    m = np.mean(x)
    if s == 0:
        return x * 0
    return (x - m) / s

def center(x):
    return x - np.mean(x)

print("Normalization helpers ready")

H("Peak detection logic")
def detect_breathing_peaks(signal, fs=TARGET_SAMPLING_RATE):
    signal_std = np.std(signal)
    signal_mean = np.mean(signal)

    peaks, properties = find_peaks(
        signal,
        distance=int(fs * PEAK_MIN_DISTANCE),
        prominence=signal_std * PEAK_PROMINENCE_FACTOR,
        height=signal_mean
    )

    return peaks

print("Peak detection ready")

H("Video FPS resolution")
def get_video_fps(filename):
    for pattern, fps in FPS_MAPPING.items():
        if pattern in filename:
            return fps
    return DEFAULT_FPS

print("FPS resolver ready")

H("Respiratory rate and IBI math from peaks")
def calculate_respiratory_metrics(peaks, fs=TARGET_SAMPLING_RATE):
    if len(peaks) < 2:
        return np.array([]), np.array([]), np.array([])

    peak_times = peaks / fs
    ibi_seconds = np.diff(peak_times)
    breathing_rate_1_over_ibi = 1 / ibi_seconds
    breath_times = peak_times[1:]

    return breathing_rate_1_over_ibi, breath_times, ibi_seconds

print("Resp metrics ready")

H("Behavior dataframe schema normalization")
def canonicalize_behavior_columns(df):
    df = df.copy()

    renames = {}
    if "frame_number" not in df.columns:
        if "Frame" in df.columns:
            renames["Frame"] = "frame_number"
        if "frame" in df.columns:
            renames["frame"] = "frame_number"

    if "syllable" not in df.columns:
        if "Syllable" in df.columns:
            renames["Syllable"] = "syllable"
        if "syllable_id" in df.columns:
            renames["syllable_id"] = "syllable"

    if renames:
        df = df.rename(columns=renames)

    if "frame_number" not in df.columns or "syllable" not in df.columns:
        raise ValueError(f"Required columns not found after canonicalization. Columns={list(df.columns)}")

    df = df.dropna(subset=["frame_number", "syllable"])
    df["frame_number"] = df["frame_number"].astype(int)
    df["syllable"] = df["syllable"].astype(int)

    return df

print("Behavior schema normalizer ready")

H("Keypoint-MoSeq syllable bout construction (grouping + duration filtering)")
def create_syllable_bouts(behavior_df, video_fps, min_duration_ms=MIN_SYLLABLE_DURATION):
    behavior_df = behavior_df.copy()
    behavior_df["time_seconds"] = behavior_df["frame_number"] / video_fps
    behavior_df["transition"] = (behavior_df["syllable"] != behavior_df["syllable"].shift()).astype(int)
    behavior_df["bout_group"] = behavior_df["transition"].cumsum()

    bouts_list = []

    for group_id, group in behavior_df.groupby("bout_group"):
        syllable_id = int(group["syllable"].iloc[0])

        start_time = float(group["time_seconds"].min())
        end_time = float(group["time_seconds"].max())
        duration_ms = float((end_time - start_time) * 1000)

        if duration_ms >= min_duration_ms:
            bout_info = {
                "syllable_id": syllable_id,
                "start_frame": int(group["frame_number"].min()),
                "end_frame": int(group["frame_number"].max()),
                "start_time_sec": start_time,
                "end_time_sec": end_time,
                "duration_ms": duration_ms,
                "frame_count": int(len(group)),
                "fps_used": float(video_fps),
            }
            bouts_list.append(bout_info)

    return bouts_list

print("Bout constructor ready")

H("Session key reconciliation and Excel selection")
def find_resp_key(resp_dict, session_pattern):
    matches = [k for k in resp_dict.keys() if session_pattern in k]
    if len(matches) == 0:
        return None
    if len(matches) == 1:
        return matches[0]
    matches_sorted = sorted(matches, key=len)
    return matches_sorted[0]

def pick_excel_file(session_id, excel_files):
    matches = [f for f in excel_files if session_id in os.path.basename(f)]
    if len(matches) == 0:
        return None
    if len(matches) == 1:
        return matches[0]
    matches_sorted = sorted(matches)
    return matches_sorted[0]

print("Key matching helpers ready")

H("Windowing math and per-bout respiratory summaries")
def count_peaks_in_window(peak_times, start_time, end_time, inclusive=True):
    if inclusive:
        mask = (peak_times >= start_time) & (peak_times <= end_time)
    else:
        mask = (peak_times > start_time) & (peak_times < end_time)
    return int(mask.sum())

def summarize_bout_respiration(peak_times, breath_times, breathing_rates_hz, start_time, end_time):
    peak_count = count_peaks_in_window(peak_times, start_time, end_time, inclusive=True)

    mid_time = (start_time + end_time) / 2
    if len(breath_times) > 0 and len(breathing_rates_hz) > 0:
        rate_hz = float(np.interp(mid_time, breath_times, breathing_rates_hz))
        bpm = float(rate_hz * 60)
        ibi = float(1 / rate_hz) if rate_hz > 0 else np.nan
    else:
        rate_hz = np.nan
        bpm = np.nan
        ibi = np.nan

    return {
        "peak_count": peak_count,
        "mean_breathing_rate_hz": rate_hz,
        "mean_bpm": bpm,
        "mean_ibi_sec": ibi
    }

print("Bout respiration summary ready")

H("Single-session integration (peaks + bouts + per-bout features)")
def process_single_session(session_id, respiratory_signal, excel_files):
    print(f"Processing: {session_id}")

    signal = respiratory_signal["respiration"]
    fs = respiratory_signal.get("fs", TARGET_SAMPLING_RATE)

    peaks = detect_breathing_peaks(signal, fs)
    print(f"  Peaks detected: {len(peaks)}")

    if len(peaks) < 2:
        print("  Insufficient peaks - skipping")
        return None

    breathing_rates_hz, breath_times, ibi_values = calculate_respiratory_metrics(peaks, fs)
    peak_times = peaks / fs

    excel_file = pick_excel_file(session_id, excel_files)
    if excel_file is None:
        print(f"  No Excel file found for {session_id}")
        return None

    print(f"  Using Excel file: {os.path.basename(excel_file)}")
    behavior_df = pd.read_excel(excel_file)
    behavior_df = canonicalize_behavior_columns(behavior_df)

    video_fps = get_video_fps(os.path.basename(excel_file))
    bouts_list = create_syllable_bouts(behavior_df, video_fps, MIN_SYLLABLE_DURATION)

    print(f"  Found {len(bouts_list)} syllable bouts")

    processed_bouts = []
    for bout in bouts_list:
        start_time = bout["start_time_sec"]
        end_time = bout["end_time_sec"]
        resp_summary = summarize_bout_respiration(peak_times, breath_times, breathing_rates_hz, start_time, end_time)

        out_row = {
            "syllable_id": bout["syllable_id"],
            "start_time_sec": start_time,
            "end_time_sec": end_time,
            "duration_ms": bout["duration_ms"],
            "frame_count": bout["frame_count"],
            "fps_used": bout["fps_used"],
        }
        out_row.update(resp_summary)
        processed_bouts.append(out_row)

    results_df = pd.DataFrame(processed_bouts)
    results_df = results_df.sort_values("start_time_sec").reset_index(drop=True)

    print(f"  Processed {len(results_df)} syllable bouts")
    return results_df

print("Single-session runner ready")

H("Batch runner and export logic")
def run_complete_analysis():
    print("Starting analysis...")

    respiratory_data = pd.read_pickle(PROCESSED_DATA_PATH)
    excel_files = glob.glob(os.path.join(EXCEL_PATH, "*track0*.xlsx"))

    print(f"Found {len(respiratory_data)} respiratory sessions")
    print(f"Found {len(excel_files)} behavioral files")

    all_results = {}
    successful_sessions = 0

    for session_id, resp_data in respiratory_data.items():
        try:
            result = process_single_session(session_id, resp_data, excel_files)

            if result is not None:
                session_name = session_id.replace(" ", "_").replace("/", "_")
                output_file = f"CORRECTED_PEAK_COUNT_{session_name}_analysis.xlsx"
                result.to_excel(output_file, index=False)
                print(f"  Saved: {output_file}")

                all_results[session_id] = result
                successful_sessions += 1

        except Exception as e:
            print(f"  Error processing {session_id}: {str(e)}")

    print(f"Analysis complete: {successful_sessions}/{len(respiratory_data)} sessions processed")
    return all_results

print("Batch runner ready")

H("Peak-count verification against exported analysis output")
def verify_peak_detection(session_id="RI1_s1_1", test_rows=[2, 5, 8]):
    excel_pattern = f"CORRECTED_PEAK_COUNT_*{session_id}*_analysis.xlsx"
    excel_files = glob.glob(excel_pattern)

    if not excel_files:
        print(f"No Excel file found for {session_id}")
        return None

    excel_file = excel_files[0]
    df = pd.read_excel(excel_file)

    respiratory_data = pd.read_pickle(PROCESSED_DATA_PATH)
    resp_key = find_resp_key(respiratory_data, session_id)
    if resp_key is None:
        print(f"No respiration key found for {session_id}")
        return None

    signal = respiratory_data[resp_key]["respiration"]
    fs = respiratory_data[resp_key].get("fs", TARGET_SAMPLING_RATE)

    peaks = detect_breathing_peaks(signal, fs)
    peak_times = peaks / fs

    matches = 0
    total_tests = len(test_rows)

    plt.figure(figsize=(15, 8))

    for i, row_idx in enumerate(test_rows):
        if row_idx >= len(df):
            continue

        bout = df.iloc[row_idx]
        start_time = float(bout["start_time_sec"])
        end_time = float(bout["end_time_sec"])

        window_mask = (peak_times >= start_time) & (peak_times <= end_time)
        window_peak_times = peak_times[window_mask]

        graph_count = len(window_peak_times)
        excel_count = int(bout["peak_count"])

        if graph_count == excel_count:
            matches += 1
            match_text = "MATCH"
        else:
            match_text = "MISMATCH"

        plt.subplot(len(test_rows), 1, i + 1)

        t = np.arange(len(signal)) / fs
        time_window = (t >= start_time - 0.5) & (t <= end_time + 0.5)
        window_time = t[time_window]
        window_signal = signal[time_window]

        plt.plot(window_time, window_signal)

        for pt in window_peak_times:
            plt.axvline(x=pt, linestyle="--", alpha=0.7)

        plt.axvline(x=start_time, linewidth=2)
        plt.axvline(x=end_time, linewidth=2)

        plt.title(
            f"Row {row_idx}: Excel={excel_count}, Graph={graph_count} {match_text} "
            f"(Syllable {int(bout['syllable_id'])}, {start_time:.2f}-{end_time:.2f}s)"
        )

    plt.suptitle(f"{session_id} Verification - {matches}/{total_tests} matches")
    plt.tight_layout()
    plt.show()

    print(f"Verification: {matches}/{total_tests} syllables match")
    return matches == total_tests

print("Verification routine ready")
